# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import auc,roc_auc_score,classification_report,roc_curve,auc,f1_score
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import optuna
import warnings
from collections import Counter
warnings.simplefilter('ignore')


SEED=95
TRIALS=100
TREES_LOWER=32
TREES_UPPER=64


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
class Config:
    train_link = "train.csv"
    test_link = "test.csv"
    sub_link  = "sample_submission.csv"
    original = "Rainfall.csv"

# %%
train = pd.read_csv(Config.train_link, index_col = 'id')
test = pd.read_csv(Config.test_link, index_col = 'id')
original = pd.read_csv(Config.original)

original.columns = [col.strip() for col in original.columns]

rain_map = {'yes':1,
           'no':0}

original['rainfall'] = original['rainfall'].map(rain_map)

original.dropna(inplace = True)

train = pd.concat([train, original], axis = 0, ignore_index = True)

train = train.fillna(0)

test.winddirection=test.winddirection.fillna(test.winddirection.median())

# %%
train.describe()
# Out:
#                day     pressure      maxtemp  temparature      mintemp  \
# count  2555.000000  2555.000000  2555.000000  2555.000000  2555.000000
# mean    156.495108  1013.625362    26.338708    23.921918    22.128885
# std     113.131808     5.768099     5.701105     5.282829     5.139142
# min       1.000000   998.500000     7.100000     4.900000     3.100000
# 25%      44.500000  1008.600000    21.300000    19.300000    17.600000
# 50%     148.000000  1013.000000    27.800000    25.500000    23.800000
# 75%     255.000000  1017.800000    31.200000    28.400000    26.500000
# max     365.000000  1034.600000    36.300000    32.400000    30.000000
#
#           dewpoint     humidity        cloud     sunshine  winddirection  \
# count  2555.000000  2555.000000  2555.000000  2555.000000    2555.000000
# mean     20.385832    81.768689    75.062622     3.840039     104.383679
# std       5.396821     8.187895    18.681667     3.679170      80.242979
# min      -0.400000    36.000000     0.000000     0.000000      10.000000
# 25%      16.800000    77.000000    68.000000     0.400000      40.000000
# 50%      22.100000    81.000000    83.000000     2.400000      70.000000
# 75%      25.000000    87.000000    88.000000     7.000000     200.000000
# max      26.700000    98.000000   100.000000    12.100000     350.000000
#
#          windspeed     rainfall
# count  2555.000000  2555.000000
# mean     21.766458     0.742857
# std       9.921727     0.437144
# min       4.400000     0.000000
# 25%      14.100000     0.000000
# 50%      20.500000     1.000000
# 75%      27.900000     1.000000
# max      59.500000     1.000000

# %%
train['month']=((train["day"] - 1) // 30) + 1
train["season"] = train["month"].map({
        1: "Winter", 2: "Winter", 3: "Spring", 4: "Spring", 5: "Spring",
        6: "Summer", 7: "Summer", 8: "Summer", 9: "Fall", 10: "Fall",
        11: "Fall", 12: "Winter"
    })

# %%
rainmap=train.groupby('day')['rainfall'].mean().to_dict()
season_weights = train.groupby('season')['rainfall'].mean().to_dict()

# %%
num_feats=[]

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

def transform_features(df, is_train=True, train_mapping=None):
    '''
    df["wind_x"] = df["windspeed"] * np.cos(np.radians(df["winddirection"]))
    df["wind_y"] = df["windspeed"] * np.sin(np.radians(df["winddirection"]))
    df["stability_index"] = df["maxtemp"] - df["mintemp"]
    df["pressure_drop"] = df["pressure"].diff().fillna(0)
    '''
    df["month"] = ((df["day"] - 1) // 30) + 1
    df["season"] = df["month"].map({
        1: "Winter", 2: "Winter", 3: "Spring", 4: "Spring", 5: "Spring",
        6: "Summer", 7: "Summer", 8: "Summer", 9: "Fall", 10: "Fall",
        11: "Fall", 12: "Winter"
    }).map(season_weights)

    #df["dew_point_depression"] = df["temparature"] - df["dewpoint"]
    #df["dew_pressure"] = df["pressure"] / (df["dewpoint"] + 1)
    #df["cloud_sun_ratio"] = df["cloud"] / (df["sunshine"] + 1)
    df['rain_day']=df['day'].map(rainmap)
    
    df.drop(columns=["month", 'day'], inplace=True)
    #df.drop(columns=["month"], inplace=True)
    df.fillna(method="ffill", inplace=True)
    df.fillna(df.median(), inplace=True)

    if is_train:
        X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['rainfall']), 
                                                            df['rainfall'], 
                                                            test_size=0.2, 
                                                            random_state=SEED,
                                                            stratify=df['rainfall'])

        num_feats=list(X_train.columns)
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        return X_train, X_test, y_train, y_test,num_feats

    else:
        df.fillna(method="ffill", inplace=True)
        df.fillna(df.median(), inplace=True)
        return df

# %%
X_train,X_test,y_train,y_test,num_feats=transform_features(train)
test=transform_features(test,False)

# %%
num_feats
# Out:
# ['pressure',
#  'maxtemp',
#  'temparature',
#  'mintemp',
#  'dewpoint',
#  'humidity',
#  'cloud',
#  'sunshine',
#  'winddirection',
#  'windspeed',
#  'season',
#  'rain_day']

# %%
test.head()
# Out:
#       pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# id
# 2190    1019.5     17.5         15.8     12.7      14.9      96.0   99.0
# 2191    1016.5     17.5         16.5     15.8      15.1      97.0   99.0
# 2192    1023.9     11.2         10.4      9.4       8.9      86.0   96.0
# 2193    1022.9     20.6         17.3     15.2       9.5      75.0   45.0
# 2194    1022.2     16.1         13.8      6.4       4.3      68.0   49.0
#
#       sunshine  winddirection  windspeed    season  rain_day
# id
# 2190       0.0           50.0       24.3  0.709571  0.666667
# 2191       0.0           50.0       35.3  0.709571  0.833333
# 2192       0.0           40.0       16.9  0.709571  0.789474
# 2193       7.1           20.0       50.6  0.709571  0.684211
# 2194       9.2           20.0       19.4  0.709571  0.684211

# %%
test.isna().sum().sum()
# Out:
# 0

# %%
test_mean = test[num_feats].mean(axis =0)
test_std = test[num_feats].std(axis =0)

test[num_feats] -= test_mean
test[num_feats] /= test_std

# %%
X_train
# Out:
# array([[ 0.47772884,  0.14879078,  0.27883038, ..., -1.36517409,
#          0.21991264,  0.43239296],
#        [ 0.52967375,  0.06073462, -0.15722876, ..., -0.50233368,
#          1.73870339, -0.14706745],
#        [ 1.55125699, -1.18966277, -1.38956982, ...,  0.72169573,
#         -0.60282571, -0.37885162],
#        ...,
#        [ 0.16605937, -1.68277724, -1.59811985, ..., -0.07091348,
#         -0.60282571,  1.24363755],
#        [-2.34461131,  1.29352079,  1.16990777, ...,  0.69159665,
#         -0.97454715,  0.43239296],
#        [-0.76894902, -0.0097103 , -0.11931058, ..., -0.11104559,
#         -0.60282571,  0.43239296]])

# %%
submission=pd.read_csv('sample_submission.csv')

# %%
import optuna
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

def create_model(trial):
    model = Sequential()
    model.add(Dense(units=trial.suggest_int('units_1', 110, 256, log=True),
                    activation='relu', kernel_initializer='he_normal', input_shape=(X_train.shape[1],)))
    model.add(Dropout(.35))
    model.add(Dense(units=trial.suggest_int('units_2', 53, 128, log=True),
                    activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(.35))
    model.add(Dense(units=32, activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(.3))
    model.add(Dense(units=16, activation='relu', kernel_initializer='he_normal'))
    model.add(Dense(units=1, activation='sigmoid'))
    
    
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    
    return model


early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %%
def objective(trial):
    model = create_model(trial)
    model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)
    score = model.evaluate(X_test, y_test, verbose=1)
    return score[1]
    
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, show_progress_bar=True)

print('Best trial:')
best_trial = study.best_trial
print(f'  Value: {best_trial.value}')
print('  Params: ')
for key, value in best_trial.params.items():
    print(f'    {key}: {value}')
# Out:
# [I 2025-03-05 10:16:23,657] A new study created in memory with name: no-name-18f22709-ae6b-4201-85b8-05af563a115e
#   0%|          | 0/100 [00:00<?, ?it/s]
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2510
# [I 2025-03-05 10:16:32,304] Trial 0 finished with value: 0.9041095972061157 and parameters: {'units_1': 144, 'units_2': 53}. Best is trial 0 with value: 0.9041095972061157.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9172 - loss: 0.2627
# [I 2025-03-05 10:16:44,571] Trial 1 finished with value: 0.9119373559951782 and parameters: {'units_1': 112, 'units_2': 65}. Best is trial 1 with value: 0.9119373559951782.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9133 - loss: 0.2565
# [I 2025-03-05 10:16:51,804] Trial 2 finished with value: 0.9001957178115845 and parameters: {'units_1': 119, 'units_2': 101}. Best is trial 1 with value: 0.9119373559951782.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9109 - loss: 0.2605
# [I 2025-03-05 10:17:01,647] Trial 3 finished with value: 0.8962817788124084 and parameters: {'units_1': 110, 'units_2': 64}. Best is trial 1 with value: 0.9119373559951782.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9022 - loss: 0.2580
# [I 2025-03-05 10:17:12,646] Trial 4 finished with value: 0.9021526575088501 and parameters: {'units_1': 118, 'units_2': 71}. Best is trial 1 with value: 0.9119373559951782.

# %%
df_study = pd.DataFrame([
    {**t.params, "AUC": t.value, "Trial Number": t.number} 
    for t in study.trials
])

df_study = df_study.sort_values(by="AUC", ascending=False).reset_index(drop=True)

print(df_study.head(5))

top_model_params = [
    trial.params for trial in sorted(study.trials, key=lambda t: t.value, reverse=True)[:5]
]

print(top_model_params)
# Out:
#    units_1  dropout_1  units_2  dropout_2       AUC  Trial Number
# 0      227   0.277655       46   0.424483  0.878995             5
# 1      240   0.370481       50   0.277941  0.878995            65
# 2      202   0.453337       46   0.323742  0.878995            63
# 3       86   0.473484      102   0.330211  0.878995            30
# 4      238   0.424672       34   0.353323  0.876712            56
# [{'units_1': 227, 'dropout_1': 0.27765503657786833, 'units_2': 46, 'dropout_2': 0.4244830377657848}, {'units_1': 86, 'dropout_1': 0.47348442354111114, 'units_2': 102, 'dropout_2': 0.3302108865667155}, {'units_1': 202, 'dropout_1': 0.4533367053750445, 'units_2': 46, 'dropout_2': 0.32374184345307977}, {'units_1': 240, 'dropout_1': 0.3704805214196765, 'units_2': 50, 'dropout_2': 0.277941167149058}, {'units_1': 71, 'dropout_1': 0.23605053728138425, 'units_2': 49, 'dropout_2': 0.3041498413928818}]

# %%
#top_model_params=[{'units_1': 92, 'dropout_1': 0.36537034589997436, 'units_2': 66, 'dropout_2': 0.31031514284970424}, {'units_1': 115, 'dropout_1': 0.35976665986533063, 'units_2': 61, 'dropout_2': 0.21245866054640758}, {'units_1': 235, 'dropout_1': 0.42604377318637393, 'units_2': 69, 'dropout_2': 0.2333035285439651}, {'units_1': 118, 'dropout_1': 0.4158563273591014, 'units_2': 51, 'dropout_2': 0.3560913945173838}, {'units_1': 203, 'dropout_1': 0.32328676753873037, 'units_2': 64, 'dropout_2': 0.20090305793683494}]

# %%
model_predictions = []

for params in top_model_params[:3]:
    model = Sequential()
    model.add(Dense(units=params['units_1'], activation='relu', kernel_initializer='he_normal', 
                    input_shape=(X_train.shape[1],)))
    model.add(Dropout(rate=params['dropout_1']))
    model.add(Dense(units=params['units_2'], activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(rate=params['dropout_2']))
    model.add(Dense(units=16, activation='relu', kernel_initializer='he_normal'))
    model.add(Dense(units=1, activation='sigmoid'))

    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    preds = model.predict(test).flatten()  
    model_predictions.append(preds)

model_predictions = np.array(model_predictions)

final_probs = np.mean(model_predictions, axis=0)  

sub = pd.read_csv(Config.sub_link)
sub['rainfall'] = final_probs  
sub.to_csv('submissionDL.csv', index=False)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
train = pd.read_csv(Config.train_link, index_col = 'id')
test = pd.read_csv(Config.test_link, index_col = 'id')
original = pd.read_csv(Config.original)

original.columns = [col.strip() for col in original.columns]

rain_map = {'yes':1,
           'no':0}

original['rainfall'] = original['rainfall'].map(rain_map)

original.dropna(inplace = True)

#train = pd.concat([train, original], axis = 0, ignore_index = True)

train = train.fillna(0)

test.winddirection=test.winddirection.fillna(test.winddirection.median())

train['month']=((train["day"] - 1) // 30) + 1
train["season"] = train["month"].map({
        1: "Winter", 2: "Winter", 3: "Spring", 4: "Spring", 5: "Spring",
        6: "Summer", 7: "Summer", 8: "Summer", 9: "Fall", 10: "Fall",
        11: "Fall", 12: "Winter"
    })

def extract_features(day):
    base_date = pd.Timestamp('2023-01-01')
    date = base_date + pd.Timedelta(days=day - 1)
    month = date.month
    day_of_week = date.dayofweek
    is_weekend = 1 if day_of_week >= 5 else 0
    return month, day_of_week, is_weekend



def transform_features(df, is_train=True, train_mapping=None):
    df[['month', 'day_of_week', 'is_weekend']] = df['day'].apply(lambda x: pd.Series(extract_features(x)))
    # Temperature features
    df['temp_range'] = df['maxtemp'] - df['mintemp']
    df['avg_temp'] = (df['maxtemp'] + df['mintemp']) / 2
    df['temp_deviation'] = df['temparature'] - df['avg_temp']
    
    # Dew point depression
    df['dew_point_depression'] = df['temparature'] - df['dewpoint']
    
    # Wind direction - sine and cosine transformation
    df['wind_dir_rad'] = np.deg2rad(df['winddirection'])
    df['wind_dir_sin'] = np.sin(df['wind_dir_rad'])
    df['wind_dir_cos'] = np.cos(df['wind_dir_rad'])
    df.drop(columns=['wind_dir_rad'], inplace=True)
    
    # Wind chill factor (simplified version)
    df['wind_chill'] = 13.12 + 0.6215 * df['temparature'] - 11.37 * (df['windspeed']**0.16) + 0.3965 * df['temparature'] * (df['windspeed']**0.16)
    
    # Interaction features
    df['humidity_temp'] = df['humidity'] * df['temparature']
    df['cloud_sunshine'] = df['cloud'] * df['sunshine']
    
    # Rolling statistical features
    df['rolling_temp_mean'] = df['avg_temp'].rolling(window=7).mean()
    df['rolling_wind_mean'] = df['windspeed'].rolling(window=7).mean()
    df['rolling_humidity_mean'] = df['humidity'].rolling(window=7).mean()
    
    # Lag features
    df['temp_lag_1'] = df['avg_temp'].shift(1)
    df['humidity_lag_1'] = df['humidity'].shift(1)
    df['windspeed_lag_1'] = df['windspeed'].shift(1)
    
    # Pressure-Temperature interaction
    df['pressure_temp_interaction'] = df['pressure'] * df['avg_temp']
    # Wind-Speed-Temperature interaction
    df['windspeed_temp_interaction'] = df['windspeed'] * df['avg_temp']
    
    # Sunshine-Cloud interaction
    df['sunshine_cloud_interaction'] = df['sunshine'] * df['cloud']
    
    # Season feature
    df['season'] = df['month'].apply(lambda x: 'Spring' if 3 <= x <= 5 else
                                      'Summer' if 6 <= x <= 8 else
                                      'Autumn' if 9 <= x <= 11 else 'Winter')

    for c in ['pressure', 'maxtemp', 'temparature', 'humidity']:
        for gap in [1]:
            df[c+f"_shift{gap}"] = df[c].shift(gap)
            df[c+f"_diff{gap}"] = df[c].diff(gap)

    # Binary encoding for season
    df = pd.get_dummies(df, columns=['season'], drop_first=True)

    # Additional features from transform_features
    df["wind_x"] = df["windspeed"] * np.cos(np.radians(df["winddirection"]))
    df["wind_y"] = df["windspeed"] * np.sin(np.radians(df["winddirection"]))
    df["stability_index"] = df["maxtemp"] - df['mintemp']
    df["pressure_drop"] = df['pressure'].diff().fillna(0)
    df["dew_pressure"] = df["pressure"] / (df["dewpoint"] + 1)
    df["cloud_sun_ratio"] = df["cloud"] / (df["sunshine"] + 1)
    df['rain_day'] = df['day'].map(rainmap)

    df.drop(columns=["month", "day"], inplace=True)
    df.fillna(method="ffill", inplace=True)
    df.fillna(df.median(), inplace=True)
    #print(df.isna().sum())

    if is_train:
        X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['rainfall']),
                                                            df['rainfall'],
                                                            test_size=0.3,
                                                            random_state=SEED,
                                                            stratify=df['rainfall'])

        num_feats = list(X_train.columns)
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        return X_train, X_test, y_train, y_test, num_feats

    else:
        return df


X_train,X_test,y_train,y_test,num_feats=transform_features(train)
test=transform_features(test,False)

test_mean = test[num_feats].mean(axis =0)
test_std = test[num_feats].std(axis =0)

test[num_feats] -= test_mean
test[num_feats] /= test_std

# %%
import lightgbm as lgb
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier,VotingClassifier,ExtraTreesClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
import optuna

# %%
def objective_extra_trees(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', TREES_LOWER, TREES_UPPER),  
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 10, 30),  
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 8, 20), 
        'max_features': trial.suggest_uniform('max_features', 0.1, 0.7),  
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False])
    }

    model = ExtraTreesClassifier(**params, random_state=SEED)
    model.fit(X_train, y_train)

    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    roc_auc = auc(fpr, tpr)

    return roc_auc


study_extra_trees = optuna.create_study(direction='maximize')
study_extra_trees.optimize(objective_extra_trees, n_trials=TRIALS, show_progress_bar=True)

print("Best parameters for ExtraTreesClassifier:", study_extra_trees.best_params)
# Out:
# [I 2025-03-05 10:01:49,241] A new study created in memory with name: no-name-97ac9c9e-e82a-404b-aed5-c57b40cfb1c7
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03
 'bootstrap': False}. Best is trial 14 with value: 0.9370993889512408.
# [I 2025-03-05 10:02:03,022] Trial 97 finished with value: 0.9343683751091159 and parameters: {'n_estimators': 54, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 29, 'min_samples_leaf': 9, 'max_features': 0.5955035463478057, 'bootstrap': False}. Best is trial 14 with value: 0.9370993889512408.
# [I 2025-03-05 10:02:03,166] Trial 98 finished with value: 0.9350667165481981 and parameters: {'n_estimators': 51, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 28, 'min_samples_leaf': 12, 'max_features': 0.5733086414856686, 'bootstrap': False}. Best is trial 14 with value: 0.9370993889512408.
# [I 2025-03-05 10:02:03,374] Trial 99 finished with value: 0.9367626886145404 and parameters: {'n_estimators': 47, 'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 25, 'min_samples_leaf': 10, 'max_features': 0.6770613846632412, 'bootstrap': False}. Best is trial 14 with value: 0.9370993889512408.
# Best parameters for ExtraTreesClassifier: {'n_estimators': 48, 'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 11, 'max_features': 0.6202975287517906, 'bootstrap': False}

# %%
print("\n=== ExtraTreesClassifier Results ===")
extra_trees_model = ExtraTreesClassifier(**study_extra_trees.best_params, random_state=SEED)
extra_trees_model.fit(X_train, y_train)
y_proba_extra = extra_trees_model.predict_proba(X_test)[:, 1]

best_threshold_extra = 0.5
best_f1_extra = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (y_proba_extra >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1_extra:
        best_f1_extra = f1
        best_threshold_extra = t

extra_trees_pred = (y_proba_extra >= best_threshold_extra).astype(int)

print(f"Best weighted F1-score: {best_f1_extra:.4f} at threshold {best_threshold_extra:.2f}")
print(f"Best parameters: {study_extra_trees.best_params}")
# print("Classification Report:\n", classification_report(y_test, extra_trees_pred))

fpr, tpr, _ = roc_curve(y_train, extra_trees_model.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, extra_trees_model.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

submission.rainfall = extra_trees_model.predict_proba(test)[:, 1]
submission.to_csv('submission_extra_trees.csv', index=False)
# Out:
# === ExtraTreesClassifier Results ===
# Best weighted F1-score: 0.8911 at threshold 0.60
# Best parameters: {'n_estimators': 48, 'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 11, 'max_features': 0.6202975287517906, 'bootstrap': False}
# (0.9523099475480428, 0.9370993889512408)

# %%
def objective_lgbm(trial):
    params = {
        'objective': 'binary',
        'metric': 'binary_logloss',
        'verbosity': -1,
        'n_estimators': trial.suggest_int('n_estimators', TREES_LOWER, TREES_UPPER),
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart']),
        'num_leaves': trial.suggest_int('num_leaves', 10, 40),  
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 0.05),  
        'min_child_samples': trial.suggest_int('min_child_samples', 20, 120),  
        'subsample': trial.suggest_uniform('subsample', 0.6, 0.9),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 0.9),  
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-2, 2),  
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-2, 2), 
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.6, 0.9), 
        'bagging_freq': trial.suggest_int('bagging_freq', 5, 10),  
        'min_gain_to_split': trial.suggest_loguniform('min_gain_to_split', 1e-2, 0.5),  
        'extra_trees': trial.suggest_categorical('extra_trees', [True, False]),
        'max_depth': trial.suggest_int('max_depth', 3, 8)
    }
    
    model = lgb.LGBMClassifier(**params, random_state=SEED)

    model.fit(X_train, y_train)

    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    roc_auc = auc(fpr, tpr)
    
    return roc_auc

study_lgbm = optuna.create_study(direction='maximize')
study_lgbm.optimize(objective_lgbm, n_trials=TRIALS, show_progress_bar=True)

print("Best parameters for LightGBM:", study_lgbm.best_params)
# Out:
# [I 2025-03-05 10:02:03,600] A new study created in memory with name: no-name-138f537e-60dc-43d8-885f-4427222fd61b
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03-05 10:02:03,829] Trial 0 finished with value: 0.9240803092654946 and parameters: {'n_estimators': 59, 'boosting_type': 'dart', 'num_leaves': 24, 'learning_rate': 0.021244996559397187, 'min_child_samples': 24, 'subsample': 0.873684095574951, 'colsample_bytree': 0.7190506832903549, 'lambda_l1': 0.9226301860410131, 'lambda_l2': 0.1441863833588765, 'feature_fraction': 0.8894384308220955, 'bagging_freq': 5, 'min_gain_to_split': 0.03183489261255121, 'extra_trees': True, 'max_depth': 4}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:03,891] Trial 1 finished with value: 0.9224591594961965 and parameters: {'n_estimators': 51, 'boosting_type': 'gbdt', 'num_leaves': 17, 'learning_rate': 0.006570228826817527, 'min_child_samples': 44, 'subsample': 0.843192803295734, 'colsample_bytree': 0.7880795494640844, 'lambda_l1': 0.3887650035558468, 'lambda_l2': 0.10415533879635444, 'feature_fraction': 0.6191981676407432, 'bagging_freq': 5, 'min_gain_to_split': 0.1472449619726059, 'extra_trees': True, 'max_depth': 6}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:03,941] Trial 2 finished with value: 0.9205262501558797 and parameters: {'n_estimators': 43, 'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.0025775107382367103, 'min_child_samples': 42, 'subsample': 0.7898860597580286, 'colsample_bytree': 0.7893719052544322, 'lambda_l1': 0.010624709684414528, 'lambda_l2': 0.4373231770211973, 'feature_fraction': 0.6238539051944896, 'bagging_freq': 10, 'min_gain_to_split': 0.33938950050012573, 'extra_trees': False, 'max_depth': 6}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:03,978] Trial 3 finished with value: 0.9189362763436837 and parameters: {'n_estimators': 43, 'boosting_type': 'dart', 'num_leaves': 31, 'learning_rate': 0.004250654336546343, 'min_child_samples': 102, 'subsample': 0.6954015801446679, 'colsample_bytree': 0.8521933858839417, 'lambda_l1': 0.15609883686210216, 'lambda_l2': 0.20409853297192707, 'feature_fraction': 0.7500707347232349, 'bagging_freq': 8, 'min_gain_to_split': 0.05512751162084319, 'extra_trees': False, 'max_depth': 4}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:04,020] Trial 4 finished with value: 0.9137298915076694 and parameters: {'n_estimators': 58, 'boosting_type': 'gbdt', 'num_leaves': 30, 'learning_rate': 0.0014402146759402833, 'min_child_samples': 103, 'subsample': 0.8740879562028312, 'colsample_bytree': 0.6976281947828419, 'lambda_l1': 0.10225948221550148, 'lambda_l2': 0.01359057341031464, 'feature_fraction': 0.7590348251441574, 'bagging_freq': 9, 'min_gain_to_split': 0.026037503310361816, 'extra_trees': True, 'max_depth': 8}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:04,050] Trial 5 finished with value: 0.9221286943509164 and parameters: {'n_estimators': 38, 'boosting_type': 'gbdt', 'num_leaves': 34, 'learning_rate': 0.014327099383909674, 'min_child_samples': 67, 'subsample': 0.8186128832643731, 'colsample_bytree': 0.7113340570726077, 'lambda_l1': 0.0195226063153679, 'lambda_l2': 0.10560873464634123, 'feature_fraction': 0.6299587478898478, 'bagging_freq': 6, 'min_gain_to_split': 0.04604959948056235, 'extra_trees': False, 'max_depth': 3}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:04,074] Trial 6 finished with value: 0.9185808704327224 and parameters: {'n_estimators': 34, 'boosting_type': 'dart', 'num_leaves': 31, 'learning_rate': 0.049647317488820654, 'min_child_samples': 66, 'subsample': 0.7886045492485421, 'colsample_bytree': 0.6066668056462062, 'lambda_l1': 0.016143610660810357, 'lambda_l2': 1.8212943539388076, 'feature_fraction': 0.6789515430239732, 'bagging_freq': 8, 'min_gain_to_split': 0.24870855284256094, 'extra_trees': True, 'max_depth': 8}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:04,099] Trial 7 finished with value: 0.9124080309265494 and parameters: {'n_estimators': 46, 'boosting_type': 'dart', 'num_leaves': 17, 'learning_rate': 0.012919157969477593, 'min_child_samples': 92, 'subsample': 0.7803747520942385, 'colsample_bytree': 0.8695550917954031, 'lambda_l1': 0.13144163436735187, 'lambda_l2': 0.033649926490637555, 'feature_fraction': 0.8427620365853333, 'bagging_freq': 8, 'min_gain_to_split': 0.40190146104450625, 'extra_trees': True, 'max_depth': 4}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:04,130] Trial 8 finished with value: 0.9150018705574261 and parameters: {'n_estimators': 45, 'boosting_type': 'dart', 'num_leaves': 33, 'learning_rate': 0.0013755291022739071, 'min_child_samples': 61, 'subsample': 0.7905183018848935, 'colsample_bytree': 0.8897974842885461, 'lambda_l1': 0.6232337763378814, 'lambda_l2': 0.9358946393677577, 'feature_fraction': 0.8854478859762074, 'bagging_freq': 10, 'min_gain_to_split': 0.33203860223751563, 'extra_trees': True, 'max_depth': 7}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:04,158] Trial 9 finished with value: 0.9183189923930664 and parameters: {'n_estimators': 35, 'boosting_type': 'gbdt', 'num_leaves': 38, 'learning_rate': 0.00802120035903248, 'min_child_samples': 66, 'subsample': 0.6981622526734765, 'colsample_bytree': 0.8173209155617953, 'lambda_l1': 0.03163402608224216, 'lambda_l2': 1.392656352805522, 'feature_fraction': 0.7944083806936679, 'bagging_freq': 7, 'min_gain_to_split': 0.04629801391528504, 'extra_trees': False, 'max_depth': 5}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:04,244] Trial 10 finished with value: 0.9219728145654071 and parameters: {'n_estimators': 64, 'boosting_type': 'dart', 'num_leaves': 10, 'learning_rate': 0.04334654114430021, 'min_child_samples': 22, 'subsample': 0.6015281980277049, 'colsample_bytree': 0.6462379739045531, 'lambda_l1': 1.8370683130217291, 'lambda_l2': 0.044944234282332116, 'feature_fraction': 0.8985754535230627, 'bagging_freq': 5, 'min_gain_to_split': 0.010580548006395392, 'extra_trees': True, 'max_depth': 3}. Best is trial 0 with value: 0.9240803092654946.
# [I 2025-03-05 10:02:04,337] Trial 11 finished with value: 0.9270732011472752 and parameters: {'n_estimators': 54, 'boosting_type': 'gbdt', 'num_leaves': 22, 'learning_rate': 0.021290640502425573, 'min_child_samples': 23, 'subsample': 0.8992240713622525, 'colsample_bytree': 0.7536945008920641, 'lambda_l1': 0.5464941452685993, 'lambda_l2': 0.13656748846918748, 'feature_fraction': 0.6884867114013776, 'bagging_freq': 5, 'min_gain_to_split': 0.15901280071942742, 'extra_trees': True, 'max_depth': 6}. Best is trial 11 with value: 0.9270732011472752.
# [I 2025-03-05 10:02:04,418] Trial 12 finished with value: 0.9194413268487341 and parameters: {'n_estimators': 54, 'boosting_type': 'dart', 'num_leaves': 23, 'learning_rate': 0.022435460852381565, 'min_child_samples': 20, 'subsample': 0.883693577475085, 'colsample_bytree': 0.7288522564337407, 'lambda_l1': 1.9208942414767203, 'lambda_l2': 0.25288054100180696, 'feature_fraction': 0.6957060588035049, 'bagging_freq': 6, 'min_gain_to_split': 0.11464649427875648, 'extra_trees': True, 'max_depth': 5}. Best is trial 11 with value: 0.9270732011472752.
# [I 2025-03-05 10:02:04,513] Trial 13 finished with value: 0.924604065344806 and parameters: {'n_estimators': 60, 'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.024562221358468948, 'min_child_samples': 40, 'subsample': 0.8969335163894601, 'colsample_bytree': 0.6688089172521059, 'lambda_l1': 0.6282806214147364, 'lambda_l2': 0.05651876417370233, 'feature_fraction': 0.6903907105091682, 'bagging_freq': 6, 'min_gain_to_split': 0.02090310116978645, 'extra_trees': True, 'max_depth': 4}. Best is trial 11 with value: 0.9270732011472752.
# [I 2025-03-05 10:02:04,601] Trial 14 finished with value: 0.9251278214241176 and parameters: {'n_estimators': 63, 'boosting_type': 'gbdt', 'num_leaves': 17, 'learning_rate': 0.028808350469074685, 'min_child_samples': 41, 'subsample': 0.894556221304782, 'colsample_bytree': 0.655066682295338, 'lambda_l1': 0.44476387121510885, 'lambda_l2': 0.05195322050959961, 'feature_fraction': 0.689904310631653, 'bagging_freq': 6, 'min_gain_to_split': 0.011418608714131692, 'extra_trees': True, 'max_depth': 7}. Best is trial 11 with value: 0.9270732011472752.
# [I 2025-03-05 10:02:04,680] Trial 15 finished with value: 0.9279211871804464 and parameters: {'n_estimators': 64, 'boosting_type': 'gbdt', 'num_leaves': 11, 'learning_rate': 0.03142200090474302, 'min_child_samples': 38, 'subsample': 0.8453345440902139, 'colsample_bytree': 0.7584633714829614, 'lambda_l1': 0.26540810401931797, 'lambda_l2': 0.01744136900121371, 'feature_fraction': 0.6654949586436382, 'bagging_freq': 7, 'min_gain_to_split': 0.09678054417648892, 'extra_trees': True, 'max_depth': 7}. Best is trial 15 with value: 0.9279211871804464.
# [I 2025-03-05 10:02:04,765] Trial 16 finished with value: 0.9211497692979174 and parameters: {'n_estimators': 54, 'boosting_type': 'gbdt', 'num_leaves': 12, 'learning_rate': 0.0131294680315213, 'min_child_samples': 54, 'subsample': 0.8414455935255033, 'colsample_bytree': 0.7652563893773996, 'lambda_l1': 0.25437335452783305, 'lambda_l2': 0.013916189027208963, 'feature_fraction': 0.6668762044743969, 'bagging_freq': 7, 'min_gain_to_split': 0.0993725864345374, 'extra_trees': True, 'max_depth': 7}. Best is trial 15 with value: 0.9279211871804464.
# [I 2025-03-05 10:02:04,857] Trial 17 finished with value: 0.9202893128819054 and parameters: {'n_estimators': 50, 'boosting_type': 'gbdt', 'num_leaves': 14, 'learning_rate': 0.03623142895632562, 'min_child_samples': 83, 'subsample': 0.72900418003577, 'colsample_bytree': 0.7578976538028068, 'lambda_l1': 0.06302244891290813, 'lambda_l2': 0.021498924412406473, 'feature_fraction': 0.7292217351962358, 'bagging_freq': 7, 'min_gain_to_split': 0.18512232119888616, 'extra_trees': True, 'max_depth': 6}. Best is trial 15 with value: 0.9279211871804464.
# [I 2025-03-05 10:02:04,955] Trial 18 finished with value: 0.9271979049756828 and parameters: {'n_estimators': 55, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.008572276677365624, 'min_child_samples': 30, 'subsample': 0.8490330666190087, 'colsample_bytree': 0.8191881793528988, 'lambda_l1': 0.24099136820572362, 'lambda_l2': 0.5032267855756767, 'feature_fraction': 0.6519458674951124, 'bagging_freq': 9, 'min_gain_to_split': 0.0839273745919592, 'extra_trees': False, 'max_depth': 7}. Best is trial 15 with value: 0.9279211871804464.
# [I 2025-03-05 10:02:05,045] Trial 19 finished with value: 0.9191607432348173 and parameters: {'n_estimators': 57, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.003362280342294838, 'min_child_samples': 119, 'subsample': 0.7483007079387152, 'colsample_bytree': 0.8261819525333569, 'lambda_l1': 0.23089257523650994, 'lambda_l2': 0.5503268191510219, 'feature_fraction': 0.646763925622594, 'bagging_freq': 9, 'min_gain_to_split': 0.07860739851242222, 'extra_trees': False, 'max_depth': 8}. Best is trial 15 with value: 0.9279211871804464.
# [I 2025-03-05 10:02:05,141] Trial 20 finished with value: 0.9280708317745354 and parameters: {'n_estimators': 61, 'boosting_type': 'gbdt', 'num_leaves':
and parameters: {'n_estimators': 60, 'boosting_type': 'gbdt', 'num_leaves': 24, 'learning_rate': 0.001671391905087741, 'min_child_samples': 31, 'subsample': 0.8241381591846706, 'colsample_bytree': 0.8084742442756728, 'lambda_l1': 0.14266681223967986, 'lambda_l2': 0.016147454642711046, 'feature_fraction': 0.6139457641614776, 'bagging_freq': 9, 'min_gain_to_split': 0.03011354897123966, 'extra_trees': False, 'max_depth': 7}. Best is trial 72 with value: 0.9285696470881657.
# [I 2025-03-05 10:02:10,060] Trial 73 finished with value: 0.9282578875171468 and parameters: {'n_estimators': 60, 'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.0015807247660157531, 'min_child_samples': 22, 'subsample': 0.8127171103534976, 'colsample_bytree': 0.8444385935187078, 'lambda_l1': 0.7237655900089287, 'lambda_l2': 0.016153310571938022, 'feature_fraction': 0.6000389463218221, 'bagging_freq': 9, 'min_gain_to_split': 0.053622067222200274, 'extra_trees': False, 'max_depth': 7}. Best is trial 72 with value: 0.9285696470881657.
# [I 2025-03-05 10:02:10,173] Trial 74 finished with value: 0.9268487342561417 and parameters: {'n_estimators': 60, 'boosting_type': 'gbdt', 'num_leaves': 22, 'learning_rate': 0.0015640773860352698, 'min_child_samples': 23, 'subsample': 0.8603293231206837, 'colsample_bytree': 0.8483613270561909, 'lambda_l1': 0.05022240273993423, 'lambda_l2': 0.014910622372717728, 'feature_fraction': 0.6083981833777069, 'bagging_freq': 9, 'min_gain_to_split': 0.05260845549898795, 'extra_trees': False, 'max_depth': 7}. Best is trial 72 with value: 0.9285696470881657.
# [I 2025-03-05 10:02:10,266] Trial 75 finished with value: 0.9282578875171468 and parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.012256993359792107, 'min_child_samples': 31, 'subsample': 0.8125452660257546, 'colsample_bytree': 0.8264271008756574, 'lambda_l1': 0.7949635851315465, 'lambda_l2': 0.017376986965073803, 'feature_fraction': 0.6006193093271939, 'bagging_freq': 10, 'min_gain_to_split': 0.06610268873297043, 'extra_trees': False, 'max_depth': 7}. Best is trial 72 with value: 0.9285696470881657.
# [I 2025-03-05 10:02:10,363] Trial 76 finished with value: 0.9261067464771169 and parameters: {'n_estimators': 58, 'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.0018057325461852507, 'min_child_samples': 30, 'subsample': 0.8173091607522891, 'colsample_bytree': 0.835210242604123, 'lambda_l1': 1.1592545898150584, 'lambda_l2': 0.019600962120749597, 'feature_fraction': 0.6189859354356496, 'bagging_freq': 10, 'min_gain_to_split': 0.06675131324749739, 'extra_trees': False, 'max_depth': 6}. Best is trial 72 with value: 0.9285696470881657.
# [I 2025-03-05 10:02:10,471] Trial 77 finished with value: 0.9298915076692855 and parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 22, 'learning_rate': 0.012542694106485692, 'min_child_samples': 21, 'subsample': 0.8075705039530787, 'colsample_bytree': 0.8479149907614594, 'lambda_l1': 0.8247838002882223, 'lambda_l2': 0.011920436105919582, 'feature_fraction': 0.6252202257564299, 'bagging_freq': 10, 'min_gain_to_split': 0.03543270830061898, 'extra_trees': False, 'max_depth': 7}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:10,567] Trial 78 finished with value: 0.9281207133058984 and parameters: {'n_estimators': 55, 'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.012157132699122681, 'min_child_samples': 20, 'subsample': 0.8087529252221272, 'colsample_bytree': 0.803437324135704, 'lambda_l1': 0.7406074972759159, 'lambda_l2': 0.016244092525681795, 'feature_fraction': 0.6246701182078647, 'bagging_freq': 10, 'min_gain_to_split': 0.04369075303835138, 'extra_trees': False, 'max_depth': 7}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:10,667] Trial 79 finished with value: 0.9247412395560544 and parameters: {'n_estimators': 56, 'boosting_type': 'dart', 'num_leaves': 20, 'learning_rate': 0.012247424907638995, 'min_child_samples': 21, 'subsample': 0.8109634273703897, 'colsample_bytree': 0.7974992734316705, 'lambda_l1': 0.7903637700838557, 'lambda_l2': 0.01635541581702365, 'feature_fraction': 0.6254663304556436, 'bagging_freq': 10, 'min_gain_to_split': 0.044848636777409814, 'extra_trees': False, 'max_depth': 7}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:10,764] Trial 80 finished with value: 0.9231575009352789 and parameters: {'n_estimators': 53, 'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.015112007778613873, 'min_child_samples': 23, 'subsample': 0.7743376863617818, 'colsample_bytree': 0.7831215347367413, 'lambda_l1': 0.7486244264466452, 'lambda_l2': 0.025144568409705165, 'feature_fraction': 0.7053988587258635, 'bagging_freq': 10, 'min_gain_to_split': 0.057455203914666464, 'extra_trees': True, 'max_depth': 7}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:10,859] Trial 81 finished with value: 0.927335079186931 and parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 24, 'learning_rate': 0.010834073146275467, 'min_child_samples': 31, 'subsample': 0.8250121973083416, 'colsample_bytree': 0.8210959846033825, 'lambda_l1': 1.07276252788856, 'lambda_l2': 0.011875872474097254, 'feature_fraction': 0.6117087779737788, 'bagging_freq': 10, 'min_gain_to_split': 0.03493574231880246, 'extra_trees': False, 'max_depth': 7}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:10,955] Trial 82 finished with value: 0.9280084798603316 and parameters: {'n_estimators': 58, 'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.015075017141500132, 'min_child_samples': 20, 'subsample': 0.832367232955359, 'colsample_bytree': 0.7487058863107815, 'lambda_l1': 1.328587061755196, 'lambda_l2': 0.016213587531131397, 'feature_fraction': 0.6017464783853274, 'bagging_freq': 10, 'min_gain_to_split': 0.049402465006514046, 'extra_trees': False, 'max_depth': 7}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,046] Trial 83 finished with value: 0.9249906472128695 and parameters: {'n_estimators': 55, 'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.020481489040214833, 'min_child_samples': 20, 'subsample': 0.8455334625172561, 'colsample_bytree': 0.7466507749804714, 'lambda_l1': 1.505587172479209, 'lambda_l2': 0.016632221079636175, 'feature_fraction': 0.6866234818450663, 'bagging_freq': 10, 'min_gain_to_split': 0.051201145963168895, 'extra_trees': False, 'max_depth': 7}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,144] Trial 84 finished with value: 0.928395061728395 and parameters: {'n_estimators': 57, 'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.02281296161625365, 'min_child_samples': 24, 'subsample': 0.8078720756541199, 'colsample_bytree': 0.7697242091709887, 'lambda_l1': 1.4636950177092851, 'lambda_l2': 0.012429062592667343, 'feature_fraction': 0.618547710196663, 'bagging_freq': 10, 'min_gain_to_split': 0.04221912929092311, 'extra_trees': False, 'max_depth': 6}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,245] Trial 85 finished with value: 0.9281705948372616 and parameters: {'n_estimators': 57, 'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.02271387979346772, 'min_child_samples': 24, 'subsample': 0.7849970549601669, 'colsample_bytree': 0.7198953093323545, 'lambda_l1': 1.5494423314493624, 'lambda_l2': 0.012289795765549906, 'feature_fraction': 0.6157533737306669, 'bagging_freq': 10, 'min_gain_to_split': 0.029577942191373198, 'extra_trees': False, 'max_depth': 6}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,349] Trial 86 finished with value: 0.9273724903354532 and parameters: {'n_estimators': 57, 'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.023588679250383587, 'min_child_samples': 24, 'subsample': 0.7803839230456335, 'colsample_bytree': 0.8048826655055616, 'lambda_l1': 1.6915822926636261, 'lambda_l2': 0.012249758943235222, 'feature_fraction': 0.6386976806779311, 'bagging_freq': 10, 'min_gain_to_split': 0.02972621739028012, 'extra_trees': False, 'max_depth': 6}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,438] Trial 87 finished with value: 0.9269734380845491 and parameters: {'n_estimators': 55, 'boosting_type': 'gbdt', 'num_leaves': 22, 'learning_rate': 0.01277877046094897, 'min_child_samples': 27, 'subsample': 0.7865247732449403, 'colsample_bytree': 0.7208071771774203, 'lambda_l1': 0.9365228666219102, 'lambda_l2': 0.01001478987179808, 'feature_fraction': 0.6167482587942115, 'bagging_freq': 10, 'min_gain_to_split': 0.042510813691334734, 'extra_trees': False, 'max_depth': 5}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,543] Trial 88 finished with value: 0.9252649956353659 and parameters: {'n_estimators': 57, 'boosting_type': 'gbdt', 'num_leaves': 19, 'learning_rate': 0.027470796331511678, 'min_child_samples': 24, 'subsample': 0.8086328334017878, 'colsample_bytree': 0.8474600730683487, 'lambda_l1': 0.7509175771946147, 'lambda_l2': 0.01330280640383337, 'feature_fraction': 0.8253924080741025, 'bagging_freq': 10, 'min_gain_to_split': 0.03379001746391502, 'extra_trees': False, 'max_depth': 6}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,640] Trial 89 finished with value: 0.9266990896620527 and parameters: {'n_estimators': 53, 'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.02020928066669424, 'min_child_samples': 29, 'subsample': 0.8223282584604373, 'colsample_bytree': 0.827002547929372, 'lambda_l1': 0.975243476953986, 'lambda_l2': 0.0212197121949727, 'feature_fraction': 0.6464267691992992, 'bagging_freq': 10, 'min_gain_to_split': 0.07939984323743521, 'extra_trees': False, 'max_depth': 6}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,731] Trial 90 finished with value: 0.9250405287442325 and parameters: {'n_estimators': 50, 'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.03946620223493814, 'min_child_samples': 63, 'subsample': 0.7597266488156641, 'colsample_bytree': 0.7784666520966403, 'lambda_l1': 1.9761410490313467, 'lambda_l2': 0.03872260664730823, 'feature_fraction': 0.6225130477179012, 'bagging_freq': 10, 'min_gain_to_split': 0.06706721742825827, 'extra_trees': False, 'max_depth': 6}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,823] Trial 91 finished with value: 0.9273226088040903 and parameters: {'n_estimators': 58, 'boosting_type': 'gbdt', 'num_leaves': 19, 'learning_rate': 0.014079444405315597, 'min_child_samples': 20, 'subsample': 0.7904093762145502, 'colsample_bytree': 0.7688752269444626, 'lambda_l1': 1.3888784890573254, 'lambda_l2': 0.014593355867176328, 'feature_fraction': 0.6073832005469442, 'bagging_freq': 10, 'min_gain_to_split': 0.04952018172454492, 'extra_trees': False, 'max_depth': 6}. Best is trial 77 with value: 0.9298915076692855.
# [I 2025-03-05 10:02:11,938] Trial 92 finished with value: 0.9306397306397306 and parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.015307891886707344, 'min_child_samples': 23, 'subsample': 0.8035508306166289, 'colsample_bytree': 0.7574898383482888, 'lambda_l1': 1.3619522439892457, 'lambda_l2': 0.017550347017133452, 'feature_fraction': 0.6135693742068848, 'bagging_freq': 10, 'min_gain_to_split': 0.04155855954323302, 'extra_trees': False, 'max_depth': 5}. Best is trial 92 with value: 0.9306397306397306.
# [I 2025-03-05 10:02:12,043] Trial 93 finished with value: 0.931687242798354 and parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.016492297662071314, 'min_child_samples': 23, 'subsample': 0.8037280465914254, 'colsample_bytree': 0.7896410285639833, 'lambda_l1': 0.6886822491284842, 'lambda_l2': 0.03075640902321159, 'feature_fraction': 0.6255395520674955, 'bagging_freq': 10, 'min_gain_to_split': 0.04222690844794642, 'extra_trees': False, 'max_depth': 5}. Best is trial 93 with value: 0.931687242798354.
# [I 2025-03-05 10:02:12,159] Trial 94 finished with value: 0.9300286818805338 and parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.01811126374658268, 'min_child_samples': 23, 'subsample': 0.8022852795467227, 'colsample_bytree': 0.7584190858665836, 'lambda_l1': 0.8265361316025076, 'lambda_l2': 0.03201805976229715, 'feature_fraction': 0.6357124071397315, 'bagging_freq': 10, 'min_gain_to_split': 0.04278268208231067, 'extra_trees': False, 'max_depth': 5}. Best is trial 93 with value: 0.931687242798354.
# [I 2025-03-05 10:02:12,274] Trial 95 finished with value: 0.9297169223095149 and parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.01698544525743546, 'min_child_samples': 26, 'subsample': 0.8044994321854052, 'colsample_bytree': 0.7267061380103454, 'lambda_l1': 0.8373638644134613, 'lambda_l2': 0.031110360617318363, 'feature_fraction': 0.6357565662912992, 'bagging_freq': 10, 'min_gain_to_split': 0.02779952748199129, 'extra_trees': False, 'max_depth': 5}. Best is trial 93 with value: 0.931687242798354.
# [I 2025-03-05 10:02:12,384] Trial 96 finished with value: 0.9293802219728144 and parameters: {'n_estimators': 60, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.016345546851903134, 'min_child_samples': 26, 'subsample': 0.8035208572358024, 'colsample_bytree': 0.7547593904649131, 'lambda_l1': 0.843712110471332, 'lambda_l2': 0.031667467113044204, 'feature_fraction': 0.635905021998224, 'bagging_freq': 10, 'min_gain_to_split': 0.03890691284497417, 'extra_trees': False, 'max_depth': 5}. Best is trial 93 with value: 0.931687242798354.
# [I 2025-03-05 10:02:12,496] Trial 97 finished with value: 0.9258698092031425 and parameters: {'n_estimators': 60, 'boosting_type': 'dart', 'num_leaves': 20, 'learning_rate': 0.01682386949419628, 'min_child_samples': 26, 'subsample': 0.8022092298334234, 'colsample_bytree': 0.7309633326308437, 'lambda_l1': 0.6427027190684382, 'lambda_l2': 0.03023992094374835, 'feature_fraction': 0.770333858677315, 'bagging_freq': 10, 'min_gain_to_split': 0.0276024171214179, 'extra_trees': False, 'max_depth': 5}. Best is trial 93 with value: 0.931687242798354.
# [I 2025-03-05 10:02:12,604] Trial 98 finished with value: 0.9295298665669036 and parameters: {'n_estimators': 60, 'boosting_type': 'gbdt', 'num_leaves': 19, 'learning_rate': 0.018572767808905072, 'min_child_samples': 22, 'subsample': 0.7711444440423053, 'colsample_bytree': 0.7601391303546087, 'lambda_l1': 0.8803832158328501, 'lambda_l2': 0.03665527245187774, 'feature_fraction': 0.6519063006409408, 'bagging_freq': 10, 'min_gain_to_split': 0.03987996839856181, 'extra_trees': False, 'max_depth': 5}. Best is trial 93 with value: 0.931687242798354.
# [I 2025-03-05 10:02:12,700] Trial 99 finished with value: 0.9270108492330715 and parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 17, 'learning_rate': 0.018008131055782178, 'min_child_samples': 27, 'subsample': 0.7717434366075893, 'colsample_bytree': 0.7587281942959289, 'lambda_l1': 0.8985466072296732, 'lambda_l2': 0.03503420804330685, 'feature_fraction': 0.653263998594798, 'bagging_freq': 10, 'min_gain_to_split': 0.040005046708920404, 'extra_trees': False, 'max_depth': 5}. Best is trial 93 with value: 0.931687242798354.
# Best parameters for LightGBM: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.016492297662071314, 'min_child_samples': 23, 'subsample': 0.8037280465914254, 'colsample_bytree': 0.7896410285639833, 'lambda_l1': 0.6886822491284842, 'lambda_l2': 0.03075640902321159, 'feature_fraction': 0.6255395520674955, 'bagging_freq': 10, 'min_gain_to_split': 0.04222690844794642, 'extra_trees': False, 'max_depth': 5}

# %%
print("\n=== LightGBM Results ===")

lgbm_model = lgb.LGBMClassifier(**study_lgbm.best_params, random_state=SEED)
lgbm_model.fit(X_train, y_train)

y_proba = lgbm_model.predict_proba(X_test)[:, 1]

best_threshold = 0.5
best_f1 = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (y_proba >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = t

lgbm_pred = (y_proba >= best_threshold).astype(int)

print(f"Best weighted F1-score: {best_f1:.4f} at threshold {best_threshold:.2f}")
print(f"Best parameters: {study_lgbm.best_params}")
#print("Classification Report:\n", classification_report(y_test, lgbm_pred))

fpr, tpr, _ = roc_curve(y_train, lgbm_model.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, lgbm_model.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

submission.rainfall=lgbm_model.predict_proba(test)[:, 1]  
submission.to_csv('submission_lgbm.csv',index=False)
# Out:
# === LightGBM Results ===
# Best weighted F1-score: 0.8838 at threshold 0.60
# Best parameters: {'n_estimators': 59, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.016492297662071314, 'min_child_samples': 23, 'subsample': 0.8037280465914254, 'colsample_bytree': 0.7896410285639833, 'lambda_l1': 0.6886822491284842, 'lambda_l2': 0.03075640902321159, 'feature_fraction': 0.6255395520674955, 'bagging_freq': 10, 'min_gain_to_split': 0.04222690844794642, 'extra_trees': False, 'max_depth': 5}
# (0.9590370828466067, 0.931687242798354)

# %%
def objective_xgb(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', TREES_LOWER, TREES_UPPER),
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'use_label_encoder': False,
        'max_depth': trial.suggest_int('max_depth', 3, 8),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 0.05),
        'min_child_weight': trial.suggest_int('min_child_weight', 10, 30),
        'subsample': trial.suggest_uniform('subsample', 0.6, 0.9),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 0.9),
        'gamma': trial.suggest_loguniform('gamma', 0.05, 1.5),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.05, 1.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.05, 1.0),
        'max_leaves': trial.suggest_int('max_leaves', 20, 80),
        'grow_policy': trial.suggest_categorical('grow_policy', ['depthwise', 'lossguide'])
    }
    
    model = xgb.XGBClassifier(**params, random_state=SEED)

    model.fit(X_train, y_train)

    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    roc_auc = auc(fpr, tpr)
    
    return roc_auc

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgb, n_trials=TRIALS, show_progress_bar=True)

print("Best parameters for XGBoost:", study_xgb.best_params)
# Out:
# [I 2025-03-05 10:02:12,809] A new study created in memory with name: no-name-39ba382f-9da7-4145-b24d-79565bdd04cf
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03-05 10:02:12,893] Trial 0 finished with value: 0.9217421124828532 and parameters: {'n_estimators': 37, 'max_depth': 3, 'learning_rate': 0.020706342082573326, 'min_child_weight': 12, 'subsample': 0.6891324931434786, 'colsample_bytree': 0.8420931490807548, 'gamma': 0.7746381994244146, 'reg_alpha': 0.16090949269765917, 'reg_lambda': 0.8870231673180343, 'max_leaves': 37, 'grow_policy': 'lossguide'}. Best is trial 0 with value: 0
# [I 2025-03-05 10:02:22,103] Trial 95 finished with value: 0.9337573263499188 and parameters: {'n_estimators': 62, 'max_depth': 6, 'learning_rate': 0.047630621680383525, 'min_child_weight': 12, 'subsample': 0.8761045670264481, 'colsample_bytree': 0.7315784728093196, 'gamma': 0.28913159968344077, 'reg_alpha': 0.1186204824711962, 'reg_lambda': 0.20160908249462858, 'max_leaves': 54, 'grow_policy': 'lossguide'}. Best is trial 93 with value: 0.9343060231949121.
# [I 2025-03-05 10:02:22,227] Trial 96 finished with value: 0.9344806085546825 and parameters: {'n_estimators': 62, 'max_depth': 6, 'learning_rate': 0.04983345876271907, 'min_child_weight': 12, 'subsample': 0.8865994773068875, 'colsample_bytree': 0.7371378644563915, 'gamma': 0.37212171541308064, 'reg_alpha': 0.11094113891751262, 'reg_lambda': 0.20376979100289452, 'max_leaves': 55, 'grow_policy': 'lossguide'}. Best is trial 96 with value: 0.9344806085546825.
# [I 2025-03-05 10:02:22,367] Trial 97 finished with value: 0.9301284449432599 and parameters: {'n_estimators': 63, 'max_depth': 6, 'learning_rate': 0.037783088536481775, 'min_child_weight': 10, 'subsample': 0.8853915088354865, 'colsample_bytree': 0.7329083476050153, 'gamma': 0.34394590838221223, 'reg_alpha': 0.11131948982850771, 'reg_lambda': 0.18744833913726414, 'max_leaves': 53, 'grow_policy': 'lossguide'}. Best is trial 96 with value: 0.9344806085546825.
# [I 2025-03-05 10:02:22,494] Trial 98 finished with value: 0.9330215737623145 and parameters: {'n_estimators': 62, 'max_depth': 7, 'learning_rate': 0.04946982741974517, 'min_child_weight': 12, 'subsample': 0.8829116996855781, 'colsample_bytree': 0.6958314168984693, 'gamma': 0.29145966774369814, 'reg_alpha': 0.11793649539079232, 'reg_lambda': 0.22276765075105534, 'max_leaves': 51, 'grow_policy': 'lossguide'}. Best is trial 96 with value: 0.9344806085546825.
# [I 2025-03-05 10:02:22,625] Trial 99 finished with value: 0.9326349918942513 and parameters: {'n_estimators': 60, 'max_depth': 7, 'learning_rate': 0.04829504153420848, 'min_child_weight': 11, 'subsample': 0.8767909172470787, 'colsample_bytree': 0.6949463277620495, 'gamma': 0.2828223717265925, 'reg_alpha': 0.08413327056996203, 'reg_lambda': 0.16904483919822702, 'max_leaves': 49, 'grow_policy': 'lossguide'}. Best is trial 96 with value: 0.9344806085546825.
# Best parameters for XGBoost: {'n_estimators': 62, 'max_depth': 6, 'learning_rate': 0.04983345876271907, 'min_child_weight': 12, 'subsample': 0.8865994773068875, 'colsample_bytree': 0.7371378644563915, 'gamma': 0.37212171541308064, 'reg_alpha': 0.11094113891751262, 'reg_lambda': 0.20376979100289452, 'max_leaves': 55, 'grow_policy': 'lossguide'}

# %%
print("\n=== XGBoost Results ===")

xgb_model = xgb.XGBClassifier(**study_xgb.best_params, random_state=SEED)
xgb_model.fit(X_train, y_train)

y_proba = xgb_model.predict_proba(X_test)[:, 1]

best_threshold = 0.5
best_f1 = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (y_proba >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = t

xgb_pred = (y_proba >= best_threshold).astype(int)

print(f"Best weighted F1-score: {best_f1:.4f} at threshold {best_threshold:.2f}")
print(f"Best parameters: {study_xgb.best_params}")
#print("Classification Report:\n", classification_report(y_test, xgb_pred))

fpr, tpr, _ = roc_curve(y_train, xgb_model.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, xgb_model.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

submission.rainfall=xgb_model.predict_proba(test)[:, 1]  
submission.to_csv('submission_xgb.csv',index=False)
# Out:
# === XGBoost Results ===
# Best weighted F1-score: 0.8803 at threshold 0.45
# Best parameters: {'n_estimators': 62, 'max_depth': 6, 'learning_rate': 0.04983345876271907, 'min_child_weight': 12, 'subsample': 0.8865994773068875, 'colsample_bytree': 0.7371378644563915, 'gamma': 0.37212171541308064, 'reg_alpha': 0.11094113891751262, 'reg_lambda': 0.20376979100289452, 'max_leaves': 55, 'grow_policy': 'lossguide'}
# (0.9636409445933255, 0.9344806085546825)

# %%
def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', TREES_LOWER, TREES_UPPER),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 10, 40),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 5, 20),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2']),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced', 'balanced_subsample'])
    }
    
    model = RandomForestClassifier(**params, random_state=SEED)

    model.fit(X_train, y_train)

    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    roc_auc = auc(fpr, tpr)

    return roc_auc

study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective_rf, n_trials=TRIALS, show_progress_bar=True)

print("Best parameters for Random Forest:", study_rf.best_params)
# Out:
# [I 2025-03-05 10:02:22,810] A new study created in memory with name: no-name-9a91e650-ca76-4fe4-902b-fd73955363f4
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03-05 10:02:23,182] Trial 0 finished with value: 0.9201271979049757 and parameters: {'n_estimators': 60, 'max_depth': 16, 'min_samples_split': 23, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:23,499] Trial 1 finished with value: 0.9190173338321487 and parameters: {'n_estimators': 45, 'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:23,695] Trial 2 finished with value: 0.9190796857463525 and parameters: {'n_estimators': 33, 'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:23,926] Trial 3 finished with value: 0.9176081805711436 and parameters: {'n_estimators': 52, 'max_depth': 13, 'min_samples_split': 23, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:24,120] Trial 4 finished with value: 0.9143035291183439 and parameters: {'n_estimators': 42, 'max_depth': 14, 'min_samples_split': 21, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:24,365] Trial 5 finished with value: 0.9196283825913455 and parameters: {'n_estimators': 46, 'max_depth': 11, 'min_samples_split': 32, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:24,543] Trial 6 finished with value: 0.9168724279835391 and parameters: {'n_estimators': 38, 'max_depth': 9, 'min_samples_split': 16, 'min_samples_leaf': 17, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:24,757] Trial 7 finished with value: 0.9151889263000375 and parameters: {'n_estimators': 48, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:24,882] Trial 8 finished with value: 0.9179573512906846 and parameters: {'n_estimators': 35, 'max_depth': 6, 'min_samples_split': 30, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:25,132] Trial 9 finished with value: 0.9152388078314005 and parameters: {'n_estimators': 37, 'max_depth': 13, 'min_samples_split': 28, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:25,407] Trial 10 finished with value: 0.9171966579373987 and parameters: {'n_estimators': 63, 'max_depth': 19, 'min_samples_split': 40, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True, 'class_weight': None}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:25,681] Trial 11 finished with value: 0.9176206509539842 and parameters: {'n_estimators': 55, 'max_depth': 18, 'min_samples_split': 34, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 0 with value: 0.9201271979049757.
# [I 2025-03-05 10:02:26,131] Trial 12 finished with value: 0.920663424367128 and parameters: {'n_estimators': 64, 'max_depth': 10, 'min_samples_split': 34, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.920663424367128.
# [I 2025-03-05 10:02:26,574] Trial 13 finished with value: 0.920064845990772 and parameters: {'n_estimators': 63, 'max_depth': 17, 'min_samples_split': 39, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.920663424367128.
# [I 2025-03-05 10:02:26,986] Trial 14 finished with value: 0.9223843371991519 and parameters: {'n_estimators': 58, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 14 with value: 0
 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:48,140] Trial 81 finished with value: 0.9224841002618779 and parameters: {'n_estimators': 58, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:48,464] Trial 82 finished with value: 0.9224841002618779 and parameters: {'n_estimators': 58, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:48,840] Trial 83 finished with value: 0.9224841002618779 and parameters: {'n_estimators': 58, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:49,132] Trial 84 finished with value: 0.9218481107369997 and parameters: {'n_estimators': 56, 'max_depth': 9, 'min_samples_split': 13, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:49,415] Trial 85 finished with value: 0.9202519017333831 and parameters: {'n_estimators': 57, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:49,681] Trial 86 finished with value: 0.9207756578126948 and parameters: {'n_estimators': 52, 'max_depth': 9, 'min_samples_split': 16, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:49,981] Trial 87 finished with value: 0.9176081805711436 and parameters: {'n_estimators': 55, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:50,281] Trial 88 finished with value: 0.9207881281955356 and parameters: {'n_estimators': 58, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 75 with value: 0.9227958598328969.
# [I 2025-03-05 10:02:50,549] Trial 89 finished with value: 0.9245167726649208 and parameters: {'n_estimators': 54, 'max_depth': 7, 'min_samples_split': 33, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:50,790] Trial 90 finished with value: 0.9225090410275596 and parameters: {'n_estimators': 49, 'max_depth': 7, 'min_samples_split': 31, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:51,041] Trial 91 finished with value: 0.9227584486843746 and parameters: {'n_estimators': 50, 'max_depth': 7, 'min_samples_split': 31, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:51,273] Trial 92 finished with value: 0.9208130689612172 and parameters: {'n_estimators': 49, 'max_depth': 7, 'min_samples_split': 31, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:51,490] Trial 93 finished with value: 0.9233196159122086 and parameters: {'n_estimators': 46, 'max_depth': 7, 'min_samples_split': 33, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:51,707] Trial 94 finished with value: 0.9205387205387204 and parameters: {'n_estimators': 44, 'max_depth': 7, 'min_samples_split': 36, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:51,924] Trial 95 finished with value: 0.9221598703080184 and parameters: {'n_estimators': 46, 'max_depth': 7, 'min_samples_split': 33, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:52,132] Trial 96 finished with value: 0.9199775533108867 and parameters: {'n_estimators': 46, 'max_depth': 6, 'min_samples_split': 35, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:52,357] Trial 97 finished with value: 0.9161366753959347 and parameters: {'n_estimators': 50, 'max_depth': 6, 'min_samples_split': 31, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:52,590] Trial 98 finished with value: 0.9221972814565408 and parameters: {'n_estimators': 47, 'max_depth': 7, 'min_samples_split': 30, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# [I 2025-03-05 10:02:52,869] Trial 99 finished with value: 0.9225215114104003 and parameters: {'n_estimators': 52, 'max_depth': 8, 'min_samples_split': 33, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 89 with value: 0.9245167726649208.
# Best parameters for Random Forest: {'n_estimators': 54, 'max_depth': 7, 'min_samples_split': 33, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}

# %%
print("\n=== Random Forest Results ===")

rf_model = RandomForestClassifier(**study_rf.best_params, random_state=SEED)
rf_model.fit(X_train, y_train)

y_proba = rf_model.predict_proba(X_test)[:, 1]

best_threshold = 0.5
best_f1 = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (y_proba >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = t

rf_pred = (y_proba >= best_threshold).astype(int)

print(f"Best weighted F1-score: {best_f1:.4f} at threshold {best_threshold:.2f}")
print(f"Best parameters: {study_rf.best_params}")
#print("Classification Report:\n", classification_report(y_test, rf_pred))

fpr, tpr, _ = roc_curve(y_train, rf_model.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, rf_model.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

submission.rainfall=rf_model.predict_proba(test)[:, 1]  
submission.to_csv('submission_rf.csv',index=False)
# Out:
# === Random Forest Results ===
# Best weighted F1-score: 0.8822 at threshold 0.55
# Best parameters: {'n_estimators': 54, 'max_depth': 7, 'min_samples_split': 33, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}
# (0.9681050871527062, 0.9245167726649208)

# %%
print("\n=== Voting Classifier Results ===")

voting_soft = VotingClassifier(
    estimators=[
        ('lgbm', lgbm_model),
        ('xgb', xgb_model),
        ('rf', rf_model),
        ('ef', extra_trees_model)
    ],
    voting='soft'
)

voting_hard = VotingClassifier(
    estimators=[
        ('lgbm', lgbm_model),
        ('xgb', xgb_model),
        ('rf', rf_model),
        ('ef', extra_trees_model)
    ],
    voting='hard'
)

# Soft Voting
voting_soft.fit(X_train, y_train)
soft_proba = voting_soft.predict_proba(X_test)[:, 1]

best_threshold_soft = 0.5
best_f1_soft = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (soft_proba >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1_soft:
        best_f1_soft = f1
        best_threshold_soft = t

soft_pred = (soft_proba >= best_threshold_soft).astype(int)

print("\nSoft Voting:")
print(f"Best weighted F1-score: {best_f1_soft:.4f} at threshold {best_threshold_soft:.2f}")
#print("Classification Report:\n", classification_report(y_test, soft_pred))

fpr, tpr, _ = roc_curve(y_train, voting_soft.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, voting_soft.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

# Hard Voting
voting_hard.fit(X_train, y_train)
hard_pred = voting_hard.predict(X_test)

print("\nHard Voting:")
print(f"Weighted F1-score: {f1_score(y_test, hard_pred, average='weighted'):.4f}")
#print("Classification Report:\n", classification_report(y_test, hard_pred))


fpr, tpr, _ = roc_curve(y_train, np.mean([clf.predict_proba(X_train)[:, 1] for clf in voting_hard.estimators_], axis=0))
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, np.mean([clf.predict_proba(X_test)[:, 1] for clf in voting_hard.estimators_], axis=0))
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))
# Out:
# === Voting Classifier Results ===
#
# Soft Voting:
# Best weighted F1-score: 0.8847 at threshold 0.55
# (0.9636432350718065, 0.9347300162114976)
#
# Hard Voting:
# Weighted F1-score: 0.8839
# (0.9636432350718065, 0.9347300162114976)

# %%
soft_probabilities = voting_soft.predict_proba(test)[:, 1]  

hard_probabilities = np.mean([clf.predict_proba(test)[:, 1] for clf in voting_hard.estimators_], axis=0)

print("Soft Probabilities Shape:", soft_probabilities.shape)
print("Hard Probabilities Shape:", hard_probabilities.shape)
# Out:
# Soft Probabilities Shape: (730,)
# Hard Probabilities Shape: (730,)

# %%
submission.rainfall=soft_probabilities
submission.to_csv('submission_soft.csv',index=False)

# %%
submission.rainfall=hard_probabilities
submission.to_csv('submission_hard.csv',index=False)

# %%
submission.rainfall=(lgbm_model.predict_proba(test)[:, 1]+xgb_model.predict_proba(test)[:, 1]+rf_model.predict_proba(test)[:, 1]+soft_probabilities+hard_probabilities+extra_trees_model.predict_proba(test)[:, 1])/6
submission.to_csv('submission.csv',index=False)
