# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import auc,roc_auc_score,classification_report,roc_curve,auc,f1_score
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import optuna
import warnings
from collections import Counter
warnings.simplefilter('ignore')


SEED=95
TRIALS=100
TREES_LOWER=32
TREES_UPPER=64


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
class Config:
    train_link = "train.csv"
    test_link = "test.csv"
    sub_link  = "sample_submission.csv"
    original = "Rainfall.csv"

# %%
train = pd.read_csv(Config.train_link, index_col = 'id')
test = pd.read_csv(Config.test_link, index_col = 'id')
original = pd.read_csv(Config.original)

original.columns = [col.strip() for col in original.columns]

rain_map = {'yes':1,
           'no':0}

original['rainfall'] = original['rainfall'].map(rain_map)

original.dropna(inplace = True)

#train = pd.concat([train, original], axis = 0, ignore_index = True)

train = train.fillna(0)

test.winddirection=test.winddirection.fillna(test.winddirection.median())

# %%
train.describe()
# Out:
#                day     pressure      maxtemp  temparature      mintemp  \
# count  2190.000000  2190.000000  2190.000000  2190.000000  2190.000000
# mean    179.948402  1013.602146    26.365799    23.953059    22.170091
# std     105.203592     5.655366     5.654330     5.222410     5.059120
# min       1.000000   999.000000    10.400000     7.400000     4.000000
# 25%      89.000000  1008.600000    21.300000    19.300000    17.700000
# 50%     178.500000  1013.000000    27.800000    25.500000    23.850000
# 75%     270.000000  1017.775000    31.200000    28.400000    26.400000
# max     365.000000  1034.600000    36.000000    31.500000    29.800000
#
#           dewpoint     humidity        cloud     sunshine  winddirection  \
# count  2190.000000  2190.000000  2190.000000  2190.000000    2190.000000
# mean     20.454566    82.036530    75.721918     3.744429     104.863151
# std       5.288406     7.800654    18.026498     3.626327      80.002416
# min      -0.300000    39.000000     2.000000     0.000000      10.000000
# 25%      16.800000    77.000000    69.000000     0.400000      40.000000
# 50%      22.150000    82.000000    83.000000     2.400000      70.000000
# 75%      25.000000    88.000000    88.000000     6.800000     200.000000
# max      26.700000    98.000000   100.000000    12.100000     300.000000
#
#          windspeed     rainfall
# count  2190.000000  2190.000000
# mean     21.804703     0.753425
# std       9.898659     0.431116
# min       4.400000     0.000000
# 25%      14.125000     1.000000
# 50%      20.500000     1.000000
# 75%      27.900000     1.000000
# max      59.500000     1.000000

# %%
train['month']=((train["day"] - 1) // 30) + 1
train["season"] = train["month"].map({
        1: "Winter", 2: "Winter", 3: "Spring", 4: "Spring", 5: "Spring",
        6: "Summer", 7: "Summer", 8: "Summer", 9: "Fall", 10: "Fall",
        11: "Fall", 12: "Winter"
    })

# %%
rainmap=train.groupby('day')['rainfall'].mean().to_dict()
season_weights = train.groupby('season')['rainfall'].mean().to_dict()

# %%
num_feats=[]

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

def transform_features(df, is_train=True, train_mapping=None):
    '''
    df["wind_x"] = df["windspeed"] * np.cos(np.radians(df["winddirection"]))
    df["wind_y"] = df["windspeed"] * np.sin(np.radians(df["winddirection"]))
    df["stability_index"] = df["maxtemp"] - df["mintemp"]
    df["pressure_drop"] = df["pressure"].diff().fillna(0)
    '''
    df["month"] = ((df["day"] - 1) // 30) + 1
    df["season"] = df["month"].map({
        1: "Winter", 2: "Winter", 3: "Spring", 4: "Spring", 5: "Spring",
        6: "Summer", 7: "Summer", 8: "Summer", 9: "Fall", 10: "Fall",
        11: "Fall", 12: "Winter"
    }).map(season_weights)

    #df["dew_point_depression"] = df["temparature"] - df["dewpoint"]
    #df["dew_pressure"] = df["pressure"] / (df["dewpoint"] + 1)
    #df["cloud_sun_ratio"] = df["cloud"] / (df["sunshine"] + 1)
    #df['rain_day']=df['day'].map(rainmap)
    
    df.drop(columns=["month", 'day'], inplace=True)
    df.fillna(method="ffill", inplace=True)
    df.fillna(df.median(), inplace=True)

    if is_train:
        X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['rainfall']), 
                                                            df['rainfall'], 
                                                            test_size=0.2, 
                                                            random_state=SEED,
                                                            stratify=df['rainfall'])

        num_feats=list(X_train.columns)
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        return X_train, X_test, y_train, y_test,num_feats

    else:
        df.fillna(method="ffill", inplace=True)
        df.fillna(df.median(), inplace=True)
        return df

# %%
X_train,X_test,y_train,y_test,num_feats=transform_features(train)
test=transform_features(test,False)

# %%
num_feats
# Out:
# ['pressure',
#  'maxtemp',
#  'temparature',
#  'mintemp',
#  'dewpoint',
#  'humidity',
#  'cloud',
#  'sunshine',
#  'winddirection',
#  'windspeed',
#  'season']

# %%
test.head()
# Out:
#       pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# id
# 2190    1019.5     17.5         15.8     12.7      14.9      96.0   99.0
# 2191    1016.5     17.5         16.5     15.8      15.1      97.0   99.0
# 2192    1023.9     11.2         10.4      9.4       8.9      86.0   96.0
# 2193    1022.9     20.6         17.3     15.2       9.5      75.0   45.0
# 2194    1022.2     16.1         13.8      6.4       4.3      68.0   49.0
#
#       sunshine  winddirection  windspeed    season
# id
# 2190       0.0           50.0       24.3  0.729779
# 2191       0.0           50.0       35.3  0.729779
# 2192       0.0           40.0       16.9  0.729779
# 2193       7.1           20.0       50.6  0.729779
# 2194       9.2           20.0       19.4  0.729779

# %%
test.isna().sum().sum()
# Out:
# 0

# %%
test_mean = test[num_feats].mean(axis =0)
test_std = test[num_feats].std(axis =0)

test[num_feats] -= test_mean
test[num_feats] /= test_std

# %%
X_train
# Out:
# array([[-0.27405669,  0.24695983,  0.28717666, ..., -0.4311077 ,
#          0.36833592,  1.5309898 ],
#        [-0.04302011, -1.31273536, -1.47156354, ..., -0.80452413,
#          1.15737724, -0.41479973],
#        [-1.00271049,  1.20404552,  1.16654676, ...,  0.56466944,
#         -1.24009448,  1.5309898 ],
#        ...,
#        [-0.36291691,  0.72550267,  0.65039475, ..., -0.68005198,
#          0.72239292,  0.00745489],
#        [ 0.95221436, -0.85191632, -1.14657893, ..., -0.68005198,
#         -0.88603747, -0.41479973],
#        [-0.96716641,  0.42419792,  0.32541015, ...,  1.68491871,
#         -0.57244412,  1.5309898 ]])

# %%
submission=pd.read_csv('sample_submission.csv')

# %%
import optuna
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

def create_model(trial):
    model = Sequential()
    model.add(Dense(units=trial.suggest_int('units_1', 64, 256, log=True),
                    activation='relu', kernel_initializer='he_normal', input_shape=(X_train.shape[1],)))
    model.add(Dropout(rate=trial.suggest_uniform('dropout_1', 0.2, 0.5)))
    model.add(Dense(units=trial.suggest_int('units_2', 32, 128, log=True),
                    activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(rate=trial.suggest_uniform('dropout_2', 0.2, 0.5)))
    model.add(Dense(units=16, activation='relu', kernel_initializer='he_normal'))
    model.add(Dense(units=1, activation='sigmoid'))
    
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    
    return model


early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %%
'''
def objective(trial):
    model = create_model(trial)
    model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)
    score = model.evaluate(X_test, y_test, verbose=1)
    return score[1]
    
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, show_progress_bar=True)

print('Best trial:')
best_trial = study.best_trial
print(f'  Value: {best_trial.value}')
print('  Params: ')
for key, value in best_trial.params.items():
    print(f'    {key}: {value}')'''
# Out:
# "\ndef objective(trial):\n    model = create_model(trial)\n    model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)\n    score = model.evaluate(X_test, y_test, verbose=1)\n    return score[1]\n    \nstudy = optuna.create_study(direction='maximize')\nstudy.optimize(objective, n_trials=100, show_progress_bar=True)\n\nprint('Best trial:')\nbest_trial = study.best_trial\nprint(f'  Value: {best_trial.value}')\nprint('  Params: ')\nfor key, value in best_trial.params.items():\n    print(f'    {key}: {value}')"

# %%
'''
df_study = pd.DataFrame([
    {**t.params, "AUC": t.value, "Trial Number": t.number} 
    for t in study.trials
])

df_study = df_study.sort_values(by="AUC", ascending=False).reset_index(drop=True)

print(df_study.head(5))

top_model_params = [
    trial.params for trial in sorted(study.trials, key=lambda t: t.value, reverse=True)[:5]
]

print(top_model_params)'''
# Out:
# '\ndf_study = pd.DataFrame([\n    {**t.params, "AUC": t.value, "Trial Number": t.number} \n    for t in study.trials\n])\n\ndf_study = df_study.sort_values(by="AUC", ascending=False).reset_index(drop=True)\n\nprint(df_study.head(5))\n\ntop_model_params = [\n    trial.params for trial in sorted(study.trials, key=lambda t: t.value, reverse=True)[:5]\n]\n\nprint(top_model_params)'

# %%
top_model_params=[{'units_1': 92, 'dropout_1': 0.36537034589997436, 'units_2': 66, 'dropout_2': 0.31031514284970424}, {'units_1': 115, 'dropout_1': 0.35976665986533063, 'units_2': 61, 'dropout_2': 0.21245866054640758}, {'units_1': 235, 'dropout_1': 0.42604377318637393, 'units_2': 69, 'dropout_2': 0.2333035285439651}, {'units_1': 118, 'dropout_1': 0.4158563273591014, 'units_2': 51, 'dropout_2': 0.3560913945173838}, {'units_1': 203, 'dropout_1': 0.32328676753873037, 'units_2': 64, 'dropout_2': 0.20090305793683494}]

# %%
'''
model_predictions = []

for params in top_model_params[:3]:
    model = Sequential()
    model.add(Dense(units=params['units_1'], activation='relu', kernel_initializer='he_normal', 
                    input_shape=(X_train.shape[1],)))
    model.add(Dropout(rate=params['dropout_1']))
    model.add(Dense(units=params['units_2'], activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(rate=params['dropout_2']))
    model.add(Dense(units=16, activation='relu', kernel_initializer='he_normal'))
    model.add(Dense(units=1, activation='sigmoid'))

    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    preds = model.predict(test).flatten()  
    model_predictions.append(preds)

model_predictions = np.array(model_predictions)

final_probs = np.mean(model_predictions, axis=0)  

sub = pd.read_csv(Config.sub_link)
sub['rainfall'] = final_probs  
sub.to_csv('submissionDL.csv', index=False)'''
# Out:
# "\nmodel_predictions = []\n\nfor params in top_model_params[:3]:\n    model = Sequential()\n    model.add(Dense(units=params['units_1'], activation='relu', kernel_initializer='he_normal', \n                    input_shape=(X_train.shape[1],)))\n    model.add(Dropout(rate=params['dropout_1']))\n    model.add(Dense(units=params['units_2'], activation='relu', kernel_initializer='he_normal'))\n    model.add(Dropout(rate=params['dropout_2']))\n    model.add(Dense(units=16, activation='relu', kernel_initializer='he_normal'))\n    model.add(Dense(units=1, activation='sigmoid'))\n\n    optimizer = Adam(learning_rate=0.001)\n    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])\n\n    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)\n    model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)\n\n    preds = model.predict(test).flatten()  \n    model_predictions.append(preds)\n\nmodel_predictions = np.array(model_predictions)\n\nfinal_probs = np.mean(model_predictions, axis=0)  \n\nsub = pd.read_csv(Config.sub_link)\nsub['rainfall'] = final_probs  \nsub.to_csv('submissionDL.csv', index=False)"

# %%
train = pd.read_csv(Config.train_link, index_col = 'id')
test = pd.read_csv(Config.test_link, index_col = 'id')
original = pd.read_csv(Config.original)

original.columns = [col.strip() for col in original.columns]

rain_map = {'yes':1,
           'no':0}

original['rainfall'] = original['rainfall'].map(rain_map)

original.dropna(inplace = True)

#train = pd.concat([train, original], axis = 0, ignore_index = True)

train = train.fillna(0)

test.winddirection=test.winddirection.fillna(test.winddirection.median())

train['month']=((train["day"] - 1) // 30) + 1
train["season"] = train["month"].map({
        1: "Winter", 2: "Winter", 3: "Spring", 4: "Spring", 5: "Spring",
        6: "Summer", 7: "Summer", 8: "Summer", 9: "Fall", 10: "Fall",
        11: "Fall", 12: "Winter"
    })

def extract_features(day):
    base_date = pd.Timestamp('2023-01-01')
    date = base_date + pd.Timedelta(days=day - 1)
    month = date.month
    day_of_week = date.dayofweek
    is_weekend = 1 if day_of_week >= 5 else 0
    return month, day_of_week, is_weekend



def transform_features(df, is_train=True, train_mapping=None):
    df[['month', 'day_of_week', 'is_weekend']] = df['day'].apply(lambda x: pd.Series(extract_features(x)))
    # Temperature features
    df['temp_range'] = df['maxtemp'] - df['mintemp']
    df['avg_temp'] = (df['maxtemp'] + df['mintemp']) / 2
    df['temp_deviation'] = df['temparature'] - df['avg_temp']
    
    # Dew point depression
    df['dew_point_depression'] = df['temparature'] - df['dewpoint']
    
    # Wind direction - sine and cosine transformation
    df['wind_dir_rad'] = np.deg2rad(df['winddirection'])
    df['wind_dir_sin'] = np.sin(df['wind_dir_rad'])
    df['wind_dir_cos'] = np.cos(df['wind_dir_rad'])
    df.drop(columns=['wind_dir_rad'], inplace=True)
    
    # Wind chill factor (simplified version)
    df['wind_chill'] = 13.12 + 0.6215 * df['temparature'] - 11.37 * (df['windspeed']**0.16) + 0.3965 * df['temparature'] * (df['windspeed']**0.16)
    
    # Interaction features
    df['humidity_temp'] = df['humidity'] * df['temparature']
    df['cloud_sunshine'] = df['cloud'] * df['sunshine']
    
    # Rolling statistical features
    df['rolling_temp_mean'] = df['avg_temp'].rolling(window=7).mean()
    df['rolling_wind_mean'] = df['windspeed'].rolling(window=7).mean()
    df['rolling_humidity_mean'] = df['humidity'].rolling(window=7).mean()
    
    # Lag features
    df['temp_lag_1'] = df['avg_temp'].shift(1)
    df['humidity_lag_1'] = df['humidity'].shift(1)
    df['windspeed_lag_1'] = df['windspeed'].shift(1)
    
    # Pressure-Temperature interaction
    df['pressure_temp_interaction'] = df['pressure'] * df['avg_temp']
    # Wind-Speed-Temperature interaction
    df['windspeed_temp_interaction'] = df['windspeed'] * df['avg_temp']
    
    # Sunshine-Cloud interaction
    df['sunshine_cloud_interaction'] = df['sunshine'] * df['cloud']
    
    # Season feature
    df['season'] = df['month'].apply(lambda x: 'Spring' if 3 <= x <= 5 else
                                      'Summer' if 6 <= x <= 8 else
                                      'Autumn' if 9 <= x <= 11 else 'Winter')

    for c in ['pressure', 'maxtemp', 'temparature', 'humidity']:
        for gap in [1]:
            df[c+f"_shift{gap}"] = df[c].shift(gap)
            df[c+f"_diff{gap}"] = df[c].diff(gap)

    # Binary encoding for season
    df = pd.get_dummies(df, columns=['season'], drop_first=True)

    # Additional features from transform_features
    df["wind_x"] = df["windspeed"] * np.cos(np.radians(df["winddirection"]))
    df["wind_y"] = df["windspeed"] * np.sin(np.radians(df["winddirection"]))
    df["stability_index"] = df["maxtemp"] - df['mintemp']
    df["pressure_drop"] = df['pressure'].diff().fillna(0)
    df["dew_pressure"] = df["pressure"] / (df["dewpoint"] + 1)
    df["cloud_sun_ratio"] = df["cloud"] / (df["sunshine"] + 1)
    df['rain_day'] = df['day'].map(rainmap)

    df.drop(columns=["month", "day"], inplace=True)
    df.fillna(method="ffill", inplace=True)
    df.fillna(df.median(), inplace=True)
    #print(df.isna().sum())

    if is_train:
        X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['rainfall']),
                                                            df['rainfall'],
                                                            test_size=0.3,
                                                            random_state=SEED,
                                                            stratify=df['rainfall'])

        num_feats = list(X_train.columns)
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        return X_train, X_test, y_train, y_test, num_feats

    else:
        return df


X_train,X_test,y_train,y_test,num_feats=transform_features(train)
test=transform_features(test,False)

test_mean = test[num_feats].mean(axis =0)
test_std = test[num_feats].std(axis =0)

test[num_feats] -= test_mean
test[num_feats] /= test_std

# %%
import lightgbm as lgb
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier,VotingClassifier,ExtraTreesClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
import optuna

# %%
def objective_extra_trees(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', TREES_LOWER, TREES_UPPER),  
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 10, 30),  
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 8, 20), 
        'max_features': trial.suggest_uniform('max_features', 0.1, 0.7),  
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False])
    }

    model = ExtraTreesClassifier(**params, random_state=SEED)
    model.fit(X_train, y_train)

    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    roc_auc = auc(fpr, tpr)

    return roc_auc


study_extra_trees = optuna.create_study(direction='maximize')
study_extra_trees.optimize(objective_extra_trees, n_trials=TRIALS, show_progress_bar=True)

print("Best parameters for ExtraTreesClassifier:", study_extra_trees.best_params)
# Out:
# [I 2025-03-04 10:11:12,043] A new study created in memory with name: no-name-b5514a25-703c-4179-85e3-636d53e7f1aa
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03-04 10:11:12,179] Trial 0 finished with value: 0.9313380720788129 and parameters: {'n_estimators': 39, 'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 0.3184529798401361, 'bootstrap': False}. Best is trial 0 with value: 0.9313380720788129.
# [I 2025-03-04 10:11:12,318] Trial 1 finished with value: 0.9342187305150268 and parameters: {'n_estimators': 54, 'criterion': 'entropy', 'max_depth': 8, 'min_samples_split':
and parameters: {'n_estimators': 61, 'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 29, 'min_samples_leaf': 8, 'max_features': 0.6295604422375194, 'bootstrap': False}. Best is trial 96 with value: 0.9365506921062476.
# [I 2025-03-04 10:11:26,378] Trial 97 finished with value: 0.935877291432847 and parameters: {'n_estimators': 57, 'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 29, 'min_samples_leaf': 8, 'max_features': 0.6602707934227783, 'bootstrap': False}. Best is trial 96 with value: 0.9365506921062476.
# [I 2025-03-04 10:11:26,549] Trial 98 finished with value: 0.9352662426736501 and parameters: {'n_estimators': 60, 'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 28, 'min_samples_leaf': 9, 'max_features': 0.6310719241604105, 'bootstrap': False}. Best is trial 96 with value: 0.9365506921062476.
# [I 2025-03-04 10:11:26,708] Trial 99 finished with value: 0.9355904726275097 and parameters: {'n_estimators': 63, 'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 27, 'min_samples_leaf': 8, 'max_features': 0.5907407561587281, 'bootstrap': False}. Best is trial 96 with value: 0.9365506921062476.
# Best parameters for ExtraTreesClassifier: {'n_estimators': 61, 'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 29, 'min_samples_leaf': 8, 'max_features': 0.6295604422375194, 'bootstrap': False}

# %%
print("\n=== ExtraTreesClassifier Results ===")
extra_trees_model = ExtraTreesClassifier(**study_extra_trees.best_params, random_state=SEED)
extra_trees_model.fit(X_train, y_train)
y_proba_extra = extra_trees_model.predict_proba(X_test)[:, 1]

best_threshold_extra = 0.5
best_f1_extra = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (y_proba_extra >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1_extra:
        best_f1_extra = f1
        best_threshold_extra = t

extra_trees_pred = (y_proba_extra >= best_threshold_extra).astype(int)

print(f"Best weighted F1-score: {best_f1_extra:.4f} at threshold {best_threshold_extra:.2f}")
print(f"Best parameters: {study_extra_trees.best_params}")
# print("Classification Report:\n", classification_report(y_test, extra_trees_pred))

fpr, tpr, _ = roc_curve(y_train, extra_trees_model.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, extra_trees_model.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

submission.rainfall = extra_trees_model.predict_proba(test)[:, 1]
submission.to_csv('submission_extra_trees.csv', index=False)
# Out:
# === ExtraTreesClassifier Results ===
# Best weighted F1-score: 0.8862 at threshold 0.60
# Best parameters: {'n_estimators': 61, 'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 29, 'min_samples_leaf': 8, 'max_features': 0.6295604422375194, 'bootstrap': False}
# (0.9532811104239676, 0.9365506921062476)

# %%
def objective_lgbm(trial):
    params = {
        'objective': 'binary',
        'metric': 'binary_logloss',
        'verbosity': -1,
        'n_estimators': trial.suggest_int('n_estimators', TREES_LOWER, TREES_UPPER),
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart']),
        'num_leaves': trial.suggest_int('num_leaves', 10, 40),  
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 0.05),  
        'min_child_samples': trial.suggest_int('min_child_samples', 20, 120),  
        'subsample': trial.suggest_uniform('subsample', 0.6, 0.9),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 0.9),  
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-2, 2),  
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-2, 2), 
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.6, 0.9), 
        'bagging_freq': trial.suggest_int('bagging_freq', 5, 10),  
        'min_gain_to_split': trial.suggest_loguniform('min_gain_to_split', 1e-2, 0.5),  
        'extra_trees': trial.suggest_categorical('extra_trees', [True, False]),
        'max_depth': trial.suggest_int('max_depth', 3, 8)
    }
    
    model = lgb.LGBMClassifier(**params, random_state=SEED)

    model.fit(X_train, y_train)

    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    roc_auc = auc(fpr, tpr)
    
    return roc_auc

study_lgbm = optuna.create_study(direction='maximize')
study_lgbm.optimize(objective_lgbm, n_trials=TRIALS, show_progress_bar=True)

print("Best parameters for LightGBM:", study_lgbm.best_params)
# Out:
# [I 2025-03-04 10:11:26,942] A new study created in memory with name: no-name-2e118d1f-b804-45de-9001-9098eedc36dc
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03-04 10:11:27,091] Trial 0 finished with value: 0.9175832398054621 and parameters: {'n_estimators': 63, 'boosting_type': 'gbdt', 'num_leaves': 31, 'learning_rate': 0.012257421321940541, 'min_child_samples': 82, 'subsample': 0.8882863492869049, 'colsample_bytree': 0.7780717675880353, 'lambda_l1': 0.38303132535005674, 'lambda_l2': 0.14807666451215273, 'feature_fraction': 0.8775383196912327, 'bagging_freq': 10, 'min_gain_to_split': 0.05689790762765406, 'extra_trees': True, 'max_depth': 5}. Best is trial 0 with value: 0.9175832398054621.
# [I 2025-03-04 10:11:27,127] Trial 1 finished with value: 0.9082928045891008 and parameters: {'n_estimators': 49, 'boosting_type': 'gbdt', 'num_leaves': 31, 'learning_rate': 0.0012855301685135915, 'min_child_samples': 111, 'subsample': 0.7621107111494121, 'colsample_bytree': 0.6230185042157688, 'lambda_l1': 1.1178849705586253, 'lambda_l2': 0.022924004307375706, 'feature_fraction': 0.8291989122260552, 'bagging_freq': 8, 'min_gain_to_split': 0.24369783944742224, 'extra_trees': True, 'max_depth': 4}. Best is trial 0 with value: 0.9175832398054621.
# [I 2025-03-04 10:11:27,158] Trial 2 finished with value: 0.918194288564659 and parameters: {'n_estimators': 40, 'boosting_type': 'dart', 'num_leaves': 21, 'learning_rate': 0.005421524208600948, 'min_child_samples': 65, 'subsample': 0.7616129638027096, 'colsample_bytree': 0.8173929357915168, 'lambda_l1': 0.2132016609681615, 'lambda_l2': 0.2420134022737393, 'feature_fraction': 0.8296215559375463, 'bagging_freq': 5, 'min_gain_to_split': 0.30406053420515916, 'extra_trees': False, 'max_depth': 7}. Best is trial 2 with value: 0.918194288564659.
# [I 2025-03-04 10:11:27,190] Trial 3 finished with value: 0.9205137797730389 and parameters: {'n_estimators': 59, 'boosting_type': 'dart', 'num_leaves': 27, 'learning_rate': 0.008574863336357794, 'min_child_samples': 22, 'subsample': 0.6430808653551605, 'colsample_bytree': 0.7507166317709824, 'lambda_l1': 0.023893446922265228, 'lambda_l2': 0.034493839475753615, 'feature_fraction': 0.6516752170568777, 'bagging_freq': 7, 'min_gain_to_split': 0.1202244647943371, 'extra_trees': True, 'max_depth': 4}. Best is trial 3 with value: 0.9205137797730389.
# [I 2025-03-04 10:11:27,221] Trial 4 finished with value: 0.9197655568025938 and parameters: {'n_estimators': 57, 'boosting_type': 'gbdt', 'num_leaves': 28, 'learning_rate': 0.0016911492053966245, 'min_child_samples': 116, 'subsample': 0.8275361428936466, 'colsample_bytree': 0.7616361000484637, 'lambda_l1': 0.018241727380905366, 'lambda_l2': 1.8566941798724494, 'feature_fraction': 0.682667011164523, 'bagging_freq': 7, 'min_gain_to_split': 0.029813130800208563, 'extra_trees': False, 'max_depth': 6}. Best is trial 3 with value: 0.9205137797730389.
# [I 2025-03-04 10:11:27,244] Trial 5 finished with value: 0.9111173463025316 and parameters: {'n_estimators': 40, 'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.0020461594674493736, 'min_child_samples': 96, 'subsample': 0.7554790594751588, 'colsample_bytree': 0.8777133892973138, 'lambda_l1': 0.8198452526352094, 'lambda_l2': 1.1242492725303161, 'feature_fraction': 0.7955196574380071, 'bagging_freq': 5, 'min_gain_to_split': 0.17142088222359814, 'extra_trees': True, 'max_depth': 4}. Best is trial 3 with value: 0.9205137797730389.
# [I 2025-03-04 10:11:27,261] Trial 6 finished with value: 0.8979548572141164 and parameters: {'n_estimators': 33, 'boosting_type': 'gbdt', 'num_leaves': 40, 'learning_rate': 0.0015332516097671855, 'min_child_samples': 100, 'subsample': 0.6381086067297295, 'colsample_bytree': 0.7482137324642262, 'lambda_l1': 0.1078075077775549, 'lambda_l2': 0.26382547360652014, 'feature_fraction': 0.7626032278235094, 'bagging_freq': 5, 'min_gain_to_split': 0.09630367374657214, 'extra_trees': True, 'max_depth': 8}. Best is trial 3 with value: 0.9205137797730389.
# [I 2025-03-04 10:11:27,290] Trial 7 finished with value: 0.907532111235815 and parameters: {'n_estimators': 62, 'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.0010893327741653182, 'min_child_samples': 101, 'subsample': 0.7852506888664846, 'colsample_bytree': 0.7619041963238194, 'lambda_l1': 0.1791462802646854, 'lambda_l2': 0.06493340890276496, 'feature_fraction': 0.8408227206182883, 'bagging_freq': 5, 'min_gain_to_split': 0.09885497987836263, 'extra_trees': True, 'max_depth': 4}. Best is trial 3 with value: 0.9205137797730389.
# [I 2025-03-04 10:11:27,327] Trial 8 finished with value: 0.92003367003367 and parameters: {'n_estimators': 49, 'boosting_type': 'dart', 'num_leaves': 33, 'learning_rate': 0.0014209584906268436, 'min_child_samples': 96, 'subsample': 0.6925934569462888, 'colsample_bytree': 0.6330842126780644, 'lambda_l1': 0.13175935212830014, 'lambda_l2': 0.5752851088495867, 'feature_fraction': 0.6529698943910415, 'bagging_freq': 5, 'min_gain_to_split': 0.29821804343192615, 'extra_trees': False, 'max_depth': 6}. Best is trial 3 with value: 0.9205137797730389.
# [I 2025-03-04 10:11:27,360] Trial 9 finished with value: 0.925314877166729 and parameters: {'n_estimators': 54, 'boosting_type': 'gbdt', 'num_leaves': 25, 'learning_rate': 0.022229145174598394, 'min_child_samples': 23, 'subsample': 0.6854511743185902, 'colsample_bytree': 0.6449815123352153, 'lambda_l1': 0.014168365109156861, 'lambda_l2': 0.023291969272939667, 'feature_fraction': 0.6038231083758038, 'bagging_freq': 10, 'min_gain_to_split': 0.32588439012682563, 'extra_trees': True, 'max_depth': 7}. Best is trial 9 with value: 0.925314877166729.
# [I 2025-03-04 10:11:27,435] Trial 10 finished with value: 0.9253647586980921 and parameters: {'n_estimators': 54, 'boosting_type': 'dart', 'num_leaves': 10, 'learning_rate': 0.04979680707684744, 'min_child_samples': 25, 'subsample': 0.6929190449699139, 'colsample_bytree': 0.6765595455762299, 'lambda_l1': 0.03454647357409732, 'lambda_l2': 0.010659933286473708, 'feature_fraction': 0.714814178331127, 'bagging_freq': 10, 'min_gain_to_split': 0.010648281694006117, 'extra_trees': False, 'max_depth': 8}. Best is trial 10 with value: 0.9253647586980921.
# [I 2025-03-04 10:11:27,523] Trial 11 finished with value: 0.9264995635366006 and parameters: {'n_estimators': 54, 'boosting_type': 'dart', 'num_leaves': 13, 'learning_rate': 0.04828167727785107, 'min_child_samples': 21, 'subsample': 0.6956107134208378, 'colsample_bytree': 0.6806818111094068, 'lambda_l1': 0.010448090274787467, 'lambda_l2': 0.010287938736167545, 'feature_fraction': 0.6012613911813793, 'bagging_freq': 10, 'min_gain_to_split': 0.01169798515725511, 'extra_trees': False, 'max_depth': 8}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:27,623] Trial 12 finished with value: 0.9239680758199276 and parameters: {'n_estimators': 53, 'boosting_type': 'dart', 'num_leaves': 11, 'learning_rate': 0.04947926296210171, 'min_child_samples': 44, 'subsample': 0.6964740943560449, 'colsample_bytree': 0.672548708104336, 'lambda_l1': 0.04262749841042677, 'lambda_l2': 0.012846137231337644, 'feature_fraction': 0.7156905039919251, 'bagging_freq': 9, 'min_gain_to_split': 0.010740081337742988, 'extra_trees': False, 'max_depth': 8}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:27,714] Trial 13 finished with value: 0.9238558423743608 and parameters: {'n_estimators': 42, 'boosting_type': 'dart', 'num_leaves': 11, 'learning_rate': 0.04989805101712829, 'min_child_samples': 42, 'subsample': 0.7105265923351357, 'colsample_bytree': 0.6945890550223259, 'lambda_l1': 0.04762985261601781, 'lambda_l2': 0.010497905849945498, 'feature_fraction': 0.6109225009381093, 'bagging_freq': 9, 'min_gain_to_split': 0.01046408680609438, 'extra_trees': False, 'max_depth': 8}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:27,818] Trial 14 finished with value: 0.9208130689612172 and parameters: {'n_estimators': 45, 'boosting_type': 'dart', 'num_leaves': 15, 'learning_rate': 0.024940830052175948, 'min_child_samples': 42, 'subsample': 0.6051671456451757, 'colsample_bytree': 0.6949230912444615, 'lambda_l1': 0.011895124329066871, 'lambda_l2': 0.06328454218202154, 'feature_fraction': 0.7195900119477475, 'bagging_freq': 9, 'min_gain_to_split': 0.025198946892230137, 'extra_trees': False, 'max_depth': 7}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:27,932] Trial 15 finished with value: 0.9211248285322359 and parameters: {'n_estimators': 53, 'boosting_type': 'dart', 'num_leaves': 15, 'learning_rate': 0.029549960217699536, 'min_child_samples': 60, 'subsample': 0.7282551554061101, 'colsample_bytree': 0.709220135914833, 'lambda_l1': 0.04105735289385828, 'lambda_l2': 0.010151843452862123, 'feature_fraction': 0.7495631334361368, 'bagging_freq': 10, 'min_gain_to_split': 0.01977484746987796, 'extra_trees': False, 'max_depth': 8}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:28,016] Trial 16 finished with value: 0.9214802344431976 and parameters: {'n_estimators': 57, 'boosting_type': 'dart', 'num_leaves': 10, 'learning_rate': 0.015818668326711312, 'min_child_samples': 31, 'subsample': 0.6568013513939798, 'colsample_bytree': 0.6567651950127296, 'lambda_l1': 0.010295593876783075, 'lambda_l2': 0.050140038785533164, 'feature_fraction': 0.6576550411500472, 'bagging_freq': 8, 'min_gain_to_split': 0.04634907282614443, 'extra_trees': False, 'max_depth': 3}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:28,110] Trial 17 finished with value: 0.9196533233570271 and parameters: {'n_estimators': 51, 'boosting_type': 'dart', 'num_leaves': 15, 'learning_rate': 0.004064442301403922, 'min_child_samples': 53, 'subsample': 0.8070383990267228, 'colsample_bytree': 0.7232652195611105, 'lambda_l1': 0.07467674071543785, 'lambda_l2': 0.01977650023040902, 'feature_fraction': 0.6956033813937175, 'bagging_freq': 10, 'min_gain_to_split': 0.01680862428704805, 'extra_trees': False, 'max_depth': 7}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:28,184] Trial 18 finished with value: 0.9209502431724654 and parameters: {'n_estimators': 45, 'boosting_type': 'dart', 'num_leaves': 14, 'learning_rate': 0.03265186120991806, 'min_child_samples': 77, 'subsample': 0.6678534303731151, 'colsample_bytree': 0.8137843582306831, 'lambda_l1': 0.026445448855365098, 'lambda_l2': 0.10224972526173848, 'feature_fraction': 0.7609675972268507, 'bagging_freq': 9, 'min_gain_to_split': 0.037809917878472564, 'extra_trees': False, 'max_depth': 6}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:28,279] Trial 19 finished with value: 0.9230078563411898 and parameters: {'n_estimators': 59, 'boosting_type': 'dart', 'num_leaves': 21, 'learning_rate': 0.0032642833439391985, 'min_child_samples': 31, 'subsample': 0.6072901711268994, 'colsample_bytree': 0.6779200078208133, 'lambda_l1': 0.030718599817974663, 'lambda_l2': 0.03438783359354563, 'feature_fraction': 0.6306511674212693, 'bagging_freq': 6, 'min_gain_to_split': 0.01518231022376536, 'extra_trees': False, 'max_depth': 8}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:28,365] Trial 20 finished with value: 0.9183189923930666 and parameters: {'n_estimators': 34, 'boosting_type': 'dart', 'num_leaves': 18, 'learning_rate': 0.01369352709043036, 'min_child_samples': 54, 'subsample': 0.7278963776140285, 'colsample_bytree': 0.7247601529053465, 'lambda_l1': 0.06620341205233458, 'lambda_l2': 0.016886697600033387, 'feature_fraction': 0.7933809885687959, 'bagging_freq': 8, 'min_gain_to_split': 0.013563443534929939, 'extra_trees': False, 'max_depth': 5}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:28,467] Trial 21 finished with value: 0.9242050130939019 and parameters: {'n_estimators': 54, 'boosting_type': 'gbdt', 'num_leaves': 24, 'learning_rate': 0.025241878649301084, 'min_child_samples': 22, 'subsample': 0.672421293680233, 'colsample_bytree': 0.6473330048239836, 'lambda_l1': 0.013432628666963256, 'lambda_l2': 0.027231767841888903, 'feature_fraction': 0.6008410597865189, 'bagging_freq': 10, 'min_gain_to_split': 0.39042296745433896, 'extra_trees': True, 'max_depth': 7}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:28,565] Trial 22 finished with value: 0.9231450305524379 and parameters: {'n_estimators': 55, 'boosting_type': 'gbdt', 'num_leaves': 38, 'learning_rate': 0.03822122267203464, 'min_child_samples': 31, 'subsample': 0.6883134912984988, 'colsample_bytree': 0.6004202427239081, 'lambda_l1': 0.01794347208731682, 'lambda_l2': 0.01723681066600799, 'feature_fraction': 0.6162436275586056, 'bagging_freq': 10, 'min_gain_to_split': 0.022933761706845357, 'extra_trees': True, 'max_depth': 7}. Best is trial 11 with value: 0.9264995635366006.
# [I 2025-03-04 10:11:28,655] Trial 23 finished with value: 0.927285197655568 and parameters: {'n_estimators': 51, 'boosting_type': 'gbdt', 'num_leaves': 13, 'learning_rate': 0.01962571056189082, 'min_child_samples': 20, 'subsample': 0.7197703479568175, 'colsample_bytree': 0.6050191996572369, 'lambda_l1': 0.018563011069159776, 'lambda_l2': 0.014161382460963384, 'feature_fraction': 0.6359895616189933, 'bagging_freq': 9, 'min_gain_to_split': 0.4931013646309014, 'extra_trees': True, 'max_depth': 8}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:28,751] Trial 24 finished with value: 0.9228582117471007 and parameters: {'n_estimators': 47, 'boosting_type': 'dart', 'num_leaves': 13, 'learning_rate': 0.018043546663187304, 'min_child_samples': 38, 'subsample': 0.7417273029066436, 'colsample_bytree': 0.6241784828698047, 'lambda_l1': 0.02540005215836238, 'lambda_l2': 0.014736242026476571, 'feature_fraction': 0.673124689525318, 'bagging_freq': 9, 'min_gain_to_split': 0.4692759917153228, 'extra_trees': False, 'max_depth': 8}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:28,866] Trial 25 finished with value: 0.927035789998753 and parameters: {'n_estimators': 51, 'boosting_type': 'dart', 'num_leaves': 17, 'learning_rate': 0.009866442411669559, 'min_child_samples': 20, 'subsample': 0.6279050141700978, 'colsample_bytree': 0.6060425591529849, 'lambda_l1': 0.01007705547081756, 'lambda_l2': 0.04275323004517759, 'feature_fraction': 0.636188870021157, 'bagging_freq': 9, 'min_gain_to_split': 0.03349844165070649, 'extra_trees': False, 'max_depth': 8}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:28,957] Trial 26 finished with value: 0.9208878912582616 and parameters: {'n_estimators': 50, 'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.009020461477274769, 'min_child_samples': 35, 'subsample': 0.6280337576858287, 'colsample_bytree': 0.6036163154072194, 'lambda_l1': 0.015936977492023004, 'lambda_l2': 0.04334615313376303, 'feature_fraction': 0.6346606694398118, 'bagging_freq': 9, 'min_gain_to_split': 0.06724731150271225, 'extra_trees': True, 'max_depth': 7}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:29,053] Trial 27 finished with value: 0.9209751839381469 and parameters: {'n_estimators': 46, 'boosting_type': 'dart', 'num_leaves': 13, 'learning_rate': 0.010391237418346926, 'min_child_samples': 47, 'subsample': 0.7204894420484937, 'colsample_bytree': 0.6160480586031905, 'lambda_l1': 0.010740169464879415, 'lambda_l2': 0.07803494456087091, 'feature_fraction': 0.6366133917915447, 'bagging_freq': 8, 'min_gain_to_split': 0.03396641848629329, 'extra_trees': False, 'max_depth': 8}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:29,132] Trial 28 finished with value: 0.9184187554557925 and parameters: {'n_estimators': 43, 'boosting_type': 'gbdt', 'num_leaves': 19, 'learning_rate': 0.006212803992226569, 'min_child_samples': 28, 'subsample': 0.6204284296876618, 'colsample_bytree': 0.6455445077589671, 'lambda_l1': 1.826913992196113, 'lambda_l2': 0.03209557514565286, 'feature_fraction': 0.6691539451825774, 'bagging_freq': 9, 'min_gain_to_split': 0.17780504186332255, 'extra_trees': True, 'max_depth': 6}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:29,218] Trial 29 finished with value: 0.9200024940765682 and parameters: {'n_estimators': 60, 'boosting_type': 'gbdt', 'num_leaves': 17, 'learning_rate': 0.018579679061144983, 'min_child_samples': 75, 'subsample': 0.8825469027706758, 'colsample_bytree': 0.8991391740262644, 'lambda_l1': 0.35300306503543344, 'lambda_l2': 0.1583823057198706, 'feature_fraction': 0.8815491563855222, 'bagging_freq': 7, 'min_gain_to_split': 0.054699796074585326, 'extra_trees': True, 'max_depth': 5}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:29,336] Trial 30 finished with value: 0.9196283825913456 and parameters: {'n_estimators': 51, 'boosting_type': 'dart', 'num_leaves': 23, 'learning_rate': 0.013408736324954948, 'min_child_samples': 50, 'subsample': 0.6586202428614477, 'colsample_bytree': 0.6623017795906745, 'lambda_l1': 0.020244120687926245, 'lambda_l2': 0.10415316708719038, 'feature_fraction': 0.625521339832176, 'bagging_freq': 8, 'min_gain_to_split': 0.0716541929189687, 'extra_trees': False, 'max_depth': 8}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:29,450] Trial 31 finished with value: 0.9255705200149644 and parameters: {'n_estimators': 64, 'boosting_type': 'dart', 'num_leaves': 12, 'learning_rate': 0.0390194612765909, 'min_child_samples': 20, 'subsample': 0.7078852680752212, 'colsample_bytree': 0.690852467401864, 'lambda_l1': 0.010162392111459516, 'lambda_l2': 0.010145812313267435, 'feature_fraction': 0.7033856094760926, 'bagging_freq': 10, 'min_gain_to_split': 0.012817864128368448, 'extra_trees': False, 'max_depth': 8}. Best is trial 23 with value: 0.927285197655568.
# [I 2025-03-04 10:11:29,547] Trial 32 finished with value: 0.9282641227085672 and parameters: {'n_estimators': 63, 'boosting_type': 'dart', 'num_leaves': 12, 'learning_rate': 0.03342341252074174, 'min_child_samples': 20, 'subsample': 0.781371710648635, 'colsample_bytree': 0.6298287349364007, 'lambda_l1': 0.010498460939217394, 'lambda_l2': 0.01577675523102797, 'feature_fraction': 0.6967121799614526, 'bagging_freq': 10, 'min_gain_to_split': 0.02052077438535054, 'extra_trees': False, 'max_depth': 8}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:29,637] Trial 33 finished with value: 0.9270607307644344 and parameters: {'n_estimators': 57, 'boosting_type': 'dart', 'num_leaves': 16, 'learning_rate': 0.020172912233432604, 'min_child_samples': 37, 'subsample': 0.7806180779379426, 'colsample_bytree': 0.6303206141198923, 'lambda_l1': 0.017016035802814983, 'lambda_l2': 0.021105645052571974, 'feature_fraction': 0.6456842236416395, 'bagging_freq': 9, 'min_gain_to_split': 0.019889576561269506, 'extra_trees': False, 'max_depth': 7}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:29,762] Trial 34 finished with value: 0.9233196159122086 and parameters: {'n_estimators': 62, 'boosting_type': 'dart', 'num_leaves': 16, 'learning_rate': 0.011270599497890567, 'min_child_samples': 37, 'subsample': 0.7852212149352911, 'colsample_bytree': 0.6190778650557768, 'lambda_l1': 0.019144888604606027, 'lambda_l2': 0.021761193489005848, 'feature_fraction': 0.6843479721018533, 'bagging_freq': 9, 'min_gain_to_split': 0.01923266802669889, 'extra_trees': False, 'max_depth': 7}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:29,880] Trial 35 finished with value: 0.9260631001371742 and parameters: {'n_estimators': 58, 'boosting_type': 'dart', 'num_leaves': 21, 'learning_rate': 0.020099410097547652, 'min_child_samples': 27, 'subsample': 0.7800332614161998, 'colsample_bytree': 0.6297310866775984, 'lambda_l1': 0.06237146234735921, 'lambda_l2': 0.04210650276411156, 'feature_fraction': 0.6470401685941425, 'bagging_freq': 8, 'min_gain_to_split': 0.02513287877054944, 'extra_trees': False, 'max_depth': 7}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:29,964] Trial 36 finished with value: 0.9223593964334704 and parameters: {'n_estimators': 61, 'boosting_type': 'gbdt', 'num_leaves': 16, 'learning_rate': 0.007540891302114104, 'min_child_samples': 36, 'subsample': 0.8301542719122579, 'colsample_bytree': 0.6050393459616592, 'lambda_l1': 0.015842290903019245, 'lambda_l2': 0.025003856044389497, 'feature_fraction': 0.6652622128106198, 'bagging_freq': 9, 'min_gain_to_split': 0.04559119242490569, 'extra_trees': True, 'max_depth': 7}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:30,093] Trial 37 finished with value: 0.9238807831400425 and parameters: {'n_estimators': 56, 'boosting_type': 'dart', 'num_leaves': 30, 'learning_rate': 0.015273643468743235, 'min_child_samples': 29, 'subsample': 0.8469635542619411, 'colsample_bytree': 0.8090090393906455, 'lambda_l1': 0.02267571108657183, 'lambda_l2': 0.015459435779385525, 'feature_fraction': 0.6862045941090101, 'bagging_freq': 7, 'min_gain_to_split': 0.030764314738523188, 'extra_trees': False, 'max_depth': 8}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:30,195] Trial 38 finished with value: 0.9156253896994637 and parameters: {'n_estimators': 48, 'boosting_type': 'gbdt', 'num_leaves': 12, 'learning_rate': 0.004558775446386274, 'min_child_samples': 61, 'subsample': 0.7665982130765747, 'colsample_bytree': 0.6379333053216112, 'lambda_l1': 0.3141727861128675, 'lambda_l2': 0.02971583372624327, 'feature_fraction': 0.7271724323434289, 'bagging_freq': 9, 'min_gain_to_split': 0.13756710944655157, 'extra_trees': True, 'max_depth': 6}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:30,320] Trial 39 finished with value: 0.9276780147150516 and parameters: {'n_estimators': 63, 'boosting_type': 'dart', 'num_leaves': 22, 'learning_rate': 0.028127853363957626, 'min_child_samples': 20, 'subsample': 0.8072042704250632, 'colsample_bytree': 0.8448265110957649, 'lambda_l1': 0.014500483484661134, 'lambda_l2': 0.052207417433283033, 'feature_fraction': 0.6440363489899595, 'bagging_freq': 10, 'min_gain_to_split': 0.040712008236308585, 'extra_trees': False, 'max_depth': 3}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:30,415] Trial 40 finished with value: 0.924965706447188 and parameters: {'n_estimators': 64, 'boosting_type': 'gbdt', 'num_leaves': 26, 'learning_rate': 0.030276886083174685, 'min_child_samples': 86, 'subsample': 0.8159341578540719, 'colsample_bytree': 0.8377062912077582, 'lambda_l1': 0.08876601044437256, 'lambda_l2': 0.2198501863191651, 'feature_fraction': 0.899644683972455, 'bagging_freq': 10, 'min_gain_to_split': 0.23646704795643553, 'extra_trees': True, 'max_depth': 3}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:30,532] Trial 41 finished with value: 0.9276094276094277 and parameters: {'n_estimators': 62, 'boosting_type': 'dart', 'num_leaves': 20, 'learning_rate': 0.025626114411986863, 'min_child_samples': 26, 'subsample': 0.8592030643624327, 'colsample_bytree': 0.8477476498386444, 'lambda_l1': 0.014231066049745516, 'lambda_l2': 0.05232923776853528, 'feature_fraction': 0.6442050870723612, 'bagging_freq': 10, 'min_gain_to_split': 0.026924656627080896, 'extra_trees': False, 'max_depth': 4}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:30,633] Trial 42 finished with value: 0.9257326349918942 and parameters: {'n_estimators': 62, 'boosting_type': 'dart', 'num_leaves': 22, 'learning_rate': 0.024810395942256102, 'min_child_samples': 26, 'subsample': 0.8647990554663372, 'colsample_bytree': 0.8548729166916272, 'lambda_l1': 0.014447713537665757, 'lambda_l2': 0.47503245092901397, 'feature_fraction': 0.6502224938255942, 'bagging_freq': 10, 'min_gain_to_split': 0.04313215596955115, 'extra_trees': False, 'max_depth': 3}. Best is trial 32 with value: 0.9282641227085672.
# [I 2025-03-04 10:11:30,746] Trial 43 finished with value: 0.9294425738870183 and parameters: {'n_estimators': 60, 'boosting_type': 'dart', 'num_leaves': 20, 'learning_rate': 0.03632974904639697, 'min_child_samples': 33, 'subsample': 0.8987816103269342, 'colsample_bytree': 0.7904959390650497, 'lambda_l1': 0.02366134221433634, 'lambda_l2': 0.05902451525481318, 'feature_fraction': 0.6227535643462196, 'bagging_freq': 10, 'min_gain_to_split': 0.025380360253723463, 'extra_trees': False, 'max_depth': 4}. Best is trial 43 with value: 0.9294425738870183.
# [I 2025-03-04 10:11:30,866] Trial 44 finished with value: 0.931525127821424 and parameters: {'n_estimators': 60, 'boosting_type': 'dart', 'num_leaves': 28, 'learning_rate': 0.036899523795865224, 'min_child_samples': 25, 'subsample': 0.8999211293797946, 'colsample_bytree': 0.7913423386970816, 'lambda_l1': 0.03164717619340073, 'lambda_l2': 0.08862909588863763, 'feature_fraction': 0.6253427250788586, 'bagging_freq': 10, 'min_gain_to_split': 0.02473364844750706, 'extra_trees': False, 'max_depth': 4}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:30,984] Trial 45 finished with value: 0.929455044269859 and parameters: {'n_estimators': 60, 'boosting_type': 'dart', 'num_leaves': 29, 'learning_rate': 0
boosting_type': 'dart', 'num_leaves': 28, 'learning_rate': 0.0011631601378813596, 'min_child_samples': 31, 'subsample': 0.8775157255123501, 'colsample_bytree': 0.7957751755559266, 'lambda_l1': 0.054264259537988725, 'lambda_l2': 0.20597207158185524, 'feature_fraction': 0.6208792559469337, 'bagging_freq': 6, 'min_gain_to_split': 0.013824714863414822, 'extra_trees': False, 'max_depth': 5}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:33,640] Trial 70 finished with value: 0.9251714677640603 and parameters: {'n_estimators': 53, 'boosting_type': 'dart', 'num_leaves': 35, 'learning_rate': 0.02238094518946136, 'min_child_samples': 24, 'subsample': 0.8441792995375237, 'colsample_bytree': 0.7391327925623792, 'lambda_l1': 0.4010389331173471, 'lambda_l2': 0.3463500460783365, 'feature_fraction': 0.8512087700155311, 'bagging_freq': 5, 'min_gain_to_split': 0.023360842797942694, 'extra_trees': False, 'max_depth': 4}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:33,739] Trial 71 finished with value: 0.9290310512532736 and parameters: {'n_estimators': 55, 'boosting_type': 'dart', 'num_leaves': 32, 'learning_rate': 0.045361705800721935, 'min_child_samples': 28, 'subsample': 0.8640245137331368, 'colsample_bytree': 0.7528590788664695, 'lambda_l1': 0.19154993793729275, 'lambda_l2': 0.14060037496619487, 'feature_fraction': 0.658574849059502, 'bagging_freq': 6, 'min_gain_to_split': 0.020381143149749634, 'extra_trees': False, 'max_depth': 3}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:33,862] Trial 72 finished with value: 0.9280084798603316 and parameters: {'n_estimators': 57, 'boosting_type': 'dart', 'num_leaves': 32, 'learning_rate': 0.034344191665498534, 'min_child_samples': 36, 'subsample': 0.886214766241154, 'colsample_bytree': 0.7563800488444231, 'lambda_l1': 0.2817221001617263, 'lambda_l2': 0.17982400562666515, 'feature_fraction': 0.6112914906345023, 'bagging_freq': 6, 'min_gain_to_split': 0.021106233550547308, 'extra_trees': False, 'max_depth': 3}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:33,951] Trial 73 finished with value: 0.9290185808704328 and parameters: {'n_estimators': 59, 'boosting_type': 'dart', 'num_leaves': 30, 'learning_rate': 0.03900345772553284, 'min_child_samples': 30, 'subsample': 0.874105706243996, 'colsample_bytree': 0.7727305391692881, 'lambda_l1': 0.23173554866040008, 'lambda_l2': 0.10918752573018475, 'feature_fraction': 0.6288072951687139, 'bagging_freq': 6, 'min_gain_to_split': 0.027327720219882223, 'extra_trees': False, 'max_depth': 3}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:34,055] Trial 74 finished with value: 0.9277466018206759 and parameters: {'n_estimators': 56, 'boosting_type': 'dart', 'num_leaves': 34, 'learning_rate': 0.04211276854668508, 'min_child_samples': 23, 'subsample': 0.8374196290493557, 'colsample_bytree': 0.8047994184096252, 'lambda_l1': 0.9495756716837914, 'lambda_l2': 0.0692848198107296, 'feature_fraction': 0.6083648510579348, 'bagging_freq': 7, 'min_gain_to_split': 0.03214798541195816, 'extra_trees': False, 'max_depth': 4}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:34,161] Trial 75 finished with value: 0.9286319990023693 and parameters: {'n_estimators': 54, 'boosting_type': 'dart', 'num_leaves': 37, 'learning_rate': 0.04472260244651572, 'min_child_samples': 39, 'subsample': 0.8899118587013849, 'colsample_bytree': 0.7625134121441605, 'lambda_l1': 0.11541505232958611, 'lambda_l2': 0.44335650517166275, 'feature_fraction': 0.6554772365278477, 'bagging_freq': 6, 'min_gain_to_split': 0.015944393099079694, 'extra_trees': False, 'max_depth': 4}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:34,248] Trial 76 finished with value: 0.9263000374111485 and parameters: {'n_estimators': 58, 'boosting_type': 'dart', 'num_leaves': 26, 'learning_rate': 0.03212059035442683, 'min_child_samples': 44, 'subsample': 0.8673071023136608, 'colsample_bytree': 0.7912853102596303, 'lambda_l1': 0.2522955762768358, 'lambda_l2': 0.2586037203507539, 'feature_fraction': 0.6377354804514072, 'bagging_freq': 5, 'min_gain_to_split': 0.02252350466583718, 'extra_trees': False, 'max_depth': 5}. Best is trial 44 with value: 0.931525127821424.
# [I 2025-03-04 10:11:34
{'n_estimators': 60, 'boosting_type': 'dart', 'num_leaves': 28, 'learning_rate': 0.036899523795865224, 'min_child_samples': 25, 'subsample': 0.8999211293797946, 'colsample_bytree': 0.7913423386970816, 'lambda_l1': 0.03164717619340073, 'lambda_l2': 0.08862909588863763, 'feature_fraction': 0.6253427250788586, 'bagging_freq': 10, 'min_gain_to_split': 0.02473364844750706, 'extra_trees': False, 'max_depth': 4}

# %%
print("\n=== LightGBM Results ===")

lgbm_model = lgb.LGBMClassifier(**study_lgbm.best_params, random_state=SEED)
lgbm_model.fit(X_train, y_train)

y_proba = lgbm_model.predict_proba(X_test)[:, 1]

best_threshold = 0.5
best_f1 = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (y_proba >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = t

lgbm_pred = (y_proba >= best_threshold).astype(int)

print(f"Best weighted F1-score: {best_f1:.4f} at threshold {best_threshold:.2f}")
print(f"Best parameters: {study_lgbm.best_params}")
#print("Classification Report:\n", classification_report(y_test, lgbm_pred))

fpr, tpr, _ = roc_curve(y_train, lgbm_model.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, lgbm_model.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

submission.rainfall=lgbm_model.predict_proba(test)[:, 1]  
submission.to_csv('submission_lgbm.csv',index=False)
# Out:
# === LightGBM Results ===
# Best weighted F1-score: 0.8833 at threshold 0.60
# Best parameters: {'n_estimators': 60, 'boosting_type': 'dart', 'num_leaves': 28, 'learning_rate': 0.036899523795865224, 'min_child_samples': 25, 'subsample': 0.8999211293797946, 'colsample_bytree': 0.7913423386970816, 'lambda_l1': 0.03164717619340073, 'lambda_l2': 0.08862909588863763, 'feature_fraction': 0.6253427250788586, 'bagging_freq': 10, 'min_gain_to_split': 0.02473364844750706, 'extra_trees': False, 'max_depth': 4}
# (0.9533818914771295, 0.931525127821424)

# %%
def objective_xgb(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', TREES_LOWER, TREES_UPPER),
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'use_label_encoder': False,
        'max_depth': trial.suggest_int('max_depth', 3, 8),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 0.05),
        'min_child_weight': trial.suggest_int('min_child_weight', 10, 30),
        'subsample': trial.suggest_uniform('subsample', 0.6, 0.9),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 0.9),
        'gamma': trial.suggest_loguniform('gamma', 0.05, 1.5),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.05, 1.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.05, 1.0),
        'max_leaves': trial.suggest_int('max_leaves', 20, 80),
        'grow_policy': trial.suggest_categorical('grow_policy', ['depthwise', 'lossguide'])
    }
    
    model = xgb.XGBClassifier(**params, random_state=SEED)

    model.fit(X_train, y_train)

    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    roc_auc = auc(fpr, tpr)
    
    return roc_auc

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgb, n_trials=TRIALS, show_progress_bar=True)

print("Best parameters for XGBoost:", study_xgb.best_params)
# Out:
# [I 2025-03-04 10:11:36,812] A new study created in memory with name: no-name-681ca768-0b25-486c-84f3-648c29708647
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03-04 10:11:36,871] Trial 0 finished with value: 0.9195972066342438 and parameters: {'n_estimators': 45, 'max_depth': 7, 'learning_rate': 0.013484555791678622, 'min_child_weight': 27, 'subsample': 0.7104189766617999, 'colsample_bytree': 0.7578324654538978, 'gamma': 1.329276262218789, 'reg_alpha': 0.25656460135965425, 'reg_lambda': 0.16902362684712188, 'max_leaves': 21, 'grow_policy': 'lossguide'}. Best is trial 0 with value: 0.9195972066342438.
# [I 2025-03-04 10:11:36,905] Trial 1 finished with value: 0.9204264870931538 and parameters: {'n_estimators': 47, 'max_depth': 4, 'learning_rate': 0.0127244308396913, 'min_child_weight': 28, 'subsample': 0.7038377860672178, 'colsample_bytree': 0.8343935817425032, 'gamma': 1.4289000321108924, 'reg_alpha': 0.1754606730211744, 'reg_lambda': 0.1043992682111005, 'max_leaves': 40, 'grow_policy': 'lossguide'}. Best is trial 1 with value: 0.9204264870931538.
# [I 2025-03-04 10:11:36,969] Trial 2 finished with value: 0.9224030427734132 and parameters: {'n_estimators': 60, 'max_depth': 6, 'learning_rate': 0.0022320646833225337, 'min_child_weight': 12, 'subsample': 0.7806868681417181, 'colsample_bytree': 0.8759792783405116, 'gamma': 0.10268699381369964, 'reg_alpha': 0.16667567380924037, 'reg_lambda': 0.10398687879007949, 'max_leaves': 73, 'grow_policy': 'depthwise'}. Best is trial 2 with value: 0
 'grow_policy': 'lossguide'}. Best is trial 54 with value: 0.9345304900860456.
# [I 2025-03-04 10:11:45,943] Trial 95 finished with value: 0.9318493577752837 and parameters: {'n_estimators': 63, 'max_depth': 7, 'learning_rate': 0.03085598517044893, 'min_child_weight': 15, 'subsample': 0.7941839789782786, 'colsample_bytree': 0.6975534658501009, 'gamma': 0.12982388606248776, 'reg_alpha': 0.06594895913303869, 'reg_lambda': 0.6026147876487808, 'max_leaves': 75, 'grow_policy': 'lossguide'}. Best is trial 54 with value: 0.9345304900860456.
# [I 2025-03-04 10:11:46,074] Trial 96 finished with value: 0.9259882778401297 and parameters: {'n_estimators': 64, 'max_depth': 7, 'learning_rate': 0.011270694403069196, 'min_child_weight': 15, 'subsample': 0.8084123362839764, 'colsample_bytree': 0.7095748040631412, 'gamma': 0.14534948082489693, 'reg_alpha': 0.0539084034916926, 'reg_lambda': 0.3555630473927349, 'max_leaves': 70, 'grow_policy': 'lossguide'}. Best is trial 54 with value: 0.9345304900860456.
# [I 2025-03-04 10:11:46,190] Trial 97 finished with value: 0.9347175458286571 and parameters: {'n_estimators': 59, 'max_depth': 8, 'learning_rate': 0.041964532599507026, 'min_child_weight': 16, 'subsample': 0.7964325150575641, 'colsample_bytree': 0.6909321843893933, 'gamma': 0.15513755378774668, 'reg_alpha': 0.07620488881369394, 'reg_lambda': 0.4054712897472833, 'max_leaves': 79, 'grow_policy': 'lossguide'}. Best is trial 97 with value: 0.9347175458286571.
# [I 2025-03-04 10:11:46,310] Trial 98 finished with value: 0.933906970944008 and parameters: {'n_estimators': 57, 'max_depth': 8, 'learning_rate': 0.04605796771957631, 'min_child_weight': 15, 'subsample': 0.7983525241122004, 'colsample_bytree': 0.6753307693790382, 'gamma': 0.10131501811673929, 'reg_alpha': 0.07323085106922353, 'reg_lambda': 0.39847997637587407, 'max_leaves': 79, 'grow_policy': 'lossguide'}. Best is trial 97 with value: 0.9347175458286571.
# [I 2025-03-04 10:11:46,412] Trial 99 finished with value: 0.9330839256765183 and parameters: {'n_estimators': 57, 'max_depth': 8, 'learning_rate': 0.046695961018729325, 'min_child_weight': 14, 'subsample': 0.7696654682944044, 'colsample_bytree': 0.6576086660864526, 'gamma': 0.09489426459654675, 'reg_alpha': 0.09320322687347223, 'reg_lambda': 0.40652830348555286, 'max_leaves': 79, 'grow_policy': 'lossguide'}. Best is trial 97 with value: 0.9347175458286571.
# Best parameters for XGBoost: {'n_estimators': 59, 'max_depth': 8, 'learning_rate': 0.041964532599507026, 'min_child_weight': 16, 'subsample': 0.7964325150575641, 'colsample_bytree': 0.6909321843893933, 'gamma': 0.15513755378774668, 'reg_alpha': 0.07620488881369394, 'reg_lambda': 0.4054712897472833, 'max_leaves': 79, 'grow_policy': 'lossguide'}

# %%
print("\n=== XGBoost Results ===")

xgb_model = xgb.XGBClassifier(**study_xgb.best_params, random_state=SEED)
xgb_model.fit(X_train, y_train)

y_proba = xgb_model.predict_proba(X_test)[:, 1]

best_threshold = 0.5
best_f1 = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (y_proba >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = t

xgb_pred = (y_proba >= best_threshold).astype(int)

print(f"Best weighted F1-score: {best_f1:.4f} at threshold {best_threshold:.2f}")
print(f"Best parameters: {study_xgb.best_params}")
#print("Classification Report:\n", classification_report(y_test, xgb_pred))

fpr, tpr, _ = roc_curve(y_train, xgb_model.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, xgb_model.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

submission.rainfall=xgb_model.predict_proba(test)[:, 1]  
submission.to_csv('submission_xgb.csv',index=False)
# Out:
# === XGBoost Results ===
# Best weighted F1-score: 0.8824 at threshold 0.55
# Best parameters: {'n_estimators': 59, 'max_depth': 8, 'learning_rate': 0.041964532599507026, 'min_child_weight': 16, 'subsample': 0.7964325150575641, 'colsample_bytree': 0.6909321843893933, 'gamma': 0.15513755378774668, 'reg_alpha': 0.07620488881369394, 'reg_lambda': 0.4054712897472833, 'max_leaves': 79, 'grow_policy': 'lossguide'}
# (0.9479328431709385, 0.9347175458286571)

# %%
def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', TREES_LOWER, TREES_UPPER),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 10, 40),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 5, 20),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2']),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced', 'balanced_subsample'])
    }
    
    model = RandomForestClassifier(**params, random_state=SEED)

    model.fit(X_train, y_train)

    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    roc_auc = auc(fpr, tpr)

    return roc_auc

study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective_rf, n_trials=TRIALS, show_progress_bar=True)

print("Best parameters for Random Forest:", study_rf.best_params)
# Out:
# [I 2025-03-04 10:11:46,545] A new study created in memory with name: no-name-da8de005-4dfc-4f9b-803a-7b40aa12c6dd
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03-04 10:11:46,921] Trial 0 finished with value: 0.9188302780895373 and parameters: {'n_estimators': 52, 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.9188302780895373.
# [I 2025-03-04 10:11:47,201] Trial 1 finished with value: 0.9194163860830527 and parameters: {'n_estimators': 52, 'max_depth': 12, 'min_samples_split': 27, 'min_samples_leaf': 16, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.9194163860830527.
# [I 2025-03-04 10:11:47,539] Trial 2 finished with value: 0.9193665045516898 and parameters: {'n_estimators': 52, 'max_depth': 19, 'min_samples_split': 38, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9194163860830527.
# [I 2025-03-04 10:11:47,739] Trial 3 finished with value: 0.9220102257139294 and parameters: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 22, 'min_samples_leaf': 12, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9220102257139294.
# [I 2025-03-04 10:11:47,949] Trial 4 finished with value: 0.9156503304651452 and parameters: {'n_estimators': 42, 'max_depth': 15, 'min_samples_split': 33, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': False, 'class_weight': None}. Best is trial 3 with value: 0.9220102257139294.
# [I 2025-03-04 10:11:48,134] Trial 5 finished with value: 0.9194662676144156 and parameters: {'n_estimators': 39, 'max_depth': 5, 'min_samples_split': 30, 'min_samples_leaf': 15, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced_subsample'}. Best is trial 3 with value: 0.9220102257139294.
# [I 2025-03-04 10:11:48,430] Trial 6 finished with value: 0.9177079436338694 and parameters: {'n_estimators': 56, 'max_depth': 16, 'min_samples_split': 23, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced_subsample'}. Best is trial 3 with value: 0.9220102257139294.
# [I 2025-03-04 10:11:48,676] Trial 7 finished with value: 0.9211871804464398 and parameters: {'n_estimators': 47, 'max_depth': 16, 'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 3 with value: 0.9220102257139294.
# [I 2025-03-04 10:11:48,840] Trial 8 finished with value: 0.9130440204514279 and parameters: {'n_estimators': 41, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'class_weight': None}. Best is trial 3 with value: 0.9220102257139294.
# [I 2025-03-04 10:11:49,118] Trial 9 finished with value: 0.919765556802594 and parameters: {'n_estimators': 52, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None}. Best is trial 3 with value: 0.9220102257139294.
# [I 2025-03-04 10:11:49,328] Trial 10 finished with value: 0.9231699713181195 and parameters: {'n_estimators': 62, 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9231699713181195.
# [I 2025-03-04 10:11:49,576] Trial 11 finished with value: 0.9209751839381468 and parameters: {'n_estimators': 64, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9231699713181195.
# [I 2025-03-04 10:11:49,800] Trial 12 finished with value: 0.9183938146901109 and parameters: {'n_estimators': 64, 'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9231699713181195.
# [I 2025-03-04 10:11:49,928] Trial 13 finished with value: 0.9225215114104004 and parameters: {'n_estimators': 34, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9231699713181195.
# [I 2025-03-04 10:11:50,091] Trial 14 finished with value: 0.9151390447686744 and parameters: {'n_estimators': 32, 'max_depth': 9, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9231699713181195.
# [I 2025-03-04 10:11:50,237] Trial 15 finished with value: 0.9199900236937274 and parameters: {'n_estimators': 32, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9231699713181195.
# [I 2025-03-04 10:11
 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (y_proba >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = t

rf_pred = (y_proba >= best_threshold).astype(int)

print(f"Best weighted F1-score: {best_f1:.4f} at threshold {best_threshold:.2f}")
print(f"Best parameters: {study_rf.best_params}")
#print("Classification Report:\n", classification_report(y_test, rf_pred))

fpr, tpr, _ = roc_curve(y_train, rf_model.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, rf_model.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

submission.rainfall=rf_model.predict_proba(test)[:, 1]  
submission.to_csv('submission_rf.csv',index=False)
# Out:
# === Random Forest Results ===
# Best weighted F1-score: 0.8842 at threshold 0.35
# Best parameters: {'n_estimators': 56, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced'}
# (0.9695916076868458, 0.9236563162489088)

# %%
print("\n=== Voting Classifier Results ===")

voting_soft = VotingClassifier(
    estimators=[
        ('lgbm', lgbm_model),
        ('xgb', xgb_model),
        ('rf', rf_model),
        ('ef', extra_trees_model)
    ],
    voting='soft'
)

voting_hard = VotingClassifier(
    estimators=[
        ('lgbm', lgbm_model),
        ('xgb', xgb_model),
        ('rf', rf_model),
        ('ef', extra_trees_model)
    ],
    voting='hard'
)

# Soft Voting
voting_soft.fit(X_train, y_train)
soft_proba = voting_soft.predict_proba(X_test)[:, 1]

best_threshold_soft = 0.5
best_f1_soft = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (soft_proba >= t).astype(int)
    f1 = f1_score(y_test, y_pred_temp, average='weighted')
    if f1 > best_f1_soft:
        best_f1_soft = f1
        best_threshold_soft = t

soft_pred = (soft_proba >= best_threshold_soft).astype(int)

print("\nSoft Voting:")
print(f"Best weighted F1-score: {best_f1_soft:.4f} at threshold {best_threshold_soft:.2f}")
#print("Classification Report:\n", classification_report(y_test, soft_pred))

fpr, tpr, _ = roc_curve(y_train, voting_soft.predict_proba(X_train)[:, 1])
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, voting_soft.predict_proba(X_test)[:, 1])
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))

# Hard Voting
voting_hard.fit(X_train, y_train)
hard_pred = voting_hard.predict(X_test)

print("\nHard Voting:")
print(f"Weighted F1-score: {f1_score(y_test, hard_pred, average='weighted'):.4f}")
#print("Classification Report:\n", classification_report(y_test, hard_pred))


fpr, tpr, _ = roc_curve(y_train, np.mean([clf.predict_proba(X_train)[:, 1] for clf in voting_hard.estimators_], axis=0))
roc_auc_train = auc(fpr, tpr)

fpr, tpr, _ = roc_curve(y_test, np.mean([clf.predict_proba(X_test)[:, 1] for clf in voting_hard.estimators_], axis=0))
roc_auc_test = auc(fpr, tpr)

print((roc_auc_train,roc_auc_test))
# Out:
# === Voting Classifier Results ===
#
# Soft Voting:
# Best weighted F1-score: 0.8868 at threshold 0.45
# (0.9610985134794658, 0.9341813193665045)
#
# Hard Voting:
# Weighted F1-score: 0.8819
# (0.9610985134794658, 0.9341813193665045)

# %%
soft_probabilities = voting_soft.predict_proba(test)[:, 1]  

hard_probabilities = np.mean([clf.predict_proba(test)[:, 1] for clf in voting_hard.estimators_], axis=0)

print("Soft Probabilities Shape:", soft_probabilities.shape)
print("Hard Probabilities Shape:", hard_probabilities.shape)
# Out:
# Soft Probabilities Shape: (730,)
# Hard Probabilities Shape: (730,)

# %%
submission.rainfall=soft_probabilities
submission.to_csv('submission_soft.csv',index=False)

# %%
submission.rainfall=hard_probabilities
submission.to_csv('submission_hard.csv',index=False)

# %%
submission.rainfall=(lgbm_model.predict_proba(test)[:, 1]+xgb_model.predict_proba(test)[:, 1]+rf_model.predict_proba(test)[:, 1]+soft_probabilities+hard_probabilities+extra_trees_model.predict_proba(test)[:, 1])/6
submission.to_csv('submission.csv',index=False)
