# %%
#!pip install optuna[visualization]
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import holidays

# %%
df=pd.read_csv('train.csv')
df_=pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    id        date country              store             product  num_sold
# 0   0  2010-01-01  Canada  Discount Stickers   Holographic Goose       NaN
# 1   1  2010-01-01  Canada  Discount Stickers              Kaggle     973.0
# 2   2  2010-01-01  Canada  Discount Stickers        Kaggle Tiers     906.0
# 3   3  2010-01-01  Canada  Discount Stickers            Kerneler     423.0
# 4   4  2010-01-01  Canada  Discount Stickers  Kerneler Dark Mode     491.0

# %%
def transform(df):
    df.date=pd.to_datetime(df.date)
   ## Add Holidays
    extract_country = dict(
        zip(np.sort(df.country.unique()), ["CA", "FI", "IT", "KE", "NO", "SG"]))
    holidays_dict = {
        c: holidays.country_holidays(a, years=range(2010, 2020))
        for c, a in extract_country.items()
    }
    df["is_holiday"] = 0
    for c in holidays_dict:
        df.loc[df.country == c, "is_holiday"] = df.date.isin(holidays_dict[c]).astype(int)


    df["weekday_sv"] = df["date"].dt.strftime("%a").astype("category")
    df["weekday_num"] = df["date"].dt.strftime("%w").astype("category")
    df["day_of_month"] = df["date"].dt.strftime("%d").astype("category")
    df["month_name_sv"] = df["date"].dt.strftime("%b").astype("category")
    df["month_num"] = df["date"].dt.strftime("%m").astype("int")
    df["year_fv"] = df["date"].dt.strftime("%Y").astype("int")
    df["day_number_year"] = df["date"].dt.strftime("%j").astype("int")
    df["week_number_year"] = df["date"].dt.strftime("%W").astype("category")
    df["country"] = df["country"].astype("category")
    df["store"] = df["store"].astype("category")
    df["product"] = df["product"].astype("category")
    df["is_holiday"] = df["is_holiday"].astype("category")
    df["year_sin"] = np.sin(2 * np.pi * df["year_fv"] / 7)
    df["year_cos"] = np.cos(2 * np.pi * df["year_fv"] / 7)
    df["month_sin"] = np.sin(2 * np.pi * df["month_num"] / 12)
    df["month_cos"] = np.cos(2 * np.pi * df["month_num"] / 12)
    return df

df=transform(df)
df_=transform(df_)

# %%
df=df[~(df.num_sold.isna())]

# %%
from sklearn.preprocessing import LabelEncoder

pd.set_option('display.max_columns', None)
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98550 entries, 0 to 98549
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                98550 non-null  int64
#  1   date              98550 non-null  datetime64[ns]
#  2   country           98550 non-null  category
#  3   store             98550 non-null  category
#  4   product           98550 non-null  category
#  5   is_holiday        98550 non-null  category
#  6   weekday_sv        98550 non-null  category
#  7   weekday_num       98550 non-null  category
#  8   day_of_month      98550 non-null  category
#  9   month_name_sv     98550 non-null  category
#  10  month_num         98550 non-null  int32
#  11  year_fv           98550 non-null  int32
#  12  day_number_year   98550 non-null  int32
#  13  week_number_year  98550 non-null  category
#  14  year_sin          98550 non-null  float64
#  15  year_cos          98550 non-null  float64
#  16  month_sin         98550 non-null  float64
#  17  month_cos         98550 non-null  float64
# dtypes: category(9), datetime64[ns](1), float64(4), int32(3), int64(1)
# memory usage: 6.5 MB

# %%
for i in ['product','store','country', 'weekday_sv', 'month_name_sv']:
  g=df.groupby(i)['num_sold'].median()
  df[f'impute{i}']=df[i].map(g)
  df_[f'impute{i}']=df_[i].map(g)
# Out:
# C:\Users\dipty\AppData\Local\Temp\ipykernel_16096\3802713132.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g=df.groupby(i)['num_sold'].median()
# C:\Users\dipty\AppData\Local\Temp\ipykernel_16096\3802713132.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g=df.groupby(i)['num_sold'].median()
# C:\Users\dipty\AppData\Local\Temp\ipykernel_16096\3802713132.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g=df.groupby(i)['num_sold'].median()
# C:\Users\dipty\AppData\Local\Temp\ipykernel_16096\3802713132.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g=df.groupby(i)['num_sold'].median()
# C:\Users\dipty\AppData\Local\Temp\ipykernel_16096\3802713132.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g=df.groupby(i)['num_sold'].median()

# %%
for i in ['product','store','country', 'weekday_sv', 'month_name_sv']:
  le=LabelEncoder()
  df[i]=le.fit_transform(df[i])
  df_[i]=le.transform(df_[i])


for i in df.columns[df.dtypes=='category']:
  df[i]=df[i].astype('float')
  df_[i]=df_[i].astype('float')


#df['impute']=(df['imputecountry']+df['imputestore']+df['imputeproduct']+df['imputeis_holiday']+df['imputeweekday_sv']+df['imputeweekday_num']+df['imputeday_of_month']+df['imputemonth_name_sv']+df['imputeweek_number_year'])/9
#df_['impute']=(df_['imputecountry']+df_['imputestore']+df_['imputeproduct']+df_['imputeis_holiday']+df_['imputeweekday_sv']+df_['imputeweekday_num']+df_['imputeday_of_month']+df_['imputemonth_name_sv']+df_['imputeweek_number_year'])/9

#df=df.drop(columns=['imputecountry','imputestore','imputeproduct','imputeis_holiday','imputeweekday_sv','imputeweekday_num','imputeday_of_month','imputemonth_name_sv','imputeweek_number_year'])
#df_=df_.drop(columns=['imputecountry','imputestore','imputeproduct','imputeis_holiday','imputeweekday_sv','imputeweekday_num','imputeday_of_month','imputemonth_name_sv','imputeweek_number_year'])

# %%
df.head()
# Out:
#    id       date  country  store  product  num_sold  is_holiday  weekday_sv  \
# 1   1 2010-01-01        0      0        1     973.0         1.0           0
# 2   2 2010-01-01        0      0        2     906.0         1.0           0
# 3   3 2010-01-01        0      0        3     423.0         1.0           0
# 4   4 2010-01-01        0      0        4     491.0         1.0           0
# 5   5 2010-01-01        0      2        0     300.0         1.0           0
#
#    weekday_num  day_of_month  month_name_sv  month_num  year_fv  \
# 1          5.0           1.0              4          1     2010
# 2          5.0           1.0              4          1     2010
# 3          5.0           1.0              4          1     2010
# 4          5.0           1.0              4          1     2010
# 5          5.0           1.0              4          1     2010
#
#    day_number_year  week_number_year  year_sin  year_cos  month_sin  \
# 1                1               0.0  0.781831   0.62349        0.5
# 2                1               0.0  0.781831   0.62349        0.5
# 3                1               0.0  0.781831   0.62349        0.5
# 4                1               0.0  0.781831   0.62349        0.5
# 5                1               0.0  0.781831   0.62349        0.5
#
#    month_cos  imputeproduct  imputestore  imputecountry  imputeweekday_sv  \
# 1   0.866025         1215.0        380.0          731.0             610.0
# 2   0.866025         1007.0        380.0          731.0             610.0
# 3   0.866025          537.0        380.0          731.0             610.0
# 4   0.866025          617.0        380.0          731.0             610.0
# 5   0.866025          192.0        744.0          731.0             610.0
#
#    imputemonth_name_sv
# 1                614.0
# 2                614.0
# 3                614.0
# 4                614.0
# 5                614.0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(columns=['id','date','num_sold']),np.log(df.num_sold),test_size=.2,random_state=95)

# %%
#!pip install tensorflow

from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=l2(0.01)),
    BatchNormalization(),  # Batch Normalization after the Dense layer
    Dropout(0.3),

    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, activation='relu', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(1)  # Output layer for regression
])

# Custom MAPE implementation
def mean_absolute_percentage_error(y_true, y_pred):
    y_true = K.clip(y_true, K.epsilon(), None)  # Avoid division by zero
    return K.mean(K.abs((y_true - y_pred) / y_true)) * 100

# Compile the model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae', mean_absolute_percentage_error])

# Callbacks for training
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=200,  # Use a high number for experimentation; EarlyStopping will halt early if needed
    batch_size=32,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/200
# c:\Users\dipty\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 8.3092 - mae: 1.7586 - mean_absolute_percentage_error: 33.4406 - val_loss: 0.1451 - val_mae: 0.1739 - val_mean_absolute_percentage_error: 3.6571 - learning_rate: 0.0010
# Epoch 2/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.5935 - mae: 0.5718 - mean_absolute_percentage_error: 10.8162 - val_loss: 0.1204 - val_mae: 0.2128 - val_mean_absolute_percentage_error: 4.3514 - learning_rate: 0.0010
# Epoch 3/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 0.4680 - mae: 0.5049 - mean_absolute_percentage_error: 9.6321 - val_loss: 0.1253 - val_mae: 0.2084 - val_mean_absolute_percentage_error: 4.3037 - learning_rate: 0.0010
# Epoch 4/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.3863 - mae: 0.4566 - mean_absolute_percentage_error: 8.9002 - val_loss: 0.1978 - val_mae: 0.3134 - val_mean_absolute_percentage_error: 6.1699 - learning_rate: 0.0010
# Epoch 5/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.3278 - mae: 0.4186 - mean_absolute_percentage_error: 8.2813 - val_loss: 0.1608 - val_mae: 0.3073 - val_mean_absolute_percentage_error: 5.4124 - learning_rate: 0.0010
# Epoch 6/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.2991 - mae: 0.3963 - mean_absolute_percentage_error: 7.9936 - val_loss: 0.1473 - val_mae: 0.2824 - val_mean_absolute_percentage_error: 5.3879 - learning_rate: 0.0010
# Epoch 7/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2708 - mae: 0.3753 - mean_absolute_percentage_error: 7.6662
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.2708 - mae: 0.3753 - mean_absolute_percentage_error: 7.6662 - val_loss: 0.1504 - val_mae: 0.2848 - val_mean_absolute_percentage_error: 5.0111 - learning_rate: 0.0010
# Epoch 8/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.2376 - mae: 0.3590 - mean_absolute_percentage_error: 7.3718 - val_loss: 0.0695 - val_mae: 0.1941 - val_mean_absolute_percentage_error: 3.6033 - learning_rate: 2.0000e-04
# Epoch 9/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.2180 - mae: 0.3507 - mean_absolute_percentage_error: 7.2034 - val_loss: 0.0889 - val_mae: 0.2241 - val_mean_absolute_percentage_error: 4.6560 - learning_rate: 2.0000e-04
# Epoch 10/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.2206 - mae: 0.3504 - mean_absolute_percentage_error: 7.2259 - val_loss: 0.0691 - val_mae: 0.1900 - val_mean_absolute_percentage_error: 4.2095 - learning_rate: 2.0000e-04
# Epoch 11/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.2108 - mae: 0.3438 - mean_absolute_percentage_error: 7.0773 - val_loss: 0.0556 - val_mae: 0.1604 - val_mean_absolute_percentage_error: 3.6788 - learning_rate: 2.0000e-04
# Epoch 12/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.2053 - mae: 0.3419 - mean_absolute_percentage_error: 7.0138 - val_loss: 0.0477 - val_mae: 0.1502 - val_mean_absolute_percentage_error: 3.1401 - learning_rate: 2.0000e-04
# Epoch 13/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.2101 - mae: 0.3454 - mean_absolute_percentage_error: 7.1276 - val_loss: 0.0859 - val_mae: 0.2302 - val_mean_absolute_percentage_error: 4.1731 - learning_rate: 2.0000e-04
# Epoch 14/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.2108 - mae: 0.3429 - mean_absolute_percentage_error: 7.0867 - val_loss: 0.0597 - val_mae: 0.1728 - val_mean_absolute_percentage_error: 3.6794 - learning_rate: 2.0000e-04
# Epoch 15/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.2029 - mae: 0.3406 - mean_absolute_percentage_error: 7.0156 - val_loss: 0.0485 - val_mae: 0.1507 - val_mean_absolute_percentage_error: 3.2590 - learning_rate: 2.0000e-04
# Epoch 16/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.2019 - mae: 0.3386 - mean_absolute_percentage_error: 6.9435 - val_loss: 0.0630 - val_mae: 0.1862 - val_mean_absolute_percentage_error: 3.3831 - learning_rate: 2.0000e-04
# Epoch 17/200
# 5517/5532 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2003 - mae: 0.3370 - mean_absolute_percentage_error: 6.9287
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.2003 - mae: 0.3370 - mean_absolute_percentage_error: 6.9288 - val_loss: 0.1383 - val_mae: 0.3011 - val_mean_absolute_percentage_error: 5.1965 - learning_rate: 2.0000e-04
# Epoch 18/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.1951 - mae: 0.3335 - mean_absolute_percentage_error: 6.8363 - val_loss: 0.0877 - val_mae: 0.2377 - val_mean_absolute_percentage_error: 4.3100 - learning_rate: 4.0000e-05
# Epoch 19/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.1930 - mae: 0.3330 - mean_absolute_percentage_error: 6.8448 - val_loss: 0.0973 - val_mae: 0.2588 - val_mean_absolute_percentage_error: 4.5270 - learning_rate: 4.0000e-05
# Epoch 20/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - loss: 0.1899 - mae: 0.3320 - mean_absolute_percentage_error: 6.8091 - val_loss: 0.0428 - val_mae: 0.1522 - val_mean_absolute_percentage_error: 3.0374 - learning_rate: 4.0000e-05
# Epoch 21/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - loss: 0.1891 - mae: 0.3292 - mean_absolute_percentage_error: 6.7512 - val_loss: 0.0624 - val_mae: 0.1960 - val_mean_absolute_percentage_error: 3.5374 - learning_rate: 4.0000e-05
# Epoch 22/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.1875 - mae: 0.3290 - mean_absolute_percentage_error: 6.7763 - val_loss: 0.0457 - val_mae: 0.1620 - val_mean_absolute_percentage_error: 3.0746 - learning_rate: 4.0000e-05
# Epoch 23/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.1850 - mae: 0.3294 - mean_absolute_percentage_error: 6.7867 - val_loss: 0.0727 - val_mae: 0.2147 - val_mean_absolute_percentage_error: 3.8523 - learning_rate: 4.0000e-05
# Epoch 24/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.1838 - mae: 0.3284 - mean_absolute_percentage_error: 6.6969 - val_loss: 0.0609 - val_mae: 0.1936 - val_mean_absolute_percentage_error: 3.5975 - learning_rate: 4.0000e-05
# Epoch 25/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1868 - mae: 0.3298 - mean_absolute_percentage_error: 6.7609
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.1868 - mae: 0.3298 - mean_absolute_percentage_error: 6.7609 - val_loss: 0.0550 - val_mae: 0.1816 - val_mean_absolute_percentage_error: 3.3005 - learning_rate: 4.0000e-05
# Epoch 26/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.1806 - mae: 0.3274 - mean_absolute_percentage_error: 6.6750 - val_loss: 0.0559 - val_mae: 0.1851 - val_mean_absolute_percentage_error: 3.4129 - learning_rate: 8.0000e-06
# Epoch 27/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.1796 - mae: 0.3257 - mean_absolute_percentage_error: 6.6621 - val_loss: 0.0465 - val_mae: 0.1649 - val_mean_absolute_percentage_error: 3.1546 - learning_rate: 8.0000e-06
# Epoch 28/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.1804 - mae: 0.3266 - mean_absolute_percentage_error: 6.6902 - val_loss: 0.0541 - val_mae: 0.1816 - val_mean_absolute_percentage_error: 3.4164 - learning_rate: 8.0000e-06
# Epoch 29/200
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.1862 - mae: 0.3311 - mean_absolute_percentage_error: 6.7899 - val_loss: 0.0514 - val_mae: 0.1775 - val_mean_absolute_percentage_error: 3.2894 - learning_rate: 8.0000e-06
# Epoch 30/200
# 5523/5532 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1813 - mae: 0.3271 - mean_absolute_percentage_error: 6.6980
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 5532/5532 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.1813 - mae: 0.3271 - mean_absolute_percentage_error: 6.6981 - val_loss: 0.0535 - val_mae: 0.1808 - val_mean_absolute_percentage_error: 3.3412 - learning_rate: 8.0000e-06
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.

# %%
loss, mae, mape = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss (MSE): {loss:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test MAPE: {mape:.4f}")

from sklearn.metrics import mean_absolute_percentage_error as MAPE
# Predictions
y_pred = model.predict(X_test)


# Calculate RMSE
mape = MAPE(y_test, y_pred)
print(f"MAPE: {mape:.4f}")
# Out:
# Test Loss (MSE): 0.0428
# Test MAE: 0.1522
# Test MAPE: 3.0374
# 1383/1383 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# MAPE: 0.0304

# %%
df_['num_sold']=np.exp(model.predict(df_.drop(columns=['id','date'])))
df_[['id','num_sold']].set_index('id').to_csv('submission.csv')
# Out:
# 3080/3080 ━━━━━━━━━━━━━━━━━━━━ 3s 967us/step

# %%
import lightgbm
from lightgbm import LGBMRegressor


def lgbm_objective(trial):

    lgbm_params = {
        "n_estimators": 2000,
        "subsample": trial.suggest_float("subsample", 0.3, 0.9),
        "min_child_samples": trial.suggest_int("min_child_samples", 60, 100),
        "max_depth": trial.suggest_int("max_depth", 4, 25),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1),
        "lambda_l1": trial.suggest_float("lambda_l1", 0.001, 0.1),
        "lambda_l2": trial.suggest_float("lambda_l2", 0.001, 0.1),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0)

    }

    lgbm_model = LGBMRegressor(**lgbm_params, random_state=95, verbose=-1)

    lgbm_model.fit(X_train, y_train)
    y_pred = np.exp(lgbm_model.predict(X_test))
    return mean_absolute_percentage_error(np.exp(y_test), y_pred)

# %%
#!pip install optuna
#!pip install ipywidgets --upgrade

import optuna

study_LGBM = optuna.create_study(study_name="LGBM_Kaggle", direction="minimize")
optuna.logging.set_verbosity(optuna.logging.WARNING)
study_LGBM.optimize(lgbm_objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2025-01-10 09:26:21,083] A new study created in memory with name: LGBM_Kaggle
# Requirement already satisfied: ipywidgets in c:\users\dipty\anaconda3\lib\site-packages (7.6.5)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: colorama in c:\users\dipty\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\dipty\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\dipty\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\dipty\appdata\roaming\python\python311\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.8 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/139.8 kB ? eta -:--:--
#    ----------------- --------------------- 61.4/139.8 kB 825.8 kB/s eta 0:00:01
#    -------------------------------------- - 133.1/139.8 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 139.8/139.8 kB 1.0 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#    ---------------------------------------- 0.0/214.4 kB ? eta -:--:--
#    ---------------------- ----------------- 122.9/214.4 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 214.4/214.4 kB 4.3 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------ --------------------------------- 0.4/2.3 MB 12.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.3 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.0/2.3 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 14.9 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.2
#     Uninstalling widgetsnbextension-3.5.2:
#       Successfully uninstalled widgetsnbextension-3.5.2
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.9
#     Uninstalling jupyterlab-widgets-3.0.9:
#       Successfully uninstalled jupyterlab-widgets-3.0.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.5
#     Uninstalling ipywidgets-7.6.5:
#       Successfully uninstalled ipywidgets-7.6.5
# Successfully installed ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
print("Best trial:", study_LGBM.best_trial)
# Out:
# Best trial: FrozenTrial(number=94, state=1, values=[4.188229698373198], datetime_start=datetime.datetime(2025, 1, 10, 9, 36, 38, 364354), datetime_complete=datetime.datetime(2025, 1, 10, 9, 36, 43, 692249), params={'subsample': 0.6688620970553752, 'min_child_samples': 64, 'max_depth': 20, 'learning_rate': 0.09985470161579914, 'lambda_l1': 0.012482031541752786, 'lambda_l2': 0.06679435646031585, 'colsample_bytree': 0.4981504616325807}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'subsample': FloatDistribution(high=0.9, log=False, low=0.3, step=None), 'min_child_samples': IntDistribution(high=100, log=False, low=60, step=1), 'max_depth': IntDistribution(high=25, log=False, low=4, step=1), 'learning_rate': FloatDistribution(high=0.1, log=False, low=0.01, step=None), 'lambda_l1': FloatDistribution(high=0.1, log=False, low=0.001, step=None), 'lambda_l2': FloatDistribution(high=0.1, log=False, low=0.001, step=None), 'colsample_bytree': FloatDistribution(high=1.0, log=False, low=0.3, step=None)}, trial_id=94, value=None)

# %%
print("Best parameters:", study_LGBM.best_params)
# Out:
# Best parameters: {'subsample': 0.6688620970553752, 'min_child_samples': 64, 'max_depth': 20, 'learning_rate': 0.09985470161579914, 'lambda_l1': 0.012482031541752786, 'lambda_l2': 0.06679435646031585, 'colsample_bytree': 0.4981504616325807}

# %%
lgbm_final = LGBMRegressor(**study_LGBM.best_params,n_estimators= 2000,random_state=95,verbose=-1)
lgbm_final.fit(X_train, y_train)
y_pred = np.exp(lgbm_final.predict(X_test))
print("MAPE:",mean_absolute_percentage_error(np.exp(y_test), y_pred))
# Out:
# MAPE: tf.Tensor(4.188229698373198, shape=(), dtype=float64)

# %%
df_.columns
# Out:
# Index(['id', 'date', 'country', 'store', 'product', 'is_holiday', 'weekday_sv',
#        'weekday_num', 'day_of_month', 'month_name_sv', 'month_num', 'year_fv',
#        'day_number_year', 'week_number_year', 'year_sin', 'year_cos',
#        'month_sin', 'month_cos', 'imputeproduct', 'imputestore',
#        'imputecountry', 'imputeweekday_sv', 'imputemonth_name_sv', 'num_sold'],
#       dtype='object')

# %%
df_['num_sold']=np.exp(lgbm_final.predict(df_.drop(columns=['id','date','num_sold'])))
df_[['id','num_sold']].set_index('id').to_csv('submission2.csv')

# %%
import xgboost as xgb

def xgb_objective(trial):
    # Hyperparameter search space
    param = {
        'booster': trial.suggest_categorical('booster', ['gbtree', 'dart']),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'min_child_weight': trial.suggest_float('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
    }

    # Fit model
    model = xgb.XGBRegressor(**param, random_state=42, use_label_encoder=False)
    model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)

    # Predict and evaluate
    preds = model.predict(X_test)
    mape = MAPE(y_test, preds)
    return mape

# %%
study_XGB = optuna.create_study(direction='minimize')  # Minimize RMSE
study_XGB.optimize(xgb_objective, n_trials=100, show_progress_bar=True)  # Run for 50 trials or 10 minutes

# Best parameters and score
print("Best Trial:")
print(f"  Value: {study_XGB.best_trial.value:.4f}")
print("  Params: ")
for key, value in study_XGB.best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [09:41:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [09:43:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [09:43:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [09:43:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [09:43:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:09:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:09:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:09:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:10:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:10:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:10:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:10:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:26:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:29:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:48:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:48:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:09:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:31:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [12:03:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [12:27:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [12:52:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [13:46:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [13:46:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:13:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:13:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:38:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:38:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:38:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:38:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:38:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:39:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:39:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:39:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:39:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:39:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:41:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:41:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:41:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:41:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:41:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:42:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:42:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:42:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:09:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:09:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:09:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:10:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:10:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:10:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:20:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:20:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:27:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:27:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:45:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:46:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:46:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:46:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:46:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:46:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:47:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:47:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:47:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:47:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:47:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:48:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:48:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:48:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:48:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:48:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:48:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:49:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:49:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:49:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:49:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:49:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:49:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:50:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:50:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:50:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:50:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:50:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:50:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:50:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:51:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:51:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:51:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:51:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:51:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:51:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:51:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:52:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dipty\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:52:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Trial:
#   Value: 0.0085
#   Params:
#     booster: gbtree
#     learning_rate: 0.045300880797941936
#     n_estimators: 324
#     max_depth: 9
#     min_child_weight: 6.5381219847205125
#     gamma: 0.006330078578806524
#     subsample: 0.8954359399471373
#     colsample_bytree: 0.5181047026695352
#     lambda: 0.22996906744236614
#     alpha: 0.0014508605418352024

# %%
xgb_final = xgb.XGBRegressor(**study_XGB.best_params,n_estimators= 2000,random_state=95,verbose=-1)
xgb_final.fit(X_train, y_train)
y_pred = np.exp(xgb_final.predict(X_test))
print("MAPE:",mean_absolute_percentage_error(np.exp(y_test), y_pred))

# %%
df_['num_sold']=np.exp(xgb_final.predict(df_.drop(columns=['id','date','num_sold'])))
df_[['id','num_sold']].set_index('id').to_csv('submission3.csv')

# %%
from optuna.visualization import plot_optimization_history, plot_param_importances

# Plot optimization history
plot_optimization_history(study_LGBM).show()

# Plot parameter importance
plot_param_importances(study_LGBM).show()

# %%
from optuna.visualization import plot_optimization_history, plot_param_importances

# Plot optimization history
plot_optimization_history(study_XGB).show()

# Plot parameter importance
plot_param_importances(study_XGB).show()

# %%
One,Two,three=pd.read_csv('submission.csv'),pd.read_csv('submission2.csv'),pd.read_csv('submission3.csv')
df_['num_sold']=(One.num_sold+Two.num_sold+three.num_sold)/3
df_[['id','num_sold']].set_index('id').to_csv('submissionall.csv')
