# %% [markdown]
# # Interview Questions

# %% [markdown]
# ### 1. **Question:**
# You run **PCA** on a dataset to find a low-dimensional representation. During analysis, you discover the top 2 principal components capture roughly 80% variance, but the next few individually capture small amounts, which collectively add up to 15%. You only keep the top 2 anyway. Which subtle risk might you face?
#
# - A) By ignoring those lower-variance components, you remove only random noise
# - B) There’s a possibility that some important but lower-variance directions related to class distinctions or anomalies are lost, reducing downstream performance
# - C) The principal components will automatically produce better classification accuracy
# - D) PCA ensures all class boundaries are maintained in the top 2 components
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) There’s a possibility that some important but lower-variance directions related to class distinctions or anomalies are lost, reducing downstream performance
#
# **Explanation:**
# While PCA focuses on high-variance directions, those smaller-variance axes sometimes contain crucial signals (e.g., classes or outliers). Discarding them purely based on variance may overlook relevant features, harming performance in tasks like classification or anomaly detection.
#
#
# ---
#
# ### 2. **Question:**
# You apply **t-SNE** to visualize a high-dimensional dataset in 2D. Observing the 2D plot, you see several distinct clusters well-spaced from each other. Which subtlety challenges concluding that these groupings are truly separate clusters in the original space?
#
# - A) t-SNE never reveals any cluster structure
# - B) t-SNE is guaranteed to preserve global distances, so the 2D spacing must reflect actual separation
# - C) t-SNE strongly preserves local neighborhoods but can artificially expand or compress global distances, so widely spaced 2D clusters might not be truly far apart originally
# - D) The 2D layout must represent an exact partition for classification
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  C) t-SNE strongly preserves local neighborhoods but can artificially expand or compress global distances, so widely spaced 2D clusters might not be truly far apart originally
#
# **Explanation:**
# t-SNE can cause visually distinct clusters even if global separation is not large in the original high-dimensional space. It emphasizes local structure and may distort how different clusters appear relative to each other globally. This can be misleading if interpreted as absolute cluster separations.
#
#
# ---
#
# ### 3. **Question:**
# Using **K-Means** for clustering, you find that for some runs with random initialization, the algorithm converges to suboptimal partitions. You switch to **K-Means++** but still occasionally get varied outcomes. Why might that happen?
#
# - A) K-Means++ ensures the same solution in every run
# - B) Even with improved centroid seeding, K-Means remains a local optimization method, so different runs can yield different local minima
# - C) K-Means++ requires the number of clusters to be 1
# - D) If K-Means++ seeds are spread out, it always merges into one big cluster
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) Even with improved centroid seeding, K-Means remains a local optimization method, so different runs can yield different local minima
#
# **Explanation:**
# K-Means++ just improves the chances of a good start, reducing the likelihood of poor local minima. But it’s still an iterative method that can converge differently if the data has multiple local solutions or complex distributions. Repeated runs might still produce distinct partitions.
#
#
# ---
#
# ### 4. **Question:**
# You suspect your data forms **non-spherical** clusters. If you apply **K-Means** naively, you get mediocre results. Which method might yield more natural groupings, and why?
#
# - A) Standard hierarchical clustering that only merges pairs in a single chain
# - B) **GMM** or DBSCAN, because they can model clusters with arbitrary shapes or densities, not just spherical lumps around centroids
# - C) K-Means++ but set k to 1
# - D) Linear regression
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) **GMM** or DBSCAN, because they can model clusters with arbitrary shapes or densities, not just spherical lumps around centroids
#
# **Explanation:**
# K-Means imposes a spherical cluster assumption. If clusters are elliptical or irregular, a GMM with flexible covariance or a density-based approach like DBSCAN can capture these shapes more naturally, producing better cluster fits.
#
#
# ---
#
# ### 5. **Question:**
# You have a dataset containing multiple subgroups that differ in scale and density. You attempt **DBSCAN** with certain $\epsilon$ and minPts values, but it lumps some distinct clusters together. Which revision might help separate them better?
#
# - A) Use a smaller $\epsilon$ to reduce the radius for core points, so distinct dense regions remain separate rather than merging
# - B) Use a larger $\epsilon$ so that everything merges into a single cluster
# - C) Increase minPts until no clusters are formed
# - D) Switch to linear regression
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  A) Use a smaller $\epsilon$ to reduce the radius for core points, so distinct dense regions remain separate rather than merging
#
# **Explanation:**
# If $\epsilon$ is too large, DBSCAN might unify clusters that are not truly adjacent. A smaller $\epsilon$ keeps clusters with different densities separate. Adjusting minPts can also help, but typically lowering $\epsilon$ can refine cluster boundaries.
#
#
# ---
#
# ### 6. **Question:**
# **Gaussian Mixture Model (GMM)** clustering found 3 Gaussian components. However, the dataset has outliers that are far from all cluster centers. If you want to explicitly mark some points as anomalies rather than forcing them into a cluster, how might you handle it?
#
# - A) GMM always assigns a nonzero probability to every point, so you’d interpret extremely low likelihood points (across all components) as anomalies
# - B) GMM strictly rejects points if they are far
# - C) GMM can only produce spherical clusters
# - D) GMM never requires a number of clusters
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  A) GMM always assigns a nonzero probability to every point, so you’d interpret extremely low likelihood points (across all components) as anomalies
#
# **Explanation:**
# A GMM will give each point a probability under each Gaussian. Outliers that are far from all means have low overall likelihood. You can set a threshold on that combined probability to flag them as anomalies or out-of-distribution points.
#
#
# ---
#
# ### 7. **Question:**
# You perform **hierarchical clustering** on large data using an agglomerative approach. The resulting dendrogram is quite deep and confusing. Which advanced strategy can help interpret or finalize clusters?
#
# - A) Use a random threshold to slice the dendrogram
# - B) Rely on absolute cluster counts from K-Means
# - C) Look for a natural “big jump” in linkage distance when merging clusters, or use a known measure (like cophenetic correlation) to decide a cutting level
# - D) Always keep all points separate
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  C) Look for a natural “big jump” in linkage distance when merging clusters, or use a known measure (like cophenetic correlation) to decide a cutting level
#
# **Explanation:**
# In hierarchical clustering, deciding where to “cut” the dendrogram can be subjective. People often look for large merges in the distance metric or a measure that indicates a stable cluster separation level.
#
#
# ---
#
# ### 8. **Question:**
# In **anomaly detection** with high-dimensional data, applying PCA to reduce dimension and then using the reconstruction error for anomalies is common. Which subtlety can cause you to miss certain outliers?
#
# - A) Outliers always appear in the top principal components
# - B) If an outlier aligns with the main variance directions or if the actual anomalies manifest in low-variance components you discard, you might misclassify them as normal
# - C) Reconstruction error is always zero
# - D) PCA automatically sets outliers to zero
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) If an outlier aligns with the main variance directions or if the actual anomalies manifest in low-variance components you discard, you might misclassify them as normal
#
# **Explanation:**
# If an outlier lies in a high-variance direction or is overshadowed by the dominant PCs, it may produce a relatively small reconstruction error, or if the anomalies are in directions with relatively small variance that get truncated, the method can fail to flag them.
#
#
# ---
#
# ### 9. **Question:**
# You want a **manifold-based** dimensionality reduction method focusing on local distances, but t-SNE is too slow for very large data. Another method is UMAP or **Isomap**. However, which disadvantage might you face with Isomap?
#
# - A) Isomap handles big data more efficiently than t-SNE
# - B) Isomap preserves global distances flawlessly
# - C) If the data manifold is not single-connected or has complex loops, Isomap’s geodesic shortest-path assumption can produce severe distortions or bridging between “holes” in the manifold
# - D) Isomap allows no tuning of neighbors
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  C) If the data manifold is not single-connected or has complex loops, Isomap’s geodesic shortest-path assumption can produce severe distortions or bridging between “holes” in the manifold
#
# **Explanation:**
# Isomap constructs a neighborhood graph and uses approximate geodesic distances to embed data. Complex manifold structures with loops or separate sub-manifolds can lead to incorrect global geodesics that artificially connect regions, misrepresenting the true manifold geometry.
#
#
# ---
#
# ### 10. **Question:**
# You run **DBSCAN** for anomaly detection in an unlabeled dataset, tuning $\epsilon$ and minPts. Many borderline points become part of the largest cluster, leaving fewer explicit “noise” points. Which insight might cause you to adjust parameters?
#
# - A) A smaller $\epsilon$ can isolate borderline points as noise or separate clusters if you suspect they are outliers
# - B) DBSCAN automatically identifies anomalies in any case
# - C) A high minPts merges all data into one cluster
# - D) Setting $\epsilon=0$ is standard
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  A) A smaller $\epsilon$ can isolate borderline points as noise or separate clusters if you suspect they are outliers
#
# **Explanation:**
# If $\epsilon$ is too large or minPts too small, borderline points get absorbed into existing clusters. This reduces the number of points flagged as noise/outliers. Decreasing $\epsilon$ (and/or adjusting minPts) can refine cluster boundaries, potentially marking more borderline points as anomalies.
#
# ---
# ### 11. **Question:**
# When comparing **t-SNE** to **PCA**, one subtle yet important difference is in how they preserve data relationships. Specifically, **t-SNE** focuses on local structures, whereas **PCA** captures global variance directions. Which statement best reflects a potential pitfall when using **t-SNE**?
#
# - A) **t-SNE** perfectly preserves global distances, making it ideal for measuring pairwise distances at scale.
# - B) **t-SNE** sometimes overfits by mapping multiple distant points to the same region, masking inherent cluster separations.
# - C) **t-SNE** is guaranteed to produce a linear mapping between high-dimensional and low-dimensional spaces for interpretability.
# - D) **t-SNE** automatically ensures variance along each axis is maximized, much like PCA.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) **t-SNE** sometimes overfits by mapping multiple distant points to the same region, masking inherent cluster separations
# **Explanation:**
# Though t-SNE excels at highlighting local neighborhoods, it can struggle with faithfully representing global distances. In certain datasets (especially with tricky parameter choices like perplexity), distant clusters may inadvertently be projected close together, obscuring broader cluster structures.
#
# ---
#
# ### 12. **Question:**
# A data scientist runs **PCA** on a dataset and retains principal components that capture 90% of the variance. Later, they notice the classification performance does not improve. Which of the following reasons might best explain this outcome?
#
# - A) Keeping high-variance components **always** guarantees enhanced classification performance.
# - B) The low-variance components might still contain discriminative features relevant to classification, so discarding them hurt performance.
# - C) PCA transformations remove all noise, thus any further drop in performance must be due to overfitting the model.
# - D) 90% variance in PCA implies the classes are linearly separable in the projected space.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) The low-variance components might still contain discriminative features relevant to classification, so discarding them hurt performance
# **Explanation:**
# PCA’s objective is to preserve variance, not necessarily classification signals. Even components with low variance can encode information that helps distinguish classes, so discarding them can degrade predictive accuracy.
#
# ---
#
# ### 14. **Question:**
# A user applies **K-Means** to a dataset with many overlapping clusters and obtains inconsistent cluster assignments each time. Which less obvious reason might explain these variations?
#
# - A) The K-Means algorithm is deterministic for any random seed, so it cannot generate different assignments.
# - B) **K-Means** is extremely sensitive to initialization; different initial cluster centers may converge to different local minima.
# - C) **K-Means** handles overlapping clusters perfectly, so the user’s observations must be a data recording error.
# - D) Multiple global minima exist for K-Means, but the algorithm always finds the global one.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) **K-Means** is extremely sensitive to initialization; different initial cluster centers may converge to different local minima
# **Explanation:**
# K-Means often converges to local minima that are highly dependent on the initial starting positions. This can lead to different clustering results unless a robust initialization strategy is used or repeated clustering runs are consolidated.
#
# ---
#
# ### 15. **Question:**
# Which subtle advantage does **K-Means++** offer compared to standard K-Means initialization?
#
# - A) It guarantees perfect cluster separation by explicitly using hierarchical linkages.
# - B) It deterministically places all centroids in dense regions, ignoring isolated points by design.
# - C) It probabilistically spaces out initial centers to reduce the risk of them clustering too close.
# - D) It adjusts the cluster count automatically to minimize within-cluster variance.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  C) It probabilistically spaces out initial centers to reduce the risk of them clustering too close
# **Explanation:**
# K-Means++ selects initial centers in a way that favors spreading them out, reducing the chance of suboptimal clusters. It doesn’t guarantee perfect clustering but often improves K-Means convergence and the resulting cluster quality.
#
# ---
#
# ### 16. **Question:**
# When using a **Gaussian Mixture Model (GMM)** for clustering, the algorithm may converge to singular covariance matrices or degenerate solutions under certain conditions. Which subtle scenario below can lead to this issue?
#
# - A) Over-regularizing the covariance matrix with a large ridge term.
# - B) Having fewer clusters (components) than the dimensionality of the data.
# - C) Perfectly spherical clusters with zero correlation between features.
# - D) Placing a cluster component on only a handful of points, allowing the covariance to collapse near-zero.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  D) Placing a cluster component on only a handful of points, allowing the covariance to collapse near-zero
# **Explanation:**
# In some EM iterations, a mixture component can latch onto very few points, causing its estimated covariance to become nearly singular. Regularization can mitigate this, but the underlying issue is that the model’s free parameters allow overly tight fits to sparse data.
#
# ---
#
# ### 17. **Question:**
# In **Hierarchical Clustering**, different linkage criteria (single, complete, average, ward) can yield different results. What is a subtle but crucial pitfall of using **single linkage**?
#
# - A) Single linkage ensures outliers are never isolated, thus inflating cluster counts.
# - B) Single linkage frequently suffers from the “chaining effect,” potentially merging distinct clusters via a series of close pairs.
# - C) Single linkage requires specifying the number of clusters beforehand, making it rigid.
# - D) Single linkage excludes all within-cluster variance considerations, focusing only on mean distances.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) Single linkage frequently suffers from the “chaining effect,” potentially merging distinct clusters via a series of close pairs
# **Explanation:**
# Single linkage merges clusters based on the closest pair of points, sometimes forming long chains. A few points at the boundary can lead to unintended merges, obscuring true cluster structure.
#
# ---
#
# ### 18. **Question:**
# In **DBSCAN**, points are classified as core, border, or noise. Which nuanced outcome can occur when **eps** (the neighborhood radius) is slightly underestimated?
#
# - A) The algorithm creates one super-cluster containing all points.
# - B) Most points become core points, merging all clusters into a single large cluster.
# - C) Many points end up labeled as noise or outliers, even if they’re in plausible cluster interiors.
# - D) The results become identical to K-Means, with each cluster forming a spherical group.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  C) Many points end up labeled as noise or outliers, even if they’re in plausible cluster interiors
# **Explanation:**
# If eps is too small, points that should logically be part of a cluster won’t meet the neighborhood criteria. As a result, DBSCAN might label them as noise or assign them to borderline regions, failing to recognize true clusters.
#
# ---
#
# ### 19. **Question:**
# A security analyst is using an **anomaly detection** model that flags transactions deviating significantly from normal data patterns. Which subtle reason could lead to missed anomalies despite a seemingly effective model?
#
# - A) A very strict threshold is used, causing too many false alarms rather than misses.
# - B) The anomalies have feature values near the centroid of normal data distribution but differ in temporal or sequential context not captured by the model.
# - C) The model confuses anomalies with clusters, systematically reducing the number of reported anomalies.
# - D) The training data includes anomalies explicitly labeled as normal, which automatically corrects for them.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  B) The anomalies have feature values near the centroid of normal data distribution but differ in temporal or sequential context not captured by the model
# **Explanation:**
# An anomaly detection model might fail if it only considers static point-based distances in feature space. Sophisticated anomalies may share feature distributions with normal data but differ across temporal sequences or other patterns the model overlooks.
#
# ---
#
# ### 20. **Question:**
# When combining **dimensionality reduction** (such as PCA) with **clustering** (like GMM or K-Means), what is a subtle scenario where a carefully chosen lower dimension can outperform using all features?
#
# - A) Reducing dimensionality completely eliminates covariance between features, making cluster identification trivial.
# - B) Fewer dimensions simplifies the data so much that clusters become linear and always well separated.
# - C) Irrelevant or noisy high-dimensional features can obscure true cluster structure, so removing them can yield clearer clusters in fewer dimensions.
# - D) Dimensionality reduction always leads to a better silhouette score by default.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:**
#  C) Irrelevant or noisy high-dimensional features can obscure true cluster structure, so removing them can yield clearer clusters in fewer dimensions
# **Explanation:**
# Sometimes high-dimensional data contains noisy or irrelevant variables that distort distances or cluster shapes. By reducing dimensionality thoughtfully, the core structure of the data emerges, helping clustering methods perform better.

# %% [markdown]
# # Housing-Price Prediction Case Study

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from random import choices
from sklearn.svm import LinearSVR
from sklearn.metrics import r2_score
from sklearn.base import BaseEstimator
from sklearn.model_selection import KFold
from sklearn.ensemble import StackingRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer as Imputer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error as mape







plt.rcParams["figure.figsize"] = (12, 10)

# %%
# !gdown 1F9aD344ifJiKzRDlR4ZX0e4plDuP9-b9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1F9aD344ifJiKzRDlR4ZX0e4plDuP9-b9
# To: /content/kaggle_houseprices_modified.csv
# 100% 459k/459k [00:00<00:00, 90.3MB/s]

# %%
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500

# %%
ds = pd.read_csv('/content/kaggle_houseprices_modified.csv')
ds.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

# %%
ds.head(100).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# ...

# %%
todrop = ['Id']
categorical = ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
               'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'RoofStyle', 'RoofMatl', 'HouseStyle',
               'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir',
               'Electrical', 'GarageType', 'PavedDrive', 'Fence', 'MiscFeature', 'MoSold', 'SaleType', 'SaleCondition']
continuous = ['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1',
              'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'MasVnrArea',
              'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
              'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch',
              '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'YrSold', 'SalePrice']
cat_to_con = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
              'HeatingQC', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish', 'GarageQual', 'GarageCond',
              'PoolQC', ]

# %%
# list of names....used mapping of names, (NLTK female names, male names)

# %%
ds['MasVnrArea'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# run the imputation when not making pipeline

ds['LotFrontage'] = ds['LotFrontage'].fillna(ds['LotFrontage'].median())
ds['MasVnrArea']  = ds['MasVnrArea'].fillna(ds['MasVnrArea'].median())
ds['GarageYrBlt'] = ds['GarageYrBlt'].fillna(ds['GarageYrBlt'].mean())
print(ds[continuous].isna().sum().sum())
# Out:
# 0

# %%
def pre_processing(ds, todrop, categorical, cat_to_con):
  #dropping
  ds = ds.drop(columns=todrop)

  #categorical
  logical_nans = ['Alley', 'Fence', 'MiscFeature', 'MasVnrType', 'GarageType', ]
  for col in logical_nans:
      ds[col] = ds[col].fillna('NA')
  ds['Electrical'] = ds['Electrical'].fillna(ds['Electrical'].value_counts().index[0])  # mode
  print("no. of nans in categorical cols:", ds[categorical].isna().sum().sum())


  #cat_to_con
  ds['FireplaceQu'] = ds['FireplaceQu'].fillna('NA')
  logical_nans = ['FireplaceQu', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                  'BsmtFinType2', 'GarageFinish', 'GarageQual', 'GarageCond']
  for col in logical_nans:
      ds[col] = ds[col].fillna('NA')

  ds.drop(columns = ['PoolQC'], inplace=True)
  cat_to_con.remove('PoolQC')
  print("no. of nans in cat_to_con cols:",ds[cat_to_con].isna().sum().sum())

  #target_encoding
  target = 'SalePrice'
  for col in categorical:
      ds[col] = ds.groupby([col])[target].transform('mean')

  #label encoding
  grp1 = ['GarageQual', 'GarageCond', 'FireplaceQu', 'KitchenQual', 'HeatingQC', 'BsmtCond', 'BsmtQual', 'ExterCond', 'ExterQual']
  for col in grp1:
      ds[col] = ds[col].map({'TA': 3, 'Fa': 2, 'NA': 0, 'Gd': 4, 'Po': 1, 'Ex': 5})

  for col in ['BsmtFinType1', 'BsmtFinType2']:
      ds[col] = ds[col].map({'GLQ':6, 'ALQ':5, 'Unf':1, 'Rec':3, 'BLQ':4, 'NA':0, 'LwQ':2})

  ds['BsmtExposure'] = ds['BsmtExposure'].map({'No':1, 'Gd':4, 'Mn':2, 'Av':3, 'NA':0})
  ds['Functional'] = ds['Functional'].map({'Typ':7, 'Min1':6, 'Maj1':3, 'Min2':5, 'Mod':4, 'Maj2':2, 'Sev':1, 'Sal':0})
  ds['GarageFinish'] = ds['GarageFinish'].map({'RFn':2, 'Unf':1, 'Fin':3, 'NA':0})

  print("total nans in the dataframe:", ds.isna().sum().sum())

  return ds

# %%
ds = pre_processing(ds, todrop, categorical, cat_to_con)
# Out:
# no. of nans in categorical cols: 0
# no. of nans in cat_to_con cols: 0
# total nans in the dataframe: 0

# %%
ds.columns[ds.isna().sum()>0]
# Out:
# Index([], dtype='object')

# %%
# run the scaling when not making pipeline.
# All the viz will work on the standardized and imputed data

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# I pretty much always use StdScaler

# Use StdScaler if you don't know the range
# Use Minmax scaler if you know the range (it also suffers from outliers, and compression stuffs. )
# Use only one of these, don't use StdScaler for some columns, and MinMax for others.


scaler = StandardScaler()
ds_scaled = scaler.fit_transform(ds)

# %%
X = ds_scaled[:, :-1]
y = ds['SalePrice'].values

kf = KFold(n_splits=5)


y_true, y_pred = np.array([]), np.array([])
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    baseline_estimator = GradientBoostingRegressor(random_state=0)
    baseline_estimator.fit(X_train, y_train)
    y_true = np.append(y_true, y_test)
    y_pred = np.append(y_pred, baseline_estimator.predict(X_test))
print(mse(y_true, y_pred)**0.5)
print(mape(y_true, y_pred))
# Out:
# 31247.553546371884
# 0.10183201832527854

# %%
plt.scatter(range(len(y_true)), y_true)
plt.scatter(range(len(y_true)), y_pred)

# %%
# another way of visualising
plt.scatter(range(len(y_true)), sorted(y_true))
plt.scatter(range(len(y_true)), sorted(y_pred))

# %%
from sklearn.decomposition import PCA

cs = [5, 10, 15, 20, 25, 30, 40, 60, 75]
info = []
for i in cs:
  pca = PCA(n_components=i)
  pca.fit(ds_scaled[:, :-1])
  info.append(pca.explained_variance_ratio_.sum())

plt.plot(cs, info, '-o')

# %% [markdown]
# 1.  First I did feature-importance using GBDT, find out top 20 features, keep them separate.
# 2. For the remaining 60 features, USE PCA to decompose them into 30 features.

# %%
pca = PCA(n_components=40)
Xpca = pca.fit_transform(ds_scaled[:, :-1])
y = ds['SalePrice']

kf = KFold(n_splits=5)

mses = []
mapes = []
n = 0

y_true, y_pred = np.array([]), np.array([])
for train_index, test_index in kf.split(X):
    X_train, X_test = Xpca[train_index], Xpca[test_index]
    y_train, y_test = y[train_index], y[test_index]
    baseline_estimator = GradientBoostingRegressor(random_state=0)
    baseline_estimator.fit(X_train, y_train)
    y_true = np.append(y_true, y_test)
    y_pred = np.append(y_pred, baseline_estimator.predict(X_test))

print(mse(y_true, y_pred)**0.5)
# Out:
# 35956.650378010956

# %%
from sklearn.manifold import TSNE

pca = TSNE(n_components=2, perplexity=50, random_state=0)
vis = pca.fit_transform(ds_scaled[:, :-1])
plt.scatter(vis[:,0], vis[:,1], s=5)

# %%
from sklearn.cluster import DBSCAN
dbsc = DBSCAN(eps = 4.5, min_samples = 45).fit(vis)
plt.scatter(vis[:,0], vis[:,1], s=10, c=dbsc.labels_)
plt.colorbar()

# %%
ds.groupby(dbsc.labels_)['SalePrice'].mean()
# Out:
# -1    184270.901217
#  0    226433.120352
#  1    238941.562500
#  2    150031.788693
#  3    372357.129032
#  4     61967.647059
# Name: SalePrice, dtype: float64

# %%
ds.groupby(dbsc.labels_)['SalePrice'].plot(kind='kde')
plt.legend()

# %%
c = dbsc.labels_!=-1
X = ds_scaled[:, :-1][c]
y = ds['SalePrice'].values[c]
c = dbsc.labels_[dbsc.labels_!=-1]

kf = KFold(n_splits=5)

mses = []
mapes = []
n = 0

y_true, y_pred = np.array([]), np.array([])
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    c_train, c_test = c[train_index], c[test_index]
    baseline_estimator = GradientBoostingRegressor(random_state=0)
    baseline_estimator.fit(X_train, y_train)
    y_true = np.append(y_true, y_test)
    y_pred = np.append(y_pred, baseline_estimator.predict(X_test))

print(mse(y_true, y_pred)**0.5,  mape(y_true, y_pred))
# Out:
# 28729.04674854297 0.08950135709769767

# %%
plt.figure (figsize=(18, 5))
plt.plot(sorted(ds.SalePrice))

# %%
plt.figure (figsize=(18, 5))
plt.plot(sorted(np.log(ds.SalePrice)))

# %%
c = dbsc.labels_!=-1
X = ds_scaled[:, :-1][c]
y = np.log(ds['SalePrice'].values)[c]
c = dbsc.labels_[dbsc.labels_!=-1]

kf = KFold(n_splits=5)

mses = []
mapes = []
n = 0

y_true, y_pred = np.array([]), np.array([])
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    c_train, c_test = c[train_index], c[test_index]
    baseline_estimator = GradientBoostingRegressor(random_state=0)
    baseline_estimator.fit(X_train, y_train)
    y_true = np.append(y_true, np.exp(y_test))
    y_pred = np.append(y_pred, np.exp(baseline_estimator.predict(X_test)))

print(mse(y_true, y_pred)**0.5, mape(y_true, y_pred))
# Out:
# 27137.481861939505 0.08381776560698818

# %%
c = dbsc.labels_!=-1
X = ds_scaled[:, :-1][c]
y = np.log(ds['SalePrice'].values)[c]
c = dbsc.labels_[dbsc.labels_!=-1]

kf = KFold(n_splits=5)

mses = []
mapes = []
n = 0
for cluster in range(5):
    y_true, y_pred = np.array([]), np.array([])
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        c_train, c_test = c[train_index], c[test_index]
        estimator = GradientBoostingRegressor(random_state=0)
        estimator.fit(X_train, y_train)
        y_true = np.append(y_true, np.exp(y_test[c_test==cluster]))
        y_pred = np.append(y_pred, np.exp(estimator.predict(X_test[c_test==cluster])))
    mses.append(mse(y_true, y_pred)*len(y_true)**0.5)
    mapes.append(mape(y_true, y_pred)*len(y_true))
    n+=len(y_true)

    print(cluster, 'mse :', mse(y_true, y_pred)**0.5, 'mape:',mape(y_true, y_pred))

print(sum(mses)/n, sum(mapes)/n)
# Out:
# 0 mse : 22467.674531822915 mape: 0.06589067784448051
# 1 mse : 24574.950851701356 mape: 0.06338192633284288
# 2 mse : 16316.805142544157 mape: 0.0841301499029155
# 3 mse : 61321.06152425323 mape: 0.10326860518877166
# 4 mse : 13033.677322225501 mape: 0.17356275167230237
# 64582508.75766179 0.08381776560698818

# %%
mses = []
mapes = []
n = 0

dbsc_merged = pd.Series(dbsc.labels_).copy()
dbsc_merged.loc[dbsc_merged == 0] = 2
dbsc_merged.loc[dbsc_merged == 1] = 2

estimators = [GradientBoostingRegressor(n_estimators=50, learning_rate=0.6,max_depth=1, random_state=0)]
final_estimator = LinearRegression()

for cluster in range(2,5):
    X = ds_scaled[dbsc_merged==cluster][:, :-1]
    y = np.log(ds['SalePrice'].values)[dbsc_merged==cluster]
    estimator = GradientBoostingRegressor(random_state=0)
    # estimator = stacking(estimators, final_estimator)
    kf = KFold(n_splits=5)

    y_true, y_pred = np.array([]), np.array([])
    _ = []
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        estimator.fit(X_train, y_train)
        _.append(mse(np.exp(y_train), np.exp(estimator.predict(X_train))))
        y_true = np.append(y_true, np.exp(y_test))
        y_pred = np.append(y_pred, np.exp(estimator.predict(X_test)))
    print(sum(_)/len(_))
    mses.append(mse(y_true, y_pred)*len(y_true)**0.5)
    mapes.append(mape(y_true, y_pred)*len(y_true))
    n+=len(y_true)

    print(cluster, 'mse :', mse(y_true, y_pred)**0.5, 'mape:',mape(y_true, y_pred))

print(sum(mses)/n, sum(mapes)/n)
# Out:
# 84758570.39670601
# 2 mse : 20392.613628017993 mape: 0.07289429125335842
# 10415555.509546395
# 3 mse : 78666.91525260563 mape: 0.11565551408655181
# 25232.984487624613
# 4 mse : 13960.484926327983 mape: 0.19135267372668993
# 81798445.56233497 0.08421425874446226

# %% [markdown]
# 1. Clusters with unusually high errors can be further broken down/handled separately.
# 2. Some clusters can be merged, if they have similar performance.

# %% [markdown]
# # Stacking

# %% [markdown]
# xgboost; time it takes for website to send data to my model + time it takes model to predict + time it takes for the prediction to revert back to website

# %%
estimators = [
    ('rf', RandomForestRegressor(n_estimators=50,random_state=42)),
    ('gbdt', GradientBoostingRegressor(n_estimators=50, learning_rate=0.6,max_depth=1, random_state=0)),
    ('knn', KNeighborsRegressor(n_neighbors=7))
]

final_estimator = LinearRegression()

# %%
#custom stacking
class stacking(BaseEstimator):
  def __init__(self, estimators, final_estimator):
      self.estimators = estimators
      self.final_estimator = final_estimator


  def fit(self, X, y=None):
        for estimator in self.estimators:
            estimator[1].fit(X, y)

        pred_features = np.array([estimator[1].predict(X) for estimator in self.estimators]).T
        self.final_estimator.fit(pred_features, y)

  def predict(self, X):
        pred_features = np.array([estimator[1].predict(X) for estimator in self.estimators]).T
        return self.final_estimator.predict(pred_features)

  def score(self, X, y):
        pred_features = np.array([estimator[1].predict(X) for estimator in self.estimators]).T
        return self.final_estimator.score(pred_features, y)

# %%
c = dbsc.labels_!=-1
X = ds_scaled[:, :-1][c]
y = np.log(ds['SalePrice'].values)[c]
c = dbsc.labels_[dbsc.labels_!=-1]

kf = KFold(n_splits=5)

mses = []
mapes = []
n = 0

y_true, y_pred = np.array([]), np.array([])
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    c_train, c_test = c[train_index], c[test_index]
    # baseline_estimator = GradientBoostingRegressor(random_state=0)
    baeline_estimator = StackingRegressor(estimators, final_estimator)
    baseline_estimator.fit(X_train, y_train)
    y_true = np.append(y_true, np.exp(y_test))
    y_pred = np.append(y_pred, np.exp(baseline_estimator.predict(X_test)))

print(mse(y_true, y_pred)**0.5, mape(y_true, y_pred))
# Out:
# 27137.481861939505 0.08381776560698818

# %% [markdown]
# 27137.481861939505 0.08381776560698818

# %% [markdown]
# LLD and System Design

# %% [markdown]
# 9790723608; shivam.prasad_1@scaler.com
