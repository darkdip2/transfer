# %%
import pandas as pd
import datetime as dt
from datetime import datetime, timedelta


#!pip install openpyxl

df=pd.read_excel('transit.xlsx')
date_format = "%y-%m-%d"
df['Date']=pd.to_datetime(df['Date'],format=date_format)
df['Weekday']=df['Date'].dt.day_name()
df.fillna({'One':'one','Two':'iOPEX','Three':'Three','Add':0,'Minus':0, 'yt':0, 'screen':0, 'Number':95},inplace=True)

# %% [markdown]
# # BALANCE

# %%
current_balance=18000
current_date='24-11-18'
df_=df[df.Date<=pd.to_datetime(current_date)]
print(f'CURRENT BALANCE =======> {current_balance+df_.Add.sum()-df_.Minus.sum()}')
# Out:
# CURRENT BALANCE =======> 18000

# %% [markdown]
# # WEIGHT

# %%
current_weight = 95
current_date = '24-11-18'
current_date = pd.to_datetime(current_date, format='%y-%m-%d')
days_difference = (dt.datetime.today().date() - current_date.date()).days
expected_weight = current_weight - 0.5 * days_difference/7
print(f'EXPECTED WEIGHT =======> {expected_weight:.2f}')
# Out:
# EXPECTED WEIGHT =======> 95.14

# %% [markdown]
# ## TODAY

# %%
today_date = dt.datetime.today().date()
today_row = df[df['Date'] == pd.to_datetime(today_date)]
today_row
# Out:
# Empty DataFrame
# Columns: [Date, One, Two, Three, Add, Minus, yt, screen, Number, Weekday]
# Index: []

# %% [markdown]
# ## CURRENT WEEK => FIRST WEEK

# %%
today_date = datetime.today().date()
start_of_week = today_date - timedelta(days=today_date.weekday())
end_of_week = start_of_week + timedelta(days=6)
start_of_week = pd.to_datetime(start_of_week)
end_of_week = pd.to_datetime(end_of_week)
current_week_rows = df[(df['Date'] >= start_of_week) & (df['Date'] <= end_of_week)]
current_week_rows
# Out:
#         Date        One       Two Three  Add  Minus   yt  screen  Number  \
# 0 2024-11-17  Docker.py  Chill.py  GFGc    0    210  0.0     0.0    1033
#
#   Weekday
# 0  Sunday

# %% [markdown]
# ## FOURTH WEEK

# %%
df.iloc[-7:]
# Out:
#          Date       One       Two    Three  Add  Minus   yt  screen  Number  \
# 22 2024-12-09   RecSys5  iOPEX.py  Gym?.js    0    250  0.0     0.0    1055
# 23 2024-12-10    ML.all  iOPEX.py  Gym?.js    0    250  0.0     0.0    1056
# 24 2024-12-11  Revision  iOPEX.py  Gym?.js    0    250  0.0     0.0    1057
# 25 2024-12-12  Revision  iOPEX.py  Gym?.js    0    250  0.0     0.0    1058
# 26 2024-12-13  Revision  iOPEX.py  Gym?.js    0    250  0.0     0.0    1059
# 27 2024-12-14  Extra.py  Chill.py  Gym?.js    0    530  0.0     0.0    1060
# 28 2024-12-15  Extra.py  Chill.py  Gym?.js    0    530  0.0     0.0    1061
#
#       Weekday
# 22     Monday
# 23    Tuesday
# 24  Wednesday
# 25   Thursday
# 26     Friday
# 27   Saturday
# 28     Sunday

# %% [markdown]
# ## THIRD WEEK

# %%
df.iloc[-14:-7]
# Out:
#          Date       One       Two    Three  Add  Minus   yt  screen  Number  \
# 15 2024-12-02       Ts5  iOPEX.py  Gym?.js    0    250  0.0     0.0    1048
# 16 2024-12-03   RecSys1  iOPEX.py  Gym?.js    0    250  0.0     0.0    1049
# 17 2024-12-04   RecSys2  iOPEX.py  Gym?.js    0   8583  0.0     0.0    1050
# 18 2024-12-05   RecSys3  iOPEX.py  Gym?.js    0    250  0.0     0.0    1051
# 19 2024-12-06   RecSys4  iOPEX.py  Gym?.js    0    250  0.0     0.0    1052
# 20 2024-12-07  Extra.py  Chill.py  Gym?.js    0    530  0.0     0.0    1053
# 21 2024-12-08  Extra.py  Chill.py  Gym?.js    0    210  0.0     0.0    1054
#
#       Weekday
# 15     Monday
# 16    Tuesday
# 17  Wednesday
# 18   Thursday
# 19     Friday
# 20   Saturday
# 21     Sunday

# %% [markdown]
# ## SECOND WEEK

# %%
df.iloc[-21:-14]
# Out:
#          Date       One       Two    Three    Add  Minus   yt  screen  Number  \
# 8  2024-11-25  Ts.intro  iOPEX.py  Gym?.js      0    250  0.0     0.0    1041
# 9  2024-11-26       Ts1  iOPEX.py  Gym?.js      0    250  0.0     0.0    1042
# 10 2024-11-27       Ts2  iOPEX.py  Gym?.js  20000  12750  0.0     0.0    1043
# 11 2024-11-28       Ts3  iOPEX.py  Gym?.js      0    250  0.0     0.0    1044
# 12 2024-11-29       Ts4  iOPEX.py  Gym?.js      0    250  0.0     0.0    1045
# 13 2024-11-30  Extra.py  Chill.py  Gym?.js  32000   9530  0.0     0.0    1046
# 14 2024-12-01  Extra.py  Chill.py  Gym?.js      0    530  0.0     0.0    1047
#
#       Weekday
# 8      Monday
# 9     Tuesday
# 10  Wednesday
# 11   Thursday
# 12     Friday
# 13   Saturday
# 14     Sunday

# %% [markdown]
# ## FIRST WEEK

# %%
df.iloc[-28:-21]
# Out:
#         Date       One       Two    Three  Add  Minus   yt  screen  Number  \
# 1 2024-11-18        Bc  iOPEX.py  Gym?.js    0    250  0.0     0.0    1034
# 2 2024-11-19        Bc  iOPEX.py  Gym?.js    0    250  0.0     0.0    1035
# 3 2024-11-20        Bc  iOPEX.py  Gym?.js    0    250  0.0     0.0    1036
# 4 2024-11-21        Bc  iOPEX.py  Gym?.js    0    250  0.0     0.0    1037
# 5 2024-11-22        Bc  iOPEX.py  Gym?.js    0    250  0.0     0.0    1038
# 6 2024-11-23  Extra.py  Chill.py  Gym?.js    0    530  0.0     0.0    1039
# 7 2024-11-24  Extra.py  Chill.py  Gym?.js    0    210  0.0     0.0    1040
#
#      Weekday
# 1     Monday
# 2    Tuesday
# 3  Wednesday
# 4   Thursday
# 5     Friday
# 6   Saturday
# 7     Sunday
